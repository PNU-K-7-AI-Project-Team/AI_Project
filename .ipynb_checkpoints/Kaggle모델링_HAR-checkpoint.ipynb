# %% [markdown]
# # **1. 데이터 로드 및 전처리**

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras import regularizers

# 데이터 로드
data = pd.read_csv('./원본 데이터/transformed_train_mapped.csv')

# 라벨 인코딩
label_encoder = LabelEncoder()
data['activity'] = label_encoder.fit_transform(data['activity'])

# 데이터 정규화
mean = np.mean(data[['x-accl', 'y-accl', 'z-accl']], axis=0)
std = np.std(data[['x-accl', 'y-accl', 'z-accl']], axis=0)
data[['x-accl', 'y-accl', 'z-accl']] = (data[['x-accl', 'y-accl', 'z-accl']] - mean) / std

# 데이터 분할 (7:3 비율로 train/test 분할)
train_data, test_data = train_test_split(data, 
                                         test_size=0.3, 
                                         random_state=42, 
                                         stratify=data['activity'])

# 데이터 분할이 올바르게 되었는지 확인
print(f"Train data size: {len(train_data)}")
print(f"Test data size: {len(test_data)}")

# 데이터 세그먼트화 및 라벨링 함수 (-1, TIME_PERIODS, 3)
TIME_PERIODS = 80  # 세그먼트 길이
STEP_DISTANCE = 40 # if STEP_DISTANCE = TIME_PERIODS, then no overlap

def data_segments(data):
    segments = []
    labels = []
    for i in range(0, len(data) - TIME_PERIODS, STEP_DISTANCE):
        X = data.iloc[i:i + TIME_PERIODS, 2:].values.tolist()
        values, counts = np.unique(data.iloc[i:i + TIME_PERIODS, 1], return_counts=True)
        label = values[np.argmax(counts)]
        segments.append(X)
        labels.append(label)
    segments = np.array(segments, dtype=np.float32).reshape(-1, TIME_PERIODS, 3)
    labels = np.asarray(labels)
    return segments, labels

# 훈련 및 테스트 데이터 세그먼트화
x_train, y_train = data_segments(train_data)
x_test, y_test = data_segments(test_data)

# 세그먼트 생성 후 데이터 크기 확인
print(f"x_train shape: {x_train.shape}")
print(f"x_test shape: {x_test.shape}")

# 라벨 원-핫 인코딩
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# 1D CNN 모델 생성 (L2 정규화 적용)
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(TIME_PERIODS, 3)),
    tf.keras.layers.Conv1D(filters=100, kernel_size=11, activation='relu', kernel_regularizer=regularizers.l2(0.03)),
    tf.keras.layers.MaxPool1D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv1D(filters=10, kernel_size=5, activation='relu', kernel_regularizer=regularizers.l2(0.03)),
    tf.keras.layers.MaxPool1D(),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=5, activation='softmax', kernel_regularizer=regularizers.l2(0.03))
])

model.summary()

# 모델 컴파일 및 학습
opt = tf.keras.optimizers.RMSprop(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
ret = model.fit(x_train, y_train, epochs=100, batch_size=200, validation_data=(x_test, y_test), verbose=2)

# 모델 평가
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

# 정확도 및 손실 시각화
plt.title("Accuracy")
plt.plot(ret.history['accuracy'], "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc="best")
plt.show()

# 샘플 활동 데이터 시각화
activity_labels = label_encoder.classes_  # activity names
train_labels = np.argmax(y_train, axis=1)

plot_data_indices = []
n = 1  # nth data point to plot

for i in range(5):  # for each class/activity
    plot_data_indices.append(np.where(train_labels == i)[0][n])  # get nth index for class

fig, ax = plt.subplots(5, sharex=True, sharey=True, figsize=(10, 8))
fig.tight_layout()

for i in range(5):
    k = plot_data_indices[i]
    ax[i].plot(x_train[k])
    ax[i].set_title(activity_labels[i])

plt.show()
# Out:
# Train data size: 13735
# Test data size: 5887
# x_train shape: (342, 80, 3)
# x_test shape: (146, 80, 3)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_18 (Conv1D)                   │ (None, 70, 100)             │           3,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_18 (MaxPooling1D)      │ (None, 35, 100)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 35, 100)             │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_19 (Conv1D)                   │ (None, 31, 10)              │           5,010 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_19 (MaxPooling1D)      │ (None, 15, 10)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 15, 10)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_9 (Flatten)                  │ (None, 150)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 5)                   │             755 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,565 (37.36 KB)
#  Trainable params: 9,365 (36.58 KB)
#  Non-trainable params: 200 (800.00 B)
# Epoch 1/100
# 2/2 - 1s - 527ms/step - accuracy: 0.2164 - loss: 3.9805 - val_accuracy: 0.3014 - val_loss: 2.5523
# Epoch 2/100
# 2/2 - 0s - 26ms/step - accuracy: 0.4795 - loss: 2.6135 - val_accuracy: 0.5479 - val_loss: 2.4601
# Epoch 3/100
# 2/2 - 0s - 27ms/step - accuracy: 0.5556 - loss: 2.3885 - val_accuracy: 0.6233 - val_loss: 2.4150
# Epoch 4/100
# 2/2 - 0s - 26ms/step - accuracy: 0.6316 - loss: 2.1764 - val_accuracy: 0.6644 - val_loss: 2.3778
# Epoch 5/100
# 2/2 - 0s - 26ms/step - accuracy: 0.6579 - loss: 2.0052 - val_accuracy: 0.6986 - val_loss: 2.3588
# Epoch 6/100
# 2/2 - 0s - 25ms/step - accuracy: 0.7193 - loss: 1.8275 - val_accuracy: 0.7260 - val_loss: 2.3380
# Epoch 7/100
# 2/2 - 0s - 26ms/step - accuracy: 0.6930 - loss: 1.8366 - val_accuracy: 0.7260 - val_loss: 2.3408
# Epoch 8/100
# 2/2 - 0s - 26ms/step - accuracy: 0.7339 - loss: 1.7290 - val_accuracy: 0.7192 - val_loss: 2.3260
# Epoch 9/100
# 2/2 - 0s - 26ms/step - accuracy: 0.7310 - loss: 1.6684 - val_accuracy: 0.7397 - val_loss: 2.3125
# Epoch 10/100
# 2/2 - 0s - 26ms/step - accuracy: 0.7661 - loss: 1.6250 - val_accuracy: 0.7534 - val_loss: 2.2931
# Epoch 11/100
# 2/2 - 0s - 42ms/step - accuracy: 0.7924 - loss: 1.4959 - val_accuracy: 0.7397 - val_loss: 2.2895
# Epoch 12/100
# 2/2 - 0s - 24ms/step - accuracy: 0.7953 - loss: 1.5299 - val_accuracy: 0.7397 - val_loss: 2.2865
# Epoch 13/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8392 - loss: 1.4579 - val_accuracy: 0.7534 - val_loss: 2.2703
# Epoch 14/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8216 - loss: 1.4394 - val_accuracy: 0.7534 - val_loss: 2.2568
# Epoch 15/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8070 - loss: 1.4285 - val_accuracy: 0.7603 - val_loss: 2.2331
# Epoch 16/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8596 - loss: 1.3822 - val_accuracy: 0.7740 - val_loss: 2.2203
# Epoch 17/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8567 - loss: 1.3405 - val_accuracy: 0.7740 - val_loss: 2.2136
# Epoch 18/100
# 2/2 - 0s - 27ms/step - accuracy: 0.8480 - loss: 1.3198 - val_accuracy: 0.7671 - val_loss: 2.2048
# Epoch 19/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8421 - loss: 1.3461 - val_accuracy: 0.7671 - val_loss: 2.2041
# Epoch 20/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8713 - loss: 1.2367 - val_accuracy: 0.7671 - val_loss: 2.1909
# Epoch 21/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8655 - loss: 1.2547 - val_accuracy: 0.7671 - val_loss: 2.1867
# Epoch 22/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8772 - loss: 1.2527 - val_accuracy: 0.7671 - val_loss: 2.1789
# Epoch 23/100
# 2/2 - 0s - 27ms/step - accuracy: 0.9006 - loss: 1.1860 - val_accuracy: 0.7740 - val_loss: 2.1722
# Epoch 24/100
# 2/2 - 0s - 26ms/step - accuracy: 0.8860 - loss: 1.1895 - val_accuracy: 0.7808 - val_loss: 2.1407
# Epoch 25/100
# 2/2 - 0s - 27ms/step - accuracy: 0.8918 - loss: 1.1699 - val_accuracy: 0.7603 - val_loss: 2.1365
# Epoch 26/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9152 - loss: 1.1234 - val_accuracy: 0.7603 - val_loss: 2.1298
# Epoch 27/100
# 2/2 - 0s - 27ms/step - accuracy: 0.8977 - loss: 1.1304 - val_accuracy: 0.7671 - val_loss: 2.1154
# Epoch 28/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9211 - loss: 1.0842 - val_accuracy: 0.7740 - val_loss: 2.1019
# Epoch 29/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9386 - loss: 1.0587 - val_accuracy: 0.7808 - val_loss: 2.0870
# Epoch 30/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9094 - loss: 1.1187 - val_accuracy: 0.7877 - val_loss: 2.0955
# Epoch 31/100
# 2/2 - 0s - 27ms/step - accuracy: 0.9240 - loss: 1.0708 - val_accuracy: 0.7877 - val_loss: 2.0766
# Epoch 32/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9444 - loss: 1.0082 - val_accuracy: 0.7877 - val_loss: 2.0523
# Epoch 33/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9532 - loss: 1.0013 - val_accuracy: 0.7877 - val_loss: 2.0308
# Epoch 34/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9357 - loss: 1.0035 - val_accuracy: 0.7945 - val_loss: 2.0205
# Epoch 35/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9035 - loss: 1.0137 - val_accuracy: 0.7877 - val_loss: 2.0403
# Epoch 36/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9386 - loss: 0.9913 - val_accuracy: 0.7945 - val_loss: 2.0072
# Epoch 37/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9357 - loss: 0.9885 - val_accuracy: 0.7945 - val_loss: 1.9727
# Epoch 38/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9444 - loss: 0.9407 - val_accuracy: 0.7945 - val_loss: 1.9838
# Epoch 39/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9708 - loss: 0.9114 - val_accuracy: 0.7945 - val_loss: 1.9645
# Epoch 40/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9211 - loss: 0.9716 - val_accuracy: 0.7945 - val_loss: 1.9655
# Epoch 41/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9415 - loss: 0.9392 - val_accuracy: 0.7945 - val_loss: 1.9624
# Epoch 42/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9708 - loss: 0.8980 - val_accuracy: 0.7945 - val_loss: 1.9270
# Epoch 43/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9444 - loss: 0.9138 - val_accuracy: 0.7945 - val_loss: 1.9239
# Epoch 44/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9649 - loss: 0.8797 - val_accuracy: 0.7945 - val_loss: 1.9011
# Epoch 45/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9649 - loss: 0.8508 - val_accuracy: 0.7945 - val_loss: 1.8799
# Epoch 46/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9561 - loss: 0.8620 - val_accuracy: 0.7945 - val_loss: 1.8833
# Epoch 47/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9591 - loss: 0.8541 - val_accuracy: 0.7945 - val_loss: 1.8749
# Epoch 48/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9532 - loss: 0.8490 - val_accuracy: 0.7945 - val_loss: 1.8682
# Epoch 49/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9620 - loss: 0.8172 - val_accuracy: 0.7945 - val_loss: 1.8445
# Epoch 50/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9532 - loss: 0.8211 - val_accuracy: 0.7945 - val_loss: 1.8301
# Epoch 51/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9474 - loss: 0.8328 - val_accuracy: 0.7945 - val_loss: 1.8149
# Epoch 52/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9649 - loss: 0.8057 - val_accuracy: 0.7945 - val_loss: 1.8018
# Epoch 53/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9649 - loss: 0.7843 - val_accuracy: 0.7945 - val_loss: 1.7969
# Epoch 54/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9649 - loss: 0.7805 - val_accuracy: 0.7945 - val_loss: 1.7734
# Epoch 55/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9766 - loss: 0.7538 - val_accuracy: 0.7945 - val_loss: 1.7519
# Epoch 56/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9737 - loss: 0.7357 - val_accuracy: 0.7945 - val_loss: 1.7189
# Epoch 57/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9591 - loss: 0.7669 - val_accuracy: 0.7945 - val_loss: 1.7344
# Epoch 58/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9737 - loss: 0.7145 - val_accuracy: 0.7945 - val_loss: 1.7312
# Epoch 59/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9678 - loss: 0.7339 - val_accuracy: 0.7945 - val_loss: 1.7161
# Epoch 60/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9708 - loss: 0.7241 - val_accuracy: 0.7945 - val_loss: 1.6907
# Epoch 61/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9649 - loss: 0.7103 - val_accuracy: 0.7945 - val_loss: 1.6867
# Epoch 62/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9678 - loss: 0.6942 - val_accuracy: 0.7945 - val_loss: 1.6741
# Epoch 63/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9678 - loss: 0.6943 - val_accuracy: 0.7945 - val_loss: 1.6522
# Epoch 64/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9708 - loss: 0.6928 - val_accuracy: 0.7945 - val_loss: 1.6366
# Epoch 65/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9795 - loss: 0.6699 - val_accuracy: 0.8014 - val_loss: 1.6002
# Epoch 66/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9708 - loss: 0.6729 - val_accuracy: 0.8014 - val_loss: 1.6105
# Epoch 67/100
# 2/2 - 0s - 27ms/step - accuracy: 0.9708 - loss: 0.6816 - val_accuracy: 0.8014 - val_loss: 1.6029
# Epoch 68/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9708 - loss: 0.6595 - val_accuracy: 0.7945 - val_loss: 1.5913
# Epoch 69/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9795 - loss: 0.6443 - val_accuracy: 0.7945 - val_loss: 1.5594
# Epoch 70/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9825 - loss: 0.6309 - val_accuracy: 0.8014 - val_loss: 1.5558
# Epoch 71/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9883 - loss: 0.6096 - val_accuracy: 0.7945 - val_loss: 1.5339
# Epoch 72/100
# 2/2 - 0s - 27ms/step - accuracy: 0.9854 - loss: 0.6184 - val_accuracy: 0.7945 - val_loss: 1.5065
# Epoch 73/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9708 - loss: 0.6278 - val_accuracy: 0.8014 - val_loss: 1.5176
# Epoch 74/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9912 - loss: 0.6085 - val_accuracy: 0.8014 - val_loss: 1.4820
# Epoch 75/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9795 - loss: 0.6097 - val_accuracy: 0.7945 - val_loss: 1.4855
# Epoch 76/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9737 - loss: 0.6128 - val_accuracy: 0.8014 - val_loss: 1.4715
# Epoch 77/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9795 - loss: 0.6054 - val_accuracy: 0.8014 - val_loss: 1.4450
# Epoch 78/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9737 - loss: 0.5862 - val_accuracy: 0.8014 - val_loss: 1.4302
# Epoch 79/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9649 - loss: 0.5953 - val_accuracy: 0.8014 - val_loss: 1.4508
# Epoch 80/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9766 - loss: 0.5891 - val_accuracy: 0.8014 - val_loss: 1.4129
# Epoch 81/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9825 - loss: 0.5674 - val_accuracy: 0.8014 - val_loss: 1.4104
# Epoch 82/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9825 - loss: 0.5636 - val_accuracy: 0.8014 - val_loss: 1.3774
# Epoch 83/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9795 - loss: 0.5535 - val_accuracy: 0.8014 - val_loss: 1.3920
# Epoch 84/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9795 - loss: 0.5522 - val_accuracy: 0.8014 - val_loss: 1.3606
# Epoch 85/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9825 - loss: 0.5374 - val_accuracy: 0.8014 - val_loss: 1.3517
# Epoch 86/100
# 2/2 - 0s - 24ms/step - accuracy: 0.9591 - loss: 0.5660 - val_accuracy: 0.8014 - val_loss: 1.3736
# Epoch 87/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9620 - loss: 0.5573 - val_accuracy: 0.8014 - val_loss: 1.3579
# Epoch 88/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9825 - loss: 0.5414 - val_accuracy: 0.8014 - val_loss: 1.3294
# Epoch 89/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9708 - loss: 0.5306 - val_accuracy: 0.8014 - val_loss: 1.3383
# Epoch 90/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9825 - loss: 0.5186 - val_accuracy: 0.8014 - val_loss: 1.3112
# Epoch 91/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9883 - loss: 0.5092 - val_accuracy: 0.8014 - val_loss: 1.3046
# Epoch 92/100
# 2/2 - 0s - 44ms/step - accuracy: 0.9766 - loss: 0.5121 - val_accuracy: 0.8014 - val_loss: 1.2988
# Epoch 93/100
# 2/2 - 0s - 23ms/step - accuracy: 0.9766 - loss: 0.5198 - val_accuracy: 0.8014 - val_loss: 1.2791
# Epoch 94/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9708 - loss: 0.5210 - val_accuracy: 0.8014 - val_loss: 1.2741
# Epoch 95/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9883 - loss: 0.4909 - val_accuracy: 0.8014 - val_loss: 1.2611
# Epoch 96/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9912 - loss: 0.4869 - val_accuracy: 0.8014 - val_loss: 1.2457
# Epoch 97/100
# 2/2 - 0s - 25ms/step - accuracy: 0.9825 - loss: 0.4964 - val_accuracy: 0.8014 - val_loss: 1.2374
# Epoch 98/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9766 - loss: 0.4867 - val_accuracy: 0.8014 - val_loss: 1.2161
# Epoch 99/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9854 - loss: 0.4767 - val_accuracy: 0.8014 - val_loss: 1.2259
# Epoch 100/100
# 2/2 - 0s - 26ms/step - accuracy: 0.9912 - loss: 0.4798 - val_accuracy: 0.8014 - val_loss: 1.1949
# 11/11 - 0s - 2ms/step - accuracy: 0.7895 - loss: 0.9183
# 5/5 - 0s - 4ms/step - accuracy: 0.8014 - loss: 1.1949
