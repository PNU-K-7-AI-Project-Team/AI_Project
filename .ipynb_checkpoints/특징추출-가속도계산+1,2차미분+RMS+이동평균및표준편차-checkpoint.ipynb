# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.optim as optim

# %%
# 데이터 전처리 및 특징 추출 코드
def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)

    # 필요한 특징 선택
    features = data[['gyros_forearm_x', 'gyros_forearm_y', 'gyros_forearm_z']]
    labels = data['classe']

    # 가속도 계산 (각속도의 변화율)
    features['gyros_forearm_x_acc'] = np.gradient(features['gyros_forearm_x'])
    features['gyros_forearm_y_acc'] = np.gradient(features['gyros_forearm_y'])
    features['gyros_forearm_z_acc'] = np.gradient(features['gyros_forearm_z'])

    # 자이로스코프 신호의 1차 및 2차 미분
    features['gyros_forearm_x_diff'] = np.diff(features['gyros_forearm_x'], prepend=0)
    features['gyros_forearm_y_diff'] = np.diff(features['gyros_forearm_y'], prepend=0)
    features['gyros_forearm_z_diff'] = np.diff(features['gyros_forearm_z'], prepend=0)

    # 신호 에너지 계산 (RMS)
    features['gyros_forearm_x_energy'] = np.sqrt(np.mean(features['gyros_forearm_x']**2))
    features['gyros_forearm_y_energy'] = np.sqrt(np.mean(features['gyros_forearm_y']**2))
    features['gyros_forearm_z_energy'] = np.sqrt(np.mean(features['gyros_forearm_z']**2))

    # 이동 평균 및 표준 편차
    window_size = 5
    features['gyros_forearm_x_ma'] = features['gyros_forearm_x'].rolling(window=window_size).mean()
    features['gyros_forearm_y_ma'] = features['gyros_forearm_y'].rolling(window=window_size).mean()
    features['gyros_forearm_z_ma'] = features['gyros_forearm_z'].rolling(window=window_size).mean()

    features['gyros_forearm_x_std'] = features['gyros_forearm_x'].rolling(window=window_size).std()
    features['gyros_forearm_y_std'] = features['gyros_forearm_y'].rolling(window=window_size).std()
    features['gyros_forearm_z_std'] = features['gyros_forearm_z'].rolling(window=window_size).std()

    # 켤측값 및 inf 값 처리
    features = features.replace([np.inf, -np.inf], np.nan) # inf 값을 NaN으로 변환
    features = features.fillna(0) # NaN 값을 0으로 대체

    # 클래스 레이블 인코딩
    label_encoder = LabelEncoder()
    labels = label_encoder.fit_transform(labels)

    return features, labels

# 데이터 로드
training_data_path = './원본 데이터/pml-training.csv'
features, labels = load_and_preprocess_data(training_data_path)

# Train/Test 분할
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# 표준화
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# PyTorch TensorDatset 생성
train_dataset = TensorDataset(torch.tensor(x_train).float(), torch.tensor(y_train).long())
test_dataset = TensorDataset(torch.tensor(x_test).float(), torch.tensor(y_test).long())

# DataLoader 생성
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:3: DtypeWarning: Columns (11,14,19,22,25,70,73,86,87,89,90,94,97,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_x_acc'] = np.gradient(features['gyros_forearm_x'])
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_y_acc'] = np.gradient(features['gyros_forearm_y'])
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_z_acc'] = np.gradient(features['gyros_forearm_z'])
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_x_diff'] = np.diff(features['gyros_forearm_x'], prepend=0)
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_y_diff'] = np.diff(features['gyros_forearm_y'], prepend=0)
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_z_diff'] = np.diff(features['gyros_forearm_z'], prepend=0)
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_x_energy'] = np.sqrt(np.mean(features['gyros_forearm_x']**2))
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_y_energy'] = np.sqrt(np.mean(features['gyros_forearm_y']**2))
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_z_energy'] = np.sqrt(np.mean(features['gyros_forearm_z']**2))
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_x_ma'] = features['gyros_forearm_x'].rolling(window=window_size).mean()
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_y_ma'] = features['gyros_forearm_y'].rolling(window=window_size).mean()
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_z_ma'] = features['gyros_forearm_z'].rolling(window=window_size).mean()
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_x_std'] = features['gyros_forearm_x'].rolling(window=window_size).std()
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_y_std'] = features['gyros_forearm_y'].rolling(window=window_size).std()
# C:\Users\user\AppData\Local\Temp\ipykernel_13096\192735100.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['gyros_forearm_z_std'] = features['gyros_forearm_z'].rolling(window=window_size).std()

# %%
class CNN_LSTM(nn.Module):
    def __init__(self, input_channels, num_classes):
        super(CNN_LSTM, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=input_channels, out_channels=64, kernel_size=1, stride=1)
        self.bn1 = nn.BatchNorm1d(64)
        # MaxPool1d 제거
        # self.pool = nn.MaxPool1d(kernel_size=2, stride=1)  # 이 레이어를 제거하거나 적절히 조정합니다.
        
        self.lstm1 = nn.LSTM(input_size=64, hidden_size=128, num_layers=1, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=128, num_layers=1, batch_first=True)
        self.dropout = nn.Dropout(0.5)
        
        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        # x = self.pool(x)  # MaxPool1d를 사용하지 않거나 대체 방법을 고려합니다.
        
        x = x.permute(0, 2, 1)  # (batch_size, sequence_length, features) 형태로 변환
        
        x, _ = self.lstm1(x)
        x = self.dropout(x)
        x, _ = self.lstm2(x)
        
        x = x[:, -1, :]  # 마지막 LSTM의 출력을 사용
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
# 모델 초기화
input_channels = x_train.shape[1]  # 실제 입력 데이터의 채널 수를 반영
model = CNN_LSTM(input_channels=input_channels, num_classes=6)

# 손실 함수 및 옵티마이저 정의
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 학습 루프
epochs = 500
for epoch in range(epochs):
    model.train()
    train_loss, correct_train = 0, 0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        
        # 입력 데이터의 차원을 확인하여 필요한 경우 3D로 변환
        if inputs.dim() == 2:  # inputs의 차원이 (batch_size, features)인 경우
            inputs = inputs.unsqueeze(1)  # (batch_size, 1, features)

        inputs = inputs.transpose(1, 2)  # (batch_size, 1, features) -> (batch_size, features, 1)
        
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == labels).sum().item()

    train_loss /= len(train_loader.dataset)
    train_accuracy = correct_train / len(train_loader.dataset)

    # 검증 루프
    model.eval()
    test_loss, correct_test = 0, 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            if inputs.dim() == 2:
                inputs = inputs.unsqueeze(1)
                
            inputs = inputs.transpose(1, 2)  # (batch_size, 1, features) -> (batch_size, features, 1)
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            correct_test += (predicted == labels).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = correct_test / len(test_loader.dataset)

    print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
          f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/100, Train Loss: 1.5397, Train Accuracy: 0.3168, Test Loss: 1.4887, Test Accuracy: 0.3465
# Epoch 2/100, Train Loss: 1.4761, Train Accuracy: 0.3620, Test Loss: 1.5168, Test Accuracy: 0.3399
# Epoch 3/100, Train Loss: 1.4540, Train Accuracy: 0.3757, Test Loss: 1.4387, Test Accuracy: 0.3865
# Epoch 4/100, Train Loss: 1.4430, Train Accuracy: 0.3860, Test Loss: 1.4164, Test Accuracy: 0.3964
# Epoch 5/100, Train Loss: 1.4320, Train Accuracy: 0.3896, Test Loss: 1.4403, Test Accuracy: 0.3931
# Epoch 6/100, Train Loss: 1.4236, Train Accuracy: 0.3959, Test Loss: 1.4016, Test Accuracy: 0.3982
# Epoch 7/100, Train Loss: 1.4200, Train Accuracy: 0.3951, Test Loss: 1.4003, Test Accuracy: 0.4059
# Epoch 8/100, Train Loss: 1.4121, Train Accuracy: 0.4010, Test Loss: 1.5050, Test Accuracy: 0.3669
# Epoch 9/100, Train Loss: 1.4032, Train Accuracy: 0.4063, Test Loss: 1.3864, Test Accuracy: 0.4125
# Epoch 10/100, Train Loss: 1.3979, Train Accuracy: 0.4104, Test Loss: 1.3658, Test Accuracy: 0.4257
# Epoch 11/100, Train Loss: 1.3901, Train Accuracy: 0.4117, Test Loss: 1.3651, Test Accuracy: 0.4222
# Epoch 12/100, Train Loss: 1.3835, Train Accuracy: 0.4194, Test Loss: 1.3746, Test Accuracy: 0.4239
# Epoch 13/100, Train Loss: 1.3807, Train Accuracy: 0.4208, Test Loss: 1.4159, Test Accuracy: 0.4087
# Epoch 14/100, Train Loss: 1.3731, Train Accuracy: 0.4258, Test Loss: 1.3617, Test Accuracy: 0.4364
# Epoch 15/100, Train Loss: 1.3753, Train Accuracy: 0.4195, Test Loss: 1.3363, Test Accuracy: 0.4464
# Epoch 16/100, Train Loss: 1.3641, Train Accuracy: 0.4267, Test Loss: 1.3272, Test Accuracy: 0.4471
# Epoch 17/100, Train Loss: 1.3586, Train Accuracy: 0.4294, Test Loss: 1.4669, Test Accuracy: 0.3931
# Epoch 18/100, Train Loss: 1.3590, Train Accuracy: 0.4272, Test Loss: 1.4011, Test Accuracy: 0.4211
# Epoch 19/100, Train Loss: 1.3543, Train Accuracy: 0.4308, Test Loss: 1.5185, Test Accuracy: 0.3534
# Epoch 20/100, Train Loss: 1.3499, Train Accuracy: 0.4349, Test Loss: 1.4086, Test Accuracy: 0.4288
# Epoch 21/100, Train Loss: 1.3480, Train Accuracy: 0.4396, Test Loss: 1.4852, Test Accuracy: 0.3676
# Epoch 22/100, Train Loss: 1.3376, Train Accuracy: 0.4421, Test Loss: 1.4061, Test Accuracy: 0.4275
# Epoch 23/100, Train Loss: 1.3354, Train Accuracy: 0.4407, Test Loss: 1.3149, Test Accuracy: 0.4479
# Epoch 24/100, Train Loss: 1.3282, Train Accuracy: 0.4487, Test Loss: 1.3028, Test Accuracy: 0.4576
# Epoch 25/100, Train Loss: 1.3331, Train Accuracy: 0.4425, Test Loss: 1.3400, Test Accuracy: 0.4377
# Epoch 26/100, Train Loss: 1.3230, Train Accuracy: 0.4525, Test Loss: 1.4830, Test Accuracy: 0.3783
# Epoch 27/100, Train Loss: 1.3217, Train Accuracy: 0.4501, Test Loss: 1.3008, Test Accuracy: 0.4718
# Epoch 28/100, Train Loss: 1.3185, Train Accuracy: 0.4503, Test Loss: 1.2836, Test Accuracy: 0.4614
# Epoch 29/100, Train Loss: 1.3178, Train Accuracy: 0.4543, Test Loss: 1.2878, Test Accuracy: 0.4678
# Epoch 30/100, Train Loss: 1.3122, Train Accuracy: 0.4519, Test Loss: 1.5270, Test Accuracy: 0.3004
# Epoch 31/100, Train Loss: 1.3122, Train Accuracy: 0.4507, Test Loss: 1.2963, Test Accuracy: 0.4701
# Epoch 32/100, Train Loss: 1.3115, Train Accuracy: 0.4524, Test Loss: 1.3530, Test Accuracy: 0.4487
# Epoch 33/100, Train Loss: 1.3057, Train Accuracy: 0.4559, Test Loss: 1.3039, Test Accuracy: 0.4627
# Epoch 34/100, Train Loss: 1.3043, Train Accuracy: 0.4595, Test Loss: 1.2706, Test Accuracy: 0.4757
# Epoch 35/100, Train Loss: 1.3012, Train Accuracy: 0.4609, Test Loss: 1.3514, Test Accuracy: 0.4448
# Epoch 36/100, Train Loss: 1.2986, Train Accuracy: 0.4661, Test Loss: 1.2839, Test Accuracy: 0.4701
# Epoch 37/100, Train Loss: 1.3019, Train Accuracy: 0.4567, Test Loss: 1.2662, Test Accuracy: 0.4754
# Epoch 38/100, Train Loss: 1.2933, Train Accuracy: 0.4598, Test Loss: 1.2644, Test Accuracy: 0.4772
# Epoch 39/100, Train Loss: 1.2918, Train Accuracy: 0.4682, Test Loss: 1.5630, Test Accuracy: 0.2800
# Epoch 40/100, Train Loss: 1.2940, Train Accuracy: 0.4654, Test Loss: 1.2596, Test Accuracy: 0.4775
# Epoch 41/100, Train Loss: 1.2886, Train Accuracy: 0.4650, Test Loss: 1.2610, Test Accuracy: 0.4782
# Epoch 42/100, Train Loss: 1.2898, Train Accuracy: 0.4685, Test Loss: 1.5924, Test Accuracy: 0.2882
# Epoch 43/100, Train Loss: 1.2915, Train Accuracy: 0.4672, Test Loss: 1.2509, Test Accuracy: 0.4854
# Epoch 44/100, Train Loss: 1.2786, Train Accuracy: 0.4735, Test Loss: 1.2642, Test Accuracy: 0.4762
# Epoch 45/100, Train Loss: 1.2792, Train Accuracy: 0.4734, Test Loss: 1.2456, Test Accuracy: 0.4854
# Epoch 46/100, Train Loss: 1.2778, Train Accuracy: 0.4738, Test Loss: 1.3998, Test Accuracy: 0.4245
# Epoch 47/100, Train Loss: 1.2759, Train Accuracy: 0.4740, Test Loss: 1.2425, Test Accuracy: 0.4874
# Epoch 48/100, Train Loss: 1.2702, Train Accuracy: 0.4763, Test Loss: 1.2598, Test Accuracy: 0.4797
# Epoch 49/100, Train Loss: 1.2715, Train Accuracy: 0.4781, Test Loss: 1.3426, Test Accuracy: 0.4571
# Epoch 50/100, Train Loss: 1.2722, Train Accuracy: 0.4758, Test Loss: 1.2846, Test Accuracy: 0.4713
# Epoch 51/100, Train Loss: 1.2665, Train Accuracy: 0.4832, Test Loss: 1.4491, Test Accuracy: 0.3878
# Epoch 52/100, Train Loss: 1.2744, Train Accuracy: 0.4745, Test Loss: 1.2459, Test Accuracy: 0.4927
# Epoch 53/100, Train Loss: 1.2649, Train Accuracy: 0.4807, Test Loss: 1.2398, Test Accuracy: 0.4859
# Epoch 54/100, Train Loss: 1.2641, Train Accuracy: 0.4829, Test Loss: 1.3096, Test Accuracy: 0.4660
# Epoch 55/100, Train Loss: 1.2662, Train Accuracy: 0.4767, Test Loss: 1.2263, Test Accuracy: 0.5027
# Epoch 56/100, Train Loss: 1.2636, Train Accuracy: 0.4823, Test Loss: 1.2391, Test Accuracy: 0.4846
# Epoch 57/100, Train Loss: 1.2640, Train Accuracy: 0.4789, Test Loss: 1.2279, Test Accuracy: 0.4950
# Epoch 58/100, Train Loss: 1.2602, Train Accuracy: 0.4837, Test Loss: 1.2528, Test Accuracy: 0.4831
# Epoch 59/100, Train Loss: 1.2607, Train Accuracy: 0.4827, Test Loss: 1.2931, Test Accuracy: 0.4662
# Epoch 60/100, Train Loss: 1.2591, Train Accuracy: 0.4789, Test Loss: 1.2353, Test Accuracy: 0.4986
# Epoch 61/100, Train Loss: 1.2449, Train Accuracy: 0.4896, Test Loss: 1.4741, Test Accuracy: 0.3941
# Epoch 62/100, Train Loss: 1.2572, Train Accuracy: 0.4891, Test Loss: 1.2224, Test Accuracy: 0.4955
# Epoch 63/100, Train Loss: 1.2488, Train Accuracy: 0.4912, Test Loss: 1.4456, Test Accuracy: 0.3985
# Epoch 64/100, Train Loss: 1.2535, Train Accuracy: 0.4884, Test Loss: 1.2161, Test Accuracy: 0.4989
# Epoch 65/100, Train Loss: 1.2412, Train Accuracy: 0.4955, Test Loss: 1.2123, Test Accuracy: 0.5047
# Epoch 66/100, Train Loss: 1.2481, Train Accuracy: 0.4886, Test Loss: 1.2253, Test Accuracy: 0.4955
# Epoch 67/100, Train Loss: 1.2463, Train Accuracy: 0.4904, Test Loss: 1.2871, Test Accuracy: 0.4785
# Epoch 68/100, Train Loss: 1.2477, Train Accuracy: 0.4914, Test Loss: 1.4009, Test Accuracy: 0.4229
# Epoch 69/100, Train Loss: 1.2440, Train Accuracy: 0.4895, Test Loss: 1.2457, Test Accuracy: 0.4871
# Epoch 70/100, Train Loss: 1.2430, Train Accuracy: 0.4951, Test Loss: 1.2633, Test Accuracy: 0.4869
# Epoch 71/100, Train Loss: 1.2530, Train Accuracy: 0.4845, Test Loss: 1.2329, Test Accuracy: 0.4981
# Epoch 72/100, Train Loss: 1.2414, Train Accuracy: 0.4884, Test Loss: 1.3408, Test Accuracy: 0.4492
# Epoch 73/100, Train Loss: 1.2403, Train Accuracy: 0.4951, Test Loss: 1.2455, Test Accuracy: 0.4966
# Epoch 74/100, Train Loss: 1.2338, Train Accuracy: 0.4979, Test Loss: 1.3998, Test Accuracy: 0.4183
# Epoch 75/100, Train Loss: 1.2432, Train Accuracy: 0.4926, Test Loss: 1.2518, Test Accuracy: 0.4874
# Epoch 76/100, Train Loss: 1.2329, Train Accuracy: 0.4972, Test Loss: 1.2197, Test Accuracy: 0.5055
# Epoch 77/100, Train Loss: 1.2358, Train Accuracy: 0.4937, Test Loss: 1.2859, Test Accuracy: 0.4744
# Epoch 78/100, Train Loss: 1.2400, Train Accuracy: 0.4887, Test Loss: 1.2125, Test Accuracy: 0.5103
# Epoch 79/100, Train Loss: 1.2427, Train Accuracy: 0.4965, Test Loss: 1.2116, Test Accuracy: 0.5083
# Epoch 80/100, Train Loss: 1.2416, Train Accuracy: 0.4936, Test Loss: 1.2142, Test Accuracy: 0.5101
# Epoch 81/100, Train Loss: 1.2313, Train Accuracy: 0.4975, Test Loss: 1.2151, Test Accuracy: 0.4950
# Epoch 82/100, Train Loss: 1.2321, Train Accuracy: 0.4968, Test Loss: 1.2789, Test Accuracy: 0.4775
# Epoch 83/100, Train Loss: 1.2377, Train Accuracy: 0.4895, Test Loss: 1.2162, Test Accuracy: 0.5017
# Epoch 84/100, Train Loss: 1.2297, Train Accuracy: 0.4954, Test Loss: 1.4156, Test Accuracy: 0.4107
# Epoch 85/100, Train Loss: 1.2278, Train Accuracy: 0.4986, Test Loss: 1.2397, Test Accuracy: 0.4986
# Epoch 86/100, Train Loss: 1.2245, Train Accuracy: 0.4980, Test Loss: 1.1977, Test Accuracy: 0.5149
# Epoch 87/100, Train Loss: 1.2222, Train Accuracy: 0.4995, Test Loss: 1.2016, Test Accuracy: 0.5144
# Epoch 88/100, Train Loss: 1.2263, Train Accuracy: 0.5007, Test Loss: 1.1909, Test Accuracy: 0.5169
# Epoch 89/100, Train Loss: 1.2301, Train Accuracy: 0.4965, Test Loss: 1.2897, Test Accuracy: 0.4683
# Epoch 90/100, Train Loss: 1.2310, Train Accuracy: 0.4937, Test Loss: 1.2206, Test Accuracy: 0.5062
# Epoch 91/100, Train Loss: 1.2258, Train Accuracy: 0.5004, Test Loss: 1.2183, Test Accuracy: 0.5037
# Epoch 92/100, Train Loss: 1.2215, Train Accuracy: 0.4998, Test Loss: 1.5682, Test Accuracy: 0.2764
# Epoch 93/100, Train Loss: 1.2244, Train Accuracy: 0.5022, Test Loss: 1.3052, Test Accuracy: 0.4764
# Epoch 94/100, Train Loss: 1.2235, Train Accuracy: 0.4987, Test Loss: 1.4182, Test Accuracy: 0.4084
# Epoch 95/100, Train Loss: 1.2297, Train Accuracy: 0.4964, Test Loss: 1.5692, Test Accuracy: 0.3024
# Epoch 96/100, Train Loss: 1.2212, Train Accuracy: 0.5026, Test Loss: 1.1928, Test Accuracy: 0.5182
# Epoch 97/100, Train Loss: 1.2201, Train Accuracy: 0.5033, Test Loss: 1.1952, Test Accuracy: 0.5154
# Epoch 98/100, Train Loss: 1.2196, Train Accuracy: 0.5040, Test Loss: 1.2425, Test Accuracy: 0.4961
# Epoch 99/100, Train Loss: 1.2222, Train Accuracy: 0.5015, Test Loss: 1.1956, Test Accuracy: 0.5141
# Epoch 100/100, Train Loss: 1.2227, Train Accuracy: 0.4984, Test Loss: 1.4709, Test Accuracy: 0.3924
