# %% [markdown]
# > UCI-HAR와 자이로 데이터 간의 차이를 줄이고, 자이로 데이터에 적합한 행동 라벨링을 추가

# %% [markdown]
# ## 1. 라이브러리 및 데이터셋 로드

# %%
# 1. 라이브러리 및 데이터셋 로드
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, f1_score
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from scipy.fft import fft
from scipy.signal import butter, filtfilt, resample

# GPU 사용 여부 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# GPU 사용 여부 확인
if torch.cuda.is_available():
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available.")
# Out:
# GPU is available: NVIDIA GeForce GTX 1650

# %% [markdown]
# ### 1. 저역통과 필터 및 데이터 전처리 함수 ###

# %%
# 저역통과 필터 적용
def butter_lowpass(cutoff, fs, order=4):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def apply_lowpass_filter(data, cutoff, fs):
    b, a = butter_lowpass(cutoff, fs)
    return filtfilt(b, a, data, axis=0)

# 데이터 정규화 및 차원 맞춤 함수
def normalize_and_reshape_segments(segments):
    scaler = MinMaxScaler()
    normalized_segments = np.zeros_like(segments)
    for axis in range(segments.shape[2]):
        normalized_segments[:, :, axis] = scaler.fit_transform(segments[:, :, axis])
    return normalized_segments

# 슬라이딩 윈도우 생성 함수
def create_sliding_windows(data, window_size=128, stride=64):
    num_windows = (len(data) - window_size) // stride + 1
    windows = np.array([data[i:i+window_size] for i in range(0, len(data) - window_size + 1, stride)])
    return windows  # (num_windows, window_size, 3) 형태로 반환

# %% [markdown]
# ### 2. UCI-HAR 데이터 로드 및 자이로 데이터 전처리 ###

# %%
# UCI-HAR 데이터 로드
def load_ucihar_data():
    uci_har_path = './원본 데이터/UCI HAR Dataset/'
    gyro_x_train = pd.read_csv(uci_har_path + 'train/Inertial Signals/body_gyro_x_train.txt', sep='\s+', header=None).values
    gyro_y_train = pd.read_csv(uci_har_path + 'train/Inertial Signals/body_gyro_y_train.txt', sep='\s+', header=None).values
    gyro_z_train = pd.read_csv(uci_har_path + 'train/Inertial Signals/body_gyro_z_train.txt', sep='\s+', header=None).values
    labels_train = pd.read_csv(uci_har_path + 'train/y_train.txt', sep='\s+', header=None).values - 1
    X_train = np.stack([gyro_x_train, gyro_y_train, gyro_z_train], axis=-1)
    X_train_normalized = normalize_and_reshape_segments(X_train)
    return X_train_normalized, labels_train

X_train, y_train = load_ucihar_data()

# 자이로 데이터 전처리 함수
def preprocess_gyro_data(gyro_path, current_freq=100, cutoff=20, desired_freq=50, window_size=128, stride=64):
    gyro_data = pd.read_csv(gyro_path)
    n_samples = int(len(gyro_data) * desired_freq / current_freq)
    gyro_data_resampled = resample(gyro_data[['X', 'Y', 'Z']].values, n_samples)
    gyro_data_filtered = apply_lowpass_filter(gyro_data_resampled, cutoff, fs=desired_freq)
    gyro_data_windows = create_sliding_windows(gyro_data_filtered, window_size, stride)
    gyro_data_normalized = normalize_and_reshape_segments(gyro_data_windows)
    return torch.tensor(gyro_data_normalized, dtype=torch.float32)

gyro_data_tensor = preprocess_gyro_data('./원본 데이터/자이로 데이터.csv')

# 데이터를 Tensor로 변환
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
gyro_data_tensor = gyro_data_tensor.to(device)

# %% [markdown]
# ### 3. 데이터 증강 ###

# %%
# 데이터 증강 함수: 가우시안 노이즈 추가
def add_gaussian_noise(data, noise_factor=0.05):
    noise = np.random.randn(*data.shape)
    augmented_data = data + noise_factor * noise
    augmented_data = np.clip(augmented_data, -1.0, 1.0)
    return augmented_data

def time_warp(data, sigma=0.2, knot=4):
    orig_steps = np.arange(data.shape[1])
    random_warps = np.random.normal(loc=1.0, scale=sigma, size=(data.shape[0], knot+2, data.shape[2]))
    warp_steps = (np.ones((data.shape[2],1))*(np.linspace(0, data.shape[1]-1., num=knot+2))).T
    ret = np.zeros_like(data)
    for i, pat in enumerate(data):
        warper = np.interp(orig_steps, warp_steps[:, 0], random_warps[i, :, 0])
        for dim in range(data.shape[2]):
            ret[i, :, dim] = np.interp(orig_steps, np.cumsum(warper), pat[:, dim])
    return ret

# 증강된 데이터 결합 및 불균형 데이터 해결
X_train_augmented = add_gaussian_noise(X_train)

# 증강된 데이터 결합
X_train_augmented = np.concatenate([
    X_train,
    add_gaussian_noise(X_train),
    time_warp(X_train)
], axis=0)

y_train_augmented = np.concatenate([y_train] * 3, axis=0)

# 클래스별 샘플 수 계산
class_sample_count = np.array([len(np.where(y_train_augmented == t)[0]) for t in np.unique(y_train_augmented)])

# 길이 확인 및 조정
min_length = min(len(X_train_augmented), len(y_train_augmented))
X_train_augmented = X_train_augmented[:min_length]
y_train_augmented = y_train_augmented[:min_length]

# 텐서로 변환
X_train_augmented_tensor = torch.tensor(X_train_augmented, dtype=torch.float32)
y_train_augmented_tensor = torch.tensor(y_train_augmented, dtype=torch.long)

# 학습/검증 데이터 분리
X_train_tensor, X_val_tensor, y_train_tensor, y_val_tensor = train_test_split(
    X_train_augmented_tensor, 
    y_train_augmented_tensor, 
    test_size=0.2,
    random_state=42,
)

# %% [markdown]
# ### 4. 데이터셋 및 모델 정의 ###

# %%
# 데이터셋 클래스
class UCIHARData(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx].view(-1)
    
train_dataset = UCIHARData(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = UCIHARData(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## 5. LSTM, GRU, CNN-LSTM, BiLSTM, Transformer 모델 정의 및 성능 개선(앙상블)

# %%
# LSTM 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(LSTMModel, self).__init__()
        self.input_size = input_size  # 추가
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.batch_norm = nn.BatchNorm1d(hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.batch_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out

# GRU 모델 정의
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(GRUModel, self).__init__()
        self.input_size = input_size  # 추가
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.batch_norm = nn.BatchNorm1d(hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.batch_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out

# CNN-LSTM 모델 정의
class CNNLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(CNNLSTMModel, self).__init__()
        self.input_size = input_size  # 추가
        self.conv1 = nn.Conv1d(input_size, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.lstm = nn.LSTM(64, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.pool(F.relu(self.conv1(x)))
        x = x.permute(0, 2, 1)
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# BiLSTM 모델 정의
class BiLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(BiLSTMModel, self).__init__()
        self.input_size = input_size  # 추가
        self.bilstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob, bidirectional=True)
        self.batch_norm = nn.BatchNorm1d(hidden_size * 2)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        out, _ = self.bilstm(x)
        out = self.batch_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out

# Transformer 모델 정의
class TransformerModel(nn.Module):
    def __init__(self, input_size, num_heads, num_layers, num_classes, dropout_prob):
        super(TransformerModel, self).__init__()
        self.input_size = input_size  # 추가
        self.input_embedding = nn.Linear(input_size, 128)
        self.positional_encoding = nn.Parameter(torch.randn(1, 180, 128))
        encoder_layer = nn.TransformerEncoderLayer(d_model=128, nhead=num_heads, dropout=dropout_prob)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        # x: (batch_size, seq_len, input_size) -> (seq_len, batch_size, input_size)
        x = self.input_embedding(x)
        x = x + self.positional_encoding[:, :x.size(1), :]
        x = self.transformer(x.permute(1, 0, 2))  # (seq_len, batch_size, d_model)
        out = self.fc(x[-1, :, :])  # 마지막 타임스텝의 출력만 사용
        return out

# %% [markdown]
# ## 6. 앙상블 모델 정의

# %%
# 입력 크기 정의
input_size = 3  # X, Y, Z 축

# 모델 정의
models = [
    LSTMModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    GRUModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    CNNLSTMModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    BiLSTMModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    TransformerModel(input_size=input_size, num_heads=4, num_layers=2, num_classes=6, dropout_prob=0.5).to(device)
]

# 입력 크기 확인
print(f"Input size: {input_size}")
for i, model in enumerate(models):
    print(f"Model {i+1} input size: {model.input_size if hasattr(model, 'input_size') else 'N/A'}")

# 모델들의 예측값을 앙상블로 처리
# 앙상블 예측 함수
def ensemble_predict(models, X_unlabeled, weights=[1, 1, 1, 1, 1]):
    predictions = []
    X_unlabeled = X_unlabeled.to(device)
    for i, model in enumerate(models):
        model.eval()
        with torch.no_grad():
            outputs = model(X_unlabeled)
            predictions.append(weights[i] * torch.softmax(outputs, dim=1))
    
    final_predictions = torch.argmax(sum(predictions), dim=1)
    return final_predictions
# Out:
# Input size: 3
# Model 1 input size: 3
# Model 2 input size: 3
# Model 3 input size: 3
# Model 4 input size: 3
# Model 5 input size: 3
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\torch\nn\modules\transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# ## 7. 손실 함수, 옵티마이저, 스케줄러 및 모델 학습

# %%
# 클래스별 가중치 계산
class_weights = 1.0 / torch.tensor(class_sample_count, dtype=torch.float32)
class_weights = class_weights.to(device)

# 손실 함수 정의 (가중치 적용)
criterion = nn.CrossEntropyLoss(weight=class_weights)

# 각 모델별로 옵티마이저와 스케줄러 정의
optimizers = [
    torch.optim.Adam(model.parameters(), lr=0.000001, weight_decay=1e-4) for model in models
]

schedulers = [
    torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=0.0001) for optimizer in optimizers
]

# 모델 저장 함수
def save_checkpoint(epoch, model, optimizer, filename="checkpoint.pth.tar"):
    state = {'epoch': epoch, 'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()}
    torch.save(state, filename)

best_val_accuracy = 0.0

# 모델 학습 함수
def train_model(models, train_loader, val_loader, criterion, optimizers, schedulers, num_epochs, patience):
    global best_val_accuracy
    early_stop_counter = 0
    
    for epoch in range(num_epochs):
        for model in models:
            model.train()
        
        running_loss = [0.0] * len(models)
        correct = [0] * len(models)
        total = 0
        
        # Training loop
        for i, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.to(device)
           # 수정 코드
            labels = labels.to(device).squeeze()  # 1D로 변환
            total += labels.size(0)

            # 각 모델별 학습
            for j, model in enumerate(models):
                optimizers[j].zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # 그래디언트 클리핑 추가
                optimizers[j].step()
                
                running_loss[j] += loss.item()
                _, predicted = torch.max(outputs, 1)
                correct[j] += (predicted.cpu() == labels.cpu()).sum().item()

        # Training accuracy and loss
        for j, model in enumerate(models):
            accuracy = 100 * correct[j] / total
            print(f"Epoch [{epoch+1}/{num_epochs}], Model {j+1} Training Loss: {running_loss[j]/len(train_loader):.4f}, Training Accuracy: {accuracy:.2f}%")
        
        # Validation loop
        for model in models:
            model.eval()
        
        val_loss = [0.0] * len(models)
        val_correct = [0] * len(models)
        val_total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                # 수정 코드
                labels = labels.to(device).squeeze()
                val_total += labels.size(0)

                for j, model in enumerate(models):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    val_loss[j] += loss.item()

                    _, predicted = torch.max(outputs, 1)
                    val_correct[j] += (predicted.cpu() == labels.cpu()).sum().item()

        # Validation accuracy and loss
        for j, model in enumerate(models):
            val_accuracy = (val_correct[j] / val_total) * 100
            val_loss[j] = val_loss[j] / len(val_loader)

            print(f"Model {j+1} Validation Accuracy: {val_accuracy:.2f}%, Validation Loss: {val_loss[j]:.4f}")

            # 스케줄러 갱신
            schedulers[j].step()

            # Save best model
            if val_accuracy > best_val_accuracy:
                best_val_accuracy = val_accuracy
                save_checkpoint(epoch, model, optimizers[j], filename=f"best_model_{j+1}.pth.tar")
                print(f"Best model {j+1} saved with accuracy: {best_val_accuracy:.2f}%")
                early_stop_counter = 0
            else:
                early_stop_counter += 1

        # Early stopping
        if early_stop_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

        torch.cuda.empty_cache()

# 모델 학습 실행
train_model(models, train_loader, val_loader, criterion, optimizers, schedulers, num_epochs=1000, patience=200)
# Out:
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\torch\nn\functional.py:5560: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch [1/500], Model 1 Training Loss: 2.0100, Training Accuracy: 16.56%
# Epoch [1/500], Model 2 Training Loss: 2.0276, Training Accuracy: 17.05%
# Epoch [1/500], Model 3 Training Loss: 1.7931, Training Accuracy: 19.02%
# Epoch [1/500], Model 4 Training Loss: 2.0442, Training Accuracy: 16.37%
# Epoch [1/500], Model 5 Training Loss: 1.8381, Training Accuracy: 16.93%
# Model 1 Validation Accuracy: 22.67%, Validation Loss: 1.7936
# Best model 1 saved with accuracy: 22.67%
# Model 2 Validation Accuracy: 22.05%, Validation Loss: 1.7933
# Model 3 Validation Accuracy: 19.61%, Validation Loss: 1.7923
# Model 4 Validation Accuracy: 21.17%, Validation Loss: 1.7930
# Model 5 Validation Accuracy: 12.69%, Validation Loss: 1.7958
# Epoch [2/500], Model 1 Training Loss: 2.0005, Training Accuracy: 16.56%
# Epoch [2/500], Model 2 Training Loss: 2.0467, Training Accuracy: 16.46%
# Epoch [2/500], Model 3 Training Loss: 1.7929, Training Accuracy: 19.02%
# Epoch [2/500], Model 4 Training Loss: 2.0334, Training Accuracy: 16.91%
# Epoch [2/500], Model 5 Training Loss: 1.8249, Training Accuracy: 16.40%
# Model 1 Validation Accuracy: 14.60%, Validation Loss: 1.7928
# Model 2 Validation Accuracy: 22.30%, Validation Loss: 1.7932
# Model 3 Validation Accuracy: 19.61%, Validation Loss: 1.7921
# Model 4 Validation Accuracy: 20.35%, Validation Loss: 1.7929
# Model 5 Validation Accuracy: 20.99%, Validation Loss: 1.7929
# Epoch [3/500], Model 1 Training Loss: 1.9779, Training Accuracy: 16.65%
# Epoch [3/500], Model 2 Training Loss: 2.0076, Training Accuracy: 16.92%
# Epoch [3/500], Model 3 Training Loss: 1.7925, Training Accuracy: 19.02%
# Epoch [3/500], Model 4 Training Loss: 2.0080, Training Accuracy: 17.05%
# Epoch [3/500], Model 5 Training Loss: 1.8211, Training Accuracy: 17.16%
# Model 1 Validation Accuracy: 14.23%, Validation Loss: 1.7933
# Model 2 Validation Accuracy: 19.95%, Validation Loss: 1.7932
# Model 3 Validation Accuracy: 19.61%, Validation Loss: 1.7918
# Model 4 Validation Accuracy: 19.54%, Validation Loss: 1.7936
# Model 5 Validation Accuracy: 13.03%, Validation Loss: 1.7919
# Epoch [4/500], Model 1 Training Loss: 1.9500, Training Accuracy: 16.29%
# Epoch [4/500], Model 2 Training Loss: 1.9852, Training Accuracy: 16.22%
# Epoch [4/500], Model 3 Training Loss: 1.7920, Training Accuracy: 18.56%
# Epoch [4/500], Model 4 Training Loss: 1.9896, Training Accuracy: 16.83%
# Epoch [4/500], Model 5 Training Loss: 1.8179, Training Accuracy: 16.84%
# Model 1 Validation Accuracy: 14.71%, Validation Loss: 1.7934
# Model 2 Validation Accuracy: 19.63%, Validation Loss: 1.7939
# Model 3 Validation Accuracy: 19.61%, Validation Loss: 1.7916
# Model 4 Validation Accuracy: 20.31%, Validation Loss: 1.7925
# Model 5 Validation Accuracy: 22.10%, Validation Loss: 1.7956
# Epoch [5/500], Model 1 Training Loss: 1.9177, Training Accuracy: 16.45%
# Epoch [5/500], Model 2 Training Loss: 1.9484, Training Accuracy: 16.74%
# Epoch [5/500], Model 3 Training Loss: 1.7917, Training Accuracy: 18.77%
# Epoch [5/500], Model 4 Training Loss: 1.9568, Training Accuracy: 16.40%
# Epoch [5/500], Model 5 Training Loss: 1.8145, Training Accuracy: 16.99%
# Model 1 Validation Accuracy: 14.35%, Validation Loss: 1.7924
# Model 2 Validation Accuracy: 21.53%, Validation Loss: 1.7923
# Model 3 Validation Accuracy: 16.07%, Validation Loss: 1.7915
# Model 4 Validation Accuracy: 20.22%, Validation Loss: 1.7926
# Model 5 Validation Accuracy: 13.98%, Validation Loss: 1.8001
# Epoch [6/500], Model 1 Training Loss: 1.8831, Training Accuracy: 16.71%
# Epoch [6/500], Model 2 Training Loss: 1.9143, Training Accuracy: 16.44%
# Epoch [6/500], Model 3 Training Loss: 1.6320, Training Accuracy: 23.08%
# Epoch [6/500], Model 4 Training Loss: 1.9176, Training Accuracy: 16.86%
# Epoch [6/500], Model 5 Training Loss: 1.8106, Training Accuracy: 16.89%
# Model 1 Validation Accuracy: 14.42%, Validation Loss: 1.7920
# Model 2 Validation Accuracy: 20.24%, Validation Loss: 1.7922
# Model 3 Validation Accuracy: 28.83%, Validation Loss: 1.5057
# Best model 3 saved with accuracy: 28.83%
# Model 4 Validation Accuracy: 22.23%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 14.96%, Validation Loss: 1.7931
# Epoch [7/500], Model 1 Training Loss: 1.8538, Training Accuracy: 16.96%
# Epoch [7/500], Model 2 Training Loss: 1.8888, Training Accuracy: 16.19%
# Epoch [7/500], Model 3 Training Loss: 1.2961, Training Accuracy: 30.79%
# Epoch [7/500], Model 4 Training Loss: 1.8912, Training Accuracy: 16.54%
# Epoch [7/500], Model 5 Training Loss: 1.8082, Training Accuracy: 16.82%
# Model 1 Validation Accuracy: 16.50%, Validation Loss: 1.7923
# Model 2 Validation Accuracy: 20.10%, Validation Loss: 1.7923
# Model 3 Validation Accuracy: 32.16%, Validation Loss: 1.1867
# Best model 3 saved with accuracy: 32.16%
# Model 4 Validation Accuracy: 23.75%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 19.61%, Validation Loss: 1.7953
# Epoch [8/500], Model 1 Training Loss: 1.8340, Training Accuracy: 16.55%
# Epoch [8/500], Model 2 Training Loss: 1.8687, Training Accuracy: 16.79%
# Epoch [8/500], Model 3 Training Loss: 1.2077, Training Accuracy: 33.01%
# Epoch [8/500], Model 4 Training Loss: 1.8605, Training Accuracy: 16.70%
# Epoch [8/500], Model 5 Training Loss: 1.8067, Training Accuracy: 16.57%
# Model 1 Validation Accuracy: 16.09%, Validation Loss: 1.7915
# Model 2 Validation Accuracy: 20.19%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 35.65%, Validation Loss: 1.1353
# Best model 3 saved with accuracy: 35.65%
# Model 4 Validation Accuracy: 24.41%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 12.40%, Validation Loss: 1.7918
# Epoch [9/500], Model 1 Training Loss: 1.8193, Training Accuracy: 16.71%
# Epoch [9/500], Model 2 Training Loss: 1.8568, Training Accuracy: 16.89%
# Epoch [9/500], Model 3 Training Loss: 1.1843, Training Accuracy: 36.89%
# Epoch [9/500], Model 4 Training Loss: 1.8498, Training Accuracy: 16.54%
# Epoch [9/500], Model 5 Training Loss: 1.8025, Training Accuracy: 16.87%
# Model 1 Validation Accuracy: 15.66%, Validation Loss: 1.7921
# Model 2 Validation Accuracy: 21.31%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 36.13%, Validation Loss: 1.1754
# Best model 3 saved with accuracy: 36.13%
# Model 4 Validation Accuracy: 16.75%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 24.00%, Validation Loss: 1.7906
# Epoch [10/500], Model 1 Training Loss: 1.8101, Training Accuracy: 16.80%
# Epoch [10/500], Model 2 Training Loss: 1.8451, Training Accuracy: 16.48%
# Epoch [10/500], Model 3 Training Loss: 1.1612, Training Accuracy: 37.13%
# Epoch [10/500], Model 4 Training Loss: 1.8303, Training Accuracy: 16.58%
# Epoch [10/500], Model 5 Training Loss: 1.8009, Training Accuracy: 16.82%
# Model 1 Validation Accuracy: 24.09%, Validation Loss: 1.7919
# Model 2 Validation Accuracy: 19.92%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 38.92%, Validation Loss: 1.1049
# Best model 3 saved with accuracy: 38.92%
# Model 4 Validation Accuracy: 24.25%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 14.37%, Validation Loss: 1.7896
# Epoch [11/500], Model 1 Training Loss: 1.8048, Training Accuracy: 16.31%
# Epoch [11/500], Model 2 Training Loss: 1.8305, Training Accuracy: 17.09%
# Epoch [11/500], Model 3 Training Loss: 1.1510, Training Accuracy: 37.36%
# Epoch [11/500], Model 4 Training Loss: 1.8203, Training Accuracy: 16.51%
# Epoch [11/500], Model 5 Training Loss: 1.5836, Training Accuracy: 27.22%
# Model 1 Validation Accuracy: 25.50%, Validation Loss: 1.7909
# Model 2 Validation Accuracy: 23.48%, Validation Loss: 1.7913
# Model 3 Validation Accuracy: 29.47%, Validation Loss: 1.4805
# Model 4 Validation Accuracy: 23.50%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 34.16%, Validation Loss: 1.3226
# Epoch [12/500], Model 1 Training Loss: 1.7994, Training Accuracy: 17.39%
# Epoch [12/500], Model 2 Training Loss: 1.8258, Training Accuracy: 16.23%
# Epoch [12/500], Model 3 Training Loss: 1.1345, Training Accuracy: 37.98%
# Epoch [12/500], Model 4 Training Loss: 1.8100, Training Accuracy: 17.01%
# Epoch [12/500], Model 5 Training Loss: 1.3423, Training Accuracy: 33.92%
# Model 1 Validation Accuracy: 25.95%, Validation Loss: 1.7909
# Model 2 Validation Accuracy: 21.26%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 38.03%, Validation Loss: 1.2010
# Model 4 Validation Accuracy: 21.03%, Validation Loss: 1.7912
# Model 5 Validation Accuracy: 36.38%, Validation Loss: 1.2747
# Epoch [13/500], Model 1 Training Loss: 1.7988, Training Accuracy: 17.33%
# Epoch [13/500], Model 2 Training Loss: 1.8163, Training Accuracy: 17.14%
# Epoch [13/500], Model 3 Training Loss: 1.1183, Training Accuracy: 39.75%
# Epoch [13/500], Model 4 Training Loss: 1.8057, Training Accuracy: 17.66%
# Epoch [13/500], Model 5 Training Loss: 1.2666, Training Accuracy: 34.96%
# Model 1 Validation Accuracy: 15.12%, Validation Loss: 1.7914
# Model 2 Validation Accuracy: 23.16%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 40.48%, Validation Loss: 1.0819
# Best model 3 saved with accuracy: 40.48%
# Model 4 Validation Accuracy: 19.15%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 39.26%, Validation Loss: 1.2023
# Epoch [14/500], Model 1 Training Loss: 1.7975, Training Accuracy: 16.95%
# Epoch [14/500], Model 2 Training Loss: 1.8120, Training Accuracy: 17.20%
# Epoch [14/500], Model 3 Training Loss: 1.1189, Training Accuracy: 39.30%
# Epoch [14/500], Model 4 Training Loss: 1.8036, Training Accuracy: 17.23%
# Epoch [14/500], Model 5 Training Loss: 1.2207, Training Accuracy: 35.94%
# Model 1 Validation Accuracy: 13.87%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 22.26%, Validation Loss: 1.7916
# Model 3 Validation Accuracy: 40.14%, Validation Loss: 1.1586
# Model 4 Validation Accuracy: 24.64%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 38.15%, Validation Loss: 1.1838
# Epoch [15/500], Model 1 Training Loss: 1.7965, Training Accuracy: 17.30%
# Epoch [15/500], Model 2 Training Loss: 1.8116, Training Accuracy: 16.58%
# Epoch [15/500], Model 3 Training Loss: 1.1134, Training Accuracy: 40.33%
# Epoch [15/500], Model 4 Training Loss: 1.8002, Training Accuracy: 17.79%
# Epoch [15/500], Model 5 Training Loss: 1.1936, Training Accuracy: 37.99%
# Model 1 Validation Accuracy: 24.14%, Validation Loss: 1.7910
# Model 2 Validation Accuracy: 24.84%, Validation Loss: 1.7916
# Model 3 Validation Accuracy: 41.98%, Validation Loss: 1.0831
# Best model 3 saved with accuracy: 41.98%
# Model 4 Validation Accuracy: 21.53%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 42.36%, Validation Loss: 1.1527
# Best model 5 saved with accuracy: 42.36%
# Epoch [16/500], Model 1 Training Loss: 1.7961, Training Accuracy: 16.84%
# Epoch [16/500], Model 2 Training Loss: 1.8099, Training Accuracy: 16.76%
# Epoch [16/500], Model 3 Training Loss: 1.0950, Training Accuracy: 40.53%
# Epoch [16/500], Model 4 Training Loss: 1.8001, Training Accuracy: 17.24%
# Epoch [16/500], Model 5 Training Loss: 1.1655, Training Accuracy: 40.05%
# Model 1 Validation Accuracy: 22.85%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 23.07%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 42.38%, Validation Loss: 1.0712
# Best model 3 saved with accuracy: 42.38%
# Model 4 Validation Accuracy: 22.23%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 42.16%, Validation Loss: 1.1329
# Epoch [17/500], Model 1 Training Loss: 1.7946, Training Accuracy: 17.68%
# Epoch [17/500], Model 2 Training Loss: 1.8066, Training Accuracy: 16.99%
# Epoch [17/500], Model 3 Training Loss: 1.0878, Training Accuracy: 40.91%
# Epoch [17/500], Model 4 Training Loss: 1.7993, Training Accuracy: 17.41%
# Epoch [17/500], Model 5 Training Loss: 1.1409, Training Accuracy: 41.97%
# Model 1 Validation Accuracy: 15.53%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 24.55%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 41.61%, Validation Loss: 1.0737
# Model 4 Validation Accuracy: 22.17%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 44.24%, Validation Loss: 1.1257
# Best model 5 saved with accuracy: 44.24%
# Epoch [18/500], Model 1 Training Loss: 1.7957, Training Accuracy: 17.12%
# Epoch [18/500], Model 2 Training Loss: 1.8062, Training Accuracy: 17.00%
# Epoch [18/500], Model 3 Training Loss: 1.0798, Training Accuracy: 41.45%
# Epoch [18/500], Model 4 Training Loss: 1.7975, Training Accuracy: 17.67%
# Epoch [18/500], Model 5 Training Loss: 1.1116, Training Accuracy: 43.00%
# Model 1 Validation Accuracy: 15.91%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.29%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 41.34%, Validation Loss: 1.0735
# Model 4 Validation Accuracy: 23.01%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 45.74%, Validation Loss: 1.0810
# Best model 5 saved with accuracy: 45.74%
# Epoch [19/500], Model 1 Training Loss: 1.7942, Training Accuracy: 17.99%
# Epoch [19/500], Model 2 Training Loss: 1.8082, Training Accuracy: 16.19%
# Epoch [19/500], Model 3 Training Loss: 1.0737, Training Accuracy: 41.96%
# Epoch [19/500], Model 4 Training Loss: 1.7981, Training Accuracy: 17.55%
# Epoch [19/500], Model 5 Training Loss: 1.0981, Training Accuracy: 43.70%
# Model 1 Validation Accuracy: 16.66%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 24.84%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 40.44%, Validation Loss: 1.0772
# Model 4 Validation Accuracy: 23.50%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 44.95%, Validation Loss: 1.0748
# Epoch [20/500], Model 1 Training Loss: 1.7930, Training Accuracy: 17.84%
# Epoch [20/500], Model 2 Training Loss: 1.8064, Training Accuracy: 17.13%
# Epoch [20/500], Model 3 Training Loss: 1.0700, Training Accuracy: 41.62%
# Epoch [20/500], Model 4 Training Loss: 1.7951, Training Accuracy: 18.24%
# Epoch [20/500], Model 5 Training Loss: 1.0879, Training Accuracy: 44.61%
# Model 1 Validation Accuracy: 16.52%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 25.36%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 42.61%, Validation Loss: 1.0696
# Model 4 Validation Accuracy: 19.42%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 46.12%, Validation Loss: 1.0667
# Best model 5 saved with accuracy: 46.12%
# Epoch [21/500], Model 1 Training Loss: 1.7932, Training Accuracy: 17.89%
# Epoch [21/500], Model 2 Training Loss: 1.8044, Training Accuracy: 16.73%
# Epoch [21/500], Model 3 Training Loss: 1.0685, Training Accuracy: 41.12%
# Epoch [21/500], Model 4 Training Loss: 1.7976, Training Accuracy: 18.08%
# Epoch [21/500], Model 5 Training Loss: 1.0849, Training Accuracy: 44.55%
# Model 1 Validation Accuracy: 17.61%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 26.45%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 41.43%, Validation Loss: 1.0660
# Model 4 Validation Accuracy: 21.58%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 46.10%, Validation Loss: 1.0650
# Epoch [22/500], Model 1 Training Loss: 1.7937, Training Accuracy: 18.06%
# Epoch [22/500], Model 2 Training Loss: 1.8063, Training Accuracy: 16.58%
# Epoch [22/500], Model 3 Training Loss: 1.0686, Training Accuracy: 41.46%
# Epoch [22/500], Model 4 Training Loss: 1.7954, Training Accuracy: 18.15%
# Epoch [22/500], Model 5 Training Loss: 1.0819, Training Accuracy: 45.27%
# Model 1 Validation Accuracy: 21.37%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.88%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 42.59%, Validation Loss: 1.0653
# Model 4 Validation Accuracy: 23.23%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 46.65%, Validation Loss: 1.0648
# Best model 5 saved with accuracy: 46.65%
# Epoch [23/500], Model 1 Training Loss: 1.7936, Training Accuracy: 17.55%
# Epoch [23/500], Model 2 Training Loss: 1.8065, Training Accuracy: 16.59%
# Epoch [23/500], Model 3 Training Loss: 1.0738, Training Accuracy: 41.73%
# Epoch [23/500], Model 4 Training Loss: 1.7982, Training Accuracy: 17.26%
# Epoch [23/500], Model 5 Training Loss: 1.0839, Training Accuracy: 44.51%
# Model 1 Validation Accuracy: 16.48%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 26.47%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 40.50%, Validation Loss: 1.0671
# Model 4 Validation Accuracy: 21.35%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 44.88%, Validation Loss: 1.0506
# Epoch [24/500], Model 1 Training Loss: 1.7941, Training Accuracy: 17.50%
# Epoch [24/500], Model 2 Training Loss: 1.8034, Training Accuracy: 17.09%
# Epoch [24/500], Model 3 Training Loss: 1.0796, Training Accuracy: 41.25%
# Epoch [24/500], Model 4 Training Loss: 1.7956, Training Accuracy: 18.32%
# Epoch [24/500], Model 5 Training Loss: 1.0750, Training Accuracy: 45.29%
# Model 1 Validation Accuracy: 15.96%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 24.98%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 41.64%, Validation Loss: 1.0791
# Model 4 Validation Accuracy: 23.23%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 45.49%, Validation Loss: 1.0371
# Epoch [25/500], Model 1 Training Loss: 1.7935, Training Accuracy: 17.64%
# Epoch [25/500], Model 2 Training Loss: 1.8044, Training Accuracy: 16.90%
# Epoch [25/500], Model 3 Training Loss: 1.0855, Training Accuracy: 41.01%
# Epoch [25/500], Model 4 Training Loss: 1.7957, Training Accuracy: 17.67%
# Epoch [25/500], Model 5 Training Loss: 1.0662, Training Accuracy: 45.51%
# Model 1 Validation Accuracy: 19.72%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 25.75%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 42.29%, Validation Loss: 1.0859
# Model 4 Validation Accuracy: 22.26%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 46.26%, Validation Loss: 1.0391
# Epoch [26/500], Model 1 Training Loss: 1.7933, Training Accuracy: 17.91%
# Epoch [26/500], Model 2 Training Loss: 1.8031, Training Accuracy: 16.52%
# Epoch [26/500], Model 3 Training Loss: 1.0905, Training Accuracy: 40.48%
# Epoch [26/500], Model 4 Training Loss: 1.7963, Training Accuracy: 17.87%
# Epoch [26/500], Model 5 Training Loss: 1.0584, Training Accuracy: 45.86%
# Model 1 Validation Accuracy: 15.73%, Validation Loss: 1.7917
# Model 2 Validation Accuracy: 25.84%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 41.66%, Validation Loss: 1.0621
# Model 4 Validation Accuracy: 24.09%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 47.39%, Validation Loss: 1.0228
# Best model 5 saved with accuracy: 47.39%
# Epoch [27/500], Model 1 Training Loss: 1.7937, Training Accuracy: 17.56%
# Epoch [27/500], Model 2 Training Loss: 1.8027, Training Accuracy: 16.43%
# Epoch [27/500], Model 3 Training Loss: 1.0970, Training Accuracy: 41.20%
# Epoch [27/500], Model 4 Training Loss: 1.7963, Training Accuracy: 17.85%
# Epoch [27/500], Model 5 Training Loss: 1.0530, Training Accuracy: 46.32%
# Model 1 Validation Accuracy: 22.69%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.70%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 41.14%, Validation Loss: 1.0824
# Model 4 Validation Accuracy: 22.01%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 47.91%, Validation Loss: 1.0184
# Best model 5 saved with accuracy: 47.91%
# Epoch [28/500], Model 1 Training Loss: 1.7926, Training Accuracy: 18.00%
# Epoch [28/500], Model 2 Training Loss: 1.8001, Training Accuracy: 16.49%
# Epoch [28/500], Model 3 Training Loss: 1.1055, Training Accuracy: 40.76%
# Epoch [28/500], Model 4 Training Loss: 1.7951, Training Accuracy: 18.20%
# Epoch [28/500], Model 5 Training Loss: 1.0529, Training Accuracy: 46.05%
# Model 1 Validation Accuracy: 23.03%, Validation Loss: 1.7910
# Model 2 Validation Accuracy: 25.68%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 39.76%, Validation Loss: 1.1060
# Model 4 Validation Accuracy: 20.19%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 48.37%, Validation Loss: 1.0101
# Best model 5 saved with accuracy: 48.37%
# Epoch [29/500], Model 1 Training Loss: 1.7934, Training Accuracy: 17.89%
# Epoch [29/500], Model 2 Training Loss: 1.7996, Training Accuracy: 16.76%
# Epoch [29/500], Model 3 Training Loss: 1.1134, Training Accuracy: 40.53%
# Epoch [29/500], Model 4 Training Loss: 1.7955, Training Accuracy: 18.00%
# Epoch [29/500], Model 5 Training Loss: 1.0377, Training Accuracy: 46.71%
# Model 1 Validation Accuracy: 19.63%, Validation Loss: 1.7916
# Model 2 Validation Accuracy: 25.82%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 36.49%, Validation Loss: 1.1856
# Model 4 Validation Accuracy: 16.82%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 48.21%, Validation Loss: 1.0122
# Epoch [30/500], Model 1 Training Loss: 1.7934, Training Accuracy: 18.09%
# Epoch [30/500], Model 2 Training Loss: 1.7982, Training Accuracy: 16.70%
# Epoch [30/500], Model 3 Training Loss: 1.1060, Training Accuracy: 41.11%
# Epoch [30/500], Model 4 Training Loss: 1.7944, Training Accuracy: 18.60%
# Epoch [30/500], Model 5 Training Loss: 1.0322, Training Accuracy: 46.64%
# Model 1 Validation Accuracy: 25.36%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.77%, Validation Loss: 1.7913
# Model 3 Validation Accuracy: 43.04%, Validation Loss: 1.0769
# Model 4 Validation Accuracy: 21.85%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 47.67%, Validation Loss: 0.9994
# Epoch [31/500], Model 1 Training Loss: 1.7926, Training Accuracy: 18.07%
# Epoch [31/500], Model 2 Training Loss: 1.7977, Training Accuracy: 17.08%
# Epoch [31/500], Model 3 Training Loss: 1.1013, Training Accuracy: 40.89%
# Epoch [31/500], Model 4 Training Loss: 1.7951, Training Accuracy: 18.16%
# Epoch [31/500], Model 5 Training Loss: 1.0332, Training Accuracy: 46.81%
# Model 1 Validation Accuracy: 23.35%, Validation Loss: 1.7915
# Model 2 Validation Accuracy: 26.72%, Validation Loss: 1.7913
# Model 3 Validation Accuracy: 41.52%, Validation Loss: 1.1110
# Model 4 Validation Accuracy: 18.88%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 48.84%, Validation Loss: 1.0201
# Best model 5 saved with accuracy: 48.84%
# Epoch [32/500], Model 1 Training Loss: 1.7919, Training Accuracy: 18.52%
# Epoch [32/500], Model 2 Training Loss: 1.7964, Training Accuracy: 16.66%
# Epoch [32/500], Model 3 Training Loss: 1.1136, Training Accuracy: 41.03%
# Epoch [32/500], Model 4 Training Loss: 1.7940, Training Accuracy: 18.21%
# Epoch [32/500], Model 5 Training Loss: 1.0180, Training Accuracy: 47.99%
# Model 1 Validation Accuracy: 21.01%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 23.91%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 35.65%, Validation Loss: 1.3042
# Model 4 Validation Accuracy: 24.09%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 47.55%, Validation Loss: 1.0090
# Epoch [33/500], Model 1 Training Loss: 1.7924, Training Accuracy: 18.11%
# Epoch [33/500], Model 2 Training Loss: 1.7956, Training Accuracy: 17.04%
# Epoch [33/500], Model 3 Training Loss: 1.1052, Training Accuracy: 41.47%
# Epoch [33/500], Model 4 Training Loss: 1.7939, Training Accuracy: 18.69%
# Epoch [33/500], Model 5 Training Loss: 1.0067, Training Accuracy: 47.91%
# Model 1 Validation Accuracy: 26.77%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 25.97%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 41.70%, Validation Loss: 1.0985
# Model 4 Validation Accuracy: 18.83%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 47.42%, Validation Loss: 0.9862
# Epoch [34/500], Model 1 Training Loss: 1.7923, Training Accuracy: 18.27%
# Epoch [34/500], Model 2 Training Loss: 1.7954, Training Accuracy: 16.90%
# Epoch [34/500], Model 3 Training Loss: 1.0793, Training Accuracy: 42.92%
# Epoch [34/500], Model 4 Training Loss: 1.7917, Training Accuracy: 19.16%
# Epoch [34/500], Model 5 Training Loss: 1.0052, Training Accuracy: 48.07%
# Model 1 Validation Accuracy: 15.57%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 25.09%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 42.66%, Validation Loss: 1.0553
# Model 4 Validation Accuracy: 22.67%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 49.03%, Validation Loss: 0.9692
# Best model 5 saved with accuracy: 49.03%
# Epoch [35/500], Model 1 Training Loss: 1.7907, Training Accuracy: 18.82%
# Epoch [35/500], Model 2 Training Loss: 1.7948, Training Accuracy: 16.97%
# Epoch [35/500], Model 3 Training Loss: 1.0534, Training Accuracy: 43.90%
# Epoch [35/500], Model 4 Training Loss: 1.7923, Training Accuracy: 18.05%
# Epoch [35/500], Model 5 Training Loss: 0.9927, Training Accuracy: 48.61%
# Model 1 Validation Accuracy: 21.26%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 23.05%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 42.54%, Validation Loss: 1.0367
# Model 4 Validation Accuracy: 17.02%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 48.93%, Validation Loss: 0.9660
# Epoch [36/500], Model 1 Training Loss: 1.7906, Training Accuracy: 18.75%
# Epoch [36/500], Model 2 Training Loss: 1.7948, Training Accuracy: 16.79%
# Epoch [36/500], Model 3 Training Loss: 1.0462, Training Accuracy: 44.46%
# Epoch [36/500], Model 4 Training Loss: 1.7921, Training Accuracy: 18.88%
# Epoch [36/500], Model 5 Training Loss: 0.9819, Training Accuracy: 48.84%
# Model 1 Validation Accuracy: 17.14%, Validation Loss: 1.7918
# Model 2 Validation Accuracy: 24.30%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 46.67%, Validation Loss: 1.0271
# Model 4 Validation Accuracy: 17.41%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 49.57%, Validation Loss: 0.9620
# Best model 5 saved with accuracy: 49.57%
# Epoch [37/500], Model 1 Training Loss: 1.7901, Training Accuracy: 19.70%
# Epoch [37/500], Model 2 Training Loss: 1.7939, Training Accuracy: 17.51%
# Epoch [37/500], Model 3 Training Loss: 1.0414, Training Accuracy: 45.48%
# Epoch [37/500], Model 4 Training Loss: 1.7917, Training Accuracy: 18.54%
# Epoch [37/500], Model 5 Training Loss: 0.9748, Training Accuracy: 49.61%
# Model 1 Validation Accuracy: 22.94%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 24.75%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 45.94%, Validation Loss: 1.0216
# Model 4 Validation Accuracy: 18.31%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 49.59%, Validation Loss: 0.9638
# Best model 5 saved with accuracy: 49.59%
# Epoch [38/500], Model 1 Training Loss: 1.7903, Training Accuracy: 19.34%
# Epoch [38/500], Model 2 Training Loss: 1.7926, Training Accuracy: 17.49%
# Epoch [38/500], Model 3 Training Loss: 1.0288, Training Accuracy: 45.51%
# Epoch [38/500], Model 4 Training Loss: 1.7915, Training Accuracy: 19.04%
# Epoch [38/500], Model 5 Training Loss: 0.9669, Training Accuracy: 49.82%
# Model 1 Validation Accuracy: 24.34%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 25.32%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 46.69%, Validation Loss: 1.0452
# Model 4 Validation Accuracy: 20.42%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 50.68%, Validation Loss: 0.9459
# Best model 5 saved with accuracy: 50.68%
# Epoch [39/500], Model 1 Training Loss: 1.7899, Training Accuracy: 20.01%
# Epoch [39/500], Model 2 Training Loss: 1.7932, Training Accuracy: 17.27%
# Epoch [39/500], Model 3 Training Loss: 1.0181, Training Accuracy: 45.92%
# Epoch [39/500], Model 4 Training Loss: 1.7915, Training Accuracy: 19.21%
# Epoch [39/500], Model 5 Training Loss: 0.9591, Training Accuracy: 49.82%
# Model 1 Validation Accuracy: 22.94%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 25.34%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 45.04%, Validation Loss: 1.0241
# Model 4 Validation Accuracy: 21.31%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 50.54%, Validation Loss: 0.9452
# Epoch [40/500], Model 1 Training Loss: 1.7894, Training Accuracy: 19.29%
# Epoch [40/500], Model 2 Training Loss: 1.7948, Training Accuracy: 17.25%
# Epoch [40/500], Model 3 Training Loss: 1.0123, Training Accuracy: 45.81%
# Epoch [40/500], Model 4 Training Loss: 1.7914, Training Accuracy: 19.58%
# Epoch [40/500], Model 5 Training Loss: 0.9538, Training Accuracy: 50.50%
# Model 1 Validation Accuracy: 22.44%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.05%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 45.78%, Validation Loss: 1.0128
# Model 4 Validation Accuracy: 19.08%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 50.48%, Validation Loss: 0.9381
# Epoch [41/500], Model 1 Training Loss: 1.7900, Training Accuracy: 19.43%
# Epoch [41/500], Model 2 Training Loss: 1.7922, Training Accuracy: 17.88%
# Epoch [41/500], Model 3 Training Loss: 1.0088, Training Accuracy: 46.23%
# Epoch [41/500], Model 4 Training Loss: 1.7910, Training Accuracy: 19.34%
# Epoch [41/500], Model 5 Training Loss: 0.9544, Training Accuracy: 50.36%
# Model 1 Validation Accuracy: 18.20%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 24.61%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 45.81%, Validation Loss: 1.0121
# Model 4 Validation Accuracy: 16.86%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 50.29%, Validation Loss: 0.9384
# Epoch [42/500], Model 1 Training Loss: 1.7900, Training Accuracy: 20.03%
# Epoch [42/500], Model 2 Training Loss: 1.7937, Training Accuracy: 17.57%
# Epoch [42/500], Model 3 Training Loss: 1.0101, Training Accuracy: 46.33%
# Epoch [42/500], Model 4 Training Loss: 1.7910, Training Accuracy: 19.56%
# Epoch [42/500], Model 5 Training Loss: 0.9545, Training Accuracy: 50.52%
# Model 1 Validation Accuracy: 22.35%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 24.98%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 47.39%, Validation Loss: 1.0136
# Model 4 Validation Accuracy: 19.90%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 50.20%, Validation Loss: 0.9364
# Epoch [43/500], Model 1 Training Loss: 1.7898, Training Accuracy: 19.08%
# Epoch [43/500], Model 2 Training Loss: 1.7931, Training Accuracy: 17.63%
# Epoch [43/500], Model 3 Training Loss: 1.0125, Training Accuracy: 45.95%
# Epoch [43/500], Model 4 Training Loss: 1.7918, Training Accuracy: 19.07%
# Epoch [43/500], Model 5 Training Loss: 0.9544, Training Accuracy: 51.04%
# Model 1 Validation Accuracy: 22.42%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 24.71%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 45.87%, Validation Loss: 1.0120
# Model 4 Validation Accuracy: 21.17%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 50.23%, Validation Loss: 0.9347
# Epoch [44/500], Model 1 Training Loss: 1.7894, Training Accuracy: 19.72%
# Epoch [44/500], Model 2 Training Loss: 1.7924, Training Accuracy: 17.87%
# Epoch [44/500], Model 3 Training Loss: 1.0181, Training Accuracy: 46.45%
# Epoch [44/500], Model 4 Training Loss: 1.7908, Training Accuracy: 19.35%
# Epoch [44/500], Model 5 Training Loss: 0.9554, Training Accuracy: 50.39%
# Model 1 Validation Accuracy: 15.66%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 24.75%, Validation Loss: 1.7909
# Model 3 Validation Accuracy: 47.85%, Validation Loss: 1.0050
# Model 4 Validation Accuracy: 17.04%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 50.48%, Validation Loss: 0.9351
# Epoch [45/500], Model 1 Training Loss: 1.7900, Training Accuracy: 19.09%
# Epoch [45/500], Model 2 Training Loss: 1.7933, Training Accuracy: 17.58%
# Epoch [45/500], Model 3 Training Loss: 1.0201, Training Accuracy: 46.66%
# Epoch [45/500], Model 4 Training Loss: 1.7908, Training Accuracy: 19.53%
# Epoch [45/500], Model 5 Training Loss: 0.9604, Training Accuracy: 50.41%
# Model 1 Validation Accuracy: 19.72%, Validation Loss: 1.7909
# Model 2 Validation Accuracy: 23.93%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 45.97%, Validation Loss: 1.0094
# Model 4 Validation Accuracy: 17.25%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 50.93%, Validation Loss: 0.9351
# Best model 5 saved with accuracy: 50.93%
# Epoch [46/500], Model 1 Training Loss: 1.7887, Training Accuracy: 19.48%
# Epoch [46/500], Model 2 Training Loss: 1.7927, Training Accuracy: 17.49%
# Epoch [46/500], Model 3 Training Loss: 1.0087, Training Accuracy: 47.30%
# Epoch [46/500], Model 4 Training Loss: 1.7900, Training Accuracy: 19.73%
# Epoch [46/500], Model 5 Training Loss: 0.9562, Training Accuracy: 50.08%
# Model 1 Validation Accuracy: 18.83%, Validation Loss: 1.7906
# Model 2 Validation Accuracy: 22.67%, Validation Loss: 1.7909
# Model 3 Validation Accuracy: 49.57%, Validation Loss: 0.9854
# Model 4 Validation Accuracy: 17.95%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 49.52%, Validation Loss: 0.9294
# Epoch [47/500], Model 1 Training Loss: 1.7792, Training Accuracy: 21.16%
# Epoch [47/500], Model 2 Training Loss: 1.7930, Training Accuracy: 17.76%
# Epoch [47/500], Model 3 Training Loss: 1.0007, Training Accuracy: 48.44%
# Epoch [47/500], Model 4 Training Loss: 1.7904, Training Accuracy: 19.31%
# Epoch [47/500], Model 5 Training Loss: 0.9542, Training Accuracy: 50.21%
# Model 1 Validation Accuracy: 22.28%, Validation Loss: 1.8381
# Model 2 Validation Accuracy: 23.46%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 49.32%, Validation Loss: 0.9570
# Model 4 Validation Accuracy: 15.30%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 52.24%, Validation Loss: 0.9426
# Best model 5 saved with accuracy: 52.24%
# Epoch [48/500], Model 1 Training Loss: 1.8014, Training Accuracy: 18.15%
# Epoch [48/500], Model 2 Training Loss: 1.7920, Training Accuracy: 17.76%
# Epoch [48/500], Model 3 Training Loss: 0.9713, Training Accuracy: 49.30%
# Epoch [48/500], Model 4 Training Loss: 1.7918, Training Accuracy: 19.02%
# Epoch [48/500], Model 5 Training Loss: 0.9497, Training Accuracy: 50.16%
# Model 1 Validation Accuracy: 14.96%, Validation Loss: 1.7925
# Model 2 Validation Accuracy: 23.37%, Validation Loss: 1.7909
# Model 3 Validation Accuracy: 52.40%, Validation Loss: 0.9046
# Best model 3 saved with accuracy: 52.40%
# Model 4 Validation Accuracy: 21.60%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 52.02%, Validation Loss: 0.9116
# Epoch [49/500], Model 1 Training Loss: 1.8082, Training Accuracy: 16.61%
# Epoch [49/500], Model 2 Training Loss: 1.7930, Training Accuracy: 17.73%
# Epoch [49/500], Model 3 Training Loss: 0.9670, Training Accuracy: 49.50%
# Epoch [49/500], Model 4 Training Loss: 1.7907, Training Accuracy: 19.72%
# Epoch [49/500], Model 5 Training Loss: 0.9502, Training Accuracy: 50.34%
# Model 1 Validation Accuracy: 14.71%, Validation Loss: 1.7920
# Model 2 Validation Accuracy: 20.69%, Validation Loss: 1.7914
# Model 3 Validation Accuracy: 50.11%, Validation Loss: 0.9758
# Model 4 Validation Accuracy: 16.84%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 51.36%, Validation Loss: 0.9188
# Epoch [50/500], Model 1 Training Loss: 1.8052, Training Accuracy: 16.87%
# Epoch [50/500], Model 2 Training Loss: 1.7924, Training Accuracy: 17.98%
# Epoch [50/500], Model 3 Training Loss: 0.9492, Training Accuracy: 50.79%
# Epoch [50/500], Model 4 Training Loss: 1.7913, Training Accuracy: 18.73%
# Epoch [50/500], Model 5 Training Loss: 0.9460, Training Accuracy: 50.79%
# Model 1 Validation Accuracy: 14.96%, Validation Loss: 1.7919
# Model 2 Validation Accuracy: 16.09%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 51.16%, Validation Loss: 0.8959
# Model 4 Validation Accuracy: 17.68%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 50.57%, Validation Loss: 0.9056
# Epoch [51/500], Model 1 Training Loss: 1.8033, Training Accuracy: 16.26%
# Epoch [51/500], Model 2 Training Loss: 1.7919, Training Accuracy: 18.01%
# Epoch [51/500], Model 3 Training Loss: 0.9300, Training Accuracy: 51.21%
# Epoch [51/500], Model 4 Training Loss: 1.7909, Training Accuracy: 19.12%
# Epoch [51/500], Model 5 Training Loss: 0.9366, Training Accuracy: 51.26%
# Model 1 Validation Accuracy: 13.51%, Validation Loss: 1.7920
# Model 2 Validation Accuracy: 24.32%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 51.72%, Validation Loss: 0.9562
# Model 4 Validation Accuracy: 17.68%, Validation Loss: 1.7912
# Model 5 Validation Accuracy: 51.25%, Validation Loss: 0.9290
# Epoch [52/500], Model 1 Training Loss: 1.7990, Training Accuracy: 16.82%
# Epoch [52/500], Model 2 Training Loss: 1.7917, Training Accuracy: 18.22%
# Epoch [52/500], Model 3 Training Loss: 0.9110, Training Accuracy: 52.35%
# Epoch [52/500], Model 4 Training Loss: 1.7897, Training Accuracy: 19.45%
# Epoch [52/500], Model 5 Training Loss: 0.9319, Training Accuracy: 51.11%
# Model 1 Validation Accuracy: 14.21%, Validation Loss: 1.7918
# Model 2 Validation Accuracy: 22.85%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 54.65%, Validation Loss: 0.8653
# Best model 3 saved with accuracy: 54.65%
# Model 4 Validation Accuracy: 14.98%, Validation Loss: 1.7819
# Model 5 Validation Accuracy: 51.88%, Validation Loss: 0.8996
# Epoch [53/500], Model 1 Training Loss: 1.7988, Training Accuracy: 16.46%
# Epoch [53/500], Model 2 Training Loss: 1.7917, Training Accuracy: 18.86%
# Epoch [53/500], Model 3 Training Loss: 0.9017, Training Accuracy: 52.70%
# Epoch [53/500], Model 4 Training Loss: 1.6552, Training Accuracy: 25.83%
# Epoch [53/500], Model 5 Training Loss: 0.9275, Training Accuracy: 51.67%
# Model 1 Validation Accuracy: 22.89%, Validation Loss: 1.7918
# Model 2 Validation Accuracy: 25.11%, Validation Loss: 1.7909
# Model 3 Validation Accuracy: 52.74%, Validation Loss: 0.8765
# Model 4 Validation Accuracy: 25.52%, Validation Loss: 1.6078
# Model 5 Validation Accuracy: 52.92%, Validation Loss: 0.8855
# Epoch [54/500], Model 1 Training Loss: 1.7987, Training Accuracy: 16.45%
# Epoch [54/500], Model 2 Training Loss: 1.7914, Training Accuracy: 18.64%
# Epoch [54/500], Model 3 Training Loss: 0.8901, Training Accuracy: 53.02%
# Epoch [54/500], Model 4 Training Loss: 1.6365, Training Accuracy: 26.55%
# Epoch [54/500], Model 5 Training Loss: 0.9182, Training Accuracy: 52.48%
# Model 1 Validation Accuracy: 16.77%, Validation Loss: 1.7920
# Model 2 Validation Accuracy: 23.25%, Validation Loss: 1.7902
# Model 3 Validation Accuracy: 55.53%, Validation Loss: 0.8457
# Best model 3 saved with accuracy: 55.53%
# Model 4 Validation Accuracy: 27.49%, Validation Loss: 1.5863
# Model 5 Validation Accuracy: 49.75%, Validation Loss: 0.9353
# Epoch [55/500], Model 1 Training Loss: 1.7964, Training Accuracy: 16.60%
# Epoch [55/500], Model 2 Training Loss: 1.7926, Training Accuracy: 17.50%
# Epoch [55/500], Model 3 Training Loss: 0.8852, Training Accuracy: 53.05%
# Epoch [55/500], Model 4 Training Loss: 1.5904, Training Accuracy: 27.31%
# Epoch [55/500], Model 5 Training Loss: 0.9061, Training Accuracy: 52.51%
# Model 1 Validation Accuracy: 19.06%, Validation Loss: 1.7918
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7926
# Model 3 Validation Accuracy: 54.01%, Validation Loss: 0.8779
# Model 4 Validation Accuracy: 28.58%, Validation Loss: 1.6091
# Model 5 Validation Accuracy: 53.69%, Validation Loss: 0.8840
# Epoch [56/500], Model 1 Training Loss: 1.7705, Training Accuracy: 20.39%
# Epoch [56/500], Model 2 Training Loss: 1.7932, Training Accuracy: 16.64%
# Epoch [56/500], Model 3 Training Loss: 0.8631, Training Accuracy: 53.78%
# Epoch [56/500], Model 4 Training Loss: 1.4607, Training Accuracy: 29.51%
# Epoch [56/500], Model 5 Training Loss: 0.8943, Training Accuracy: 53.15%
# Model 1 Validation Accuracy: 24.21%, Validation Loss: 1.7412
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7922
# Model 3 Validation Accuracy: 55.28%, Validation Loss: 0.8462
# Model 4 Validation Accuracy: 32.23%, Validation Loss: 1.3214
# Model 5 Validation Accuracy: 52.72%, Validation Loss: 0.8857
# Epoch [57/500], Model 1 Training Loss: 1.6910, Training Accuracy: 25.78%
# Epoch [57/500], Model 2 Training Loss: 1.7927, Training Accuracy: 17.28%
# Epoch [57/500], Model 3 Training Loss: 0.8461, Training Accuracy: 54.65%
# Epoch [57/500], Model 4 Training Loss: 1.4077, Training Accuracy: 30.38%
# Epoch [57/500], Model 5 Training Loss: 0.8938, Training Accuracy: 52.60%
# Model 1 Validation Accuracy: 27.54%, Validation Loss: 1.6477
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7921
# Model 3 Validation Accuracy: 53.85%, Validation Loss: 0.8252
# Model 4 Validation Accuracy: 32.55%, Validation Loss: 1.3508
# Model 5 Validation Accuracy: 52.11%, Validation Loss: 0.8817
# Epoch [58/500], Model 1 Training Loss: 1.6481, Training Accuracy: 26.72%
# Epoch [58/500], Model 2 Training Loss: 1.7936, Training Accuracy: 16.40%
# Epoch [58/500], Model 3 Training Loss: 0.8403, Training Accuracy: 55.02%
# Epoch [58/500], Model 4 Training Loss: 1.4495, Training Accuracy: 30.42%
# Epoch [58/500], Model 5 Training Loss: 0.8843, Training Accuracy: 53.49%
# Model 1 Validation Accuracy: 28.63%, Validation Loss: 1.6139
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 54.26%, Validation Loss: 0.8199
# Model 4 Validation Accuracy: 29.69%, Validation Loss: 1.4038
# Model 5 Validation Accuracy: 53.56%, Validation Loss: 0.8810
# Epoch [59/500], Model 1 Training Loss: 1.6333, Training Accuracy: 26.81%
# Epoch [59/500], Model 2 Training Loss: 1.7933, Training Accuracy: 16.78%
# Epoch [59/500], Model 3 Training Loss: 0.8342, Training Accuracy: 55.17%
# Epoch [59/500], Model 4 Training Loss: 1.5425, Training Accuracy: 28.42%
# Epoch [59/500], Model 5 Training Loss: 0.8781, Training Accuracy: 53.59%
# Model 1 Validation Accuracy: 26.04%, Validation Loss: 1.6086
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 56.80%, Validation Loss: 0.8131
# Best model 3 saved with accuracy: 56.80%
# Model 4 Validation Accuracy: 27.22%, Validation Loss: 1.5524
# Model 5 Validation Accuracy: 53.58%, Validation Loss: 0.8738
# Epoch [60/500], Model 1 Training Loss: 1.6255, Training Accuracy: 26.25%
# Epoch [60/500], Model 2 Training Loss: 1.7929, Training Accuracy: 16.74%
# Epoch [60/500], Model 3 Training Loss: 0.8253, Training Accuracy: 56.15%
# Epoch [60/500], Model 4 Training Loss: 1.5582, Training Accuracy: 28.16%
# Epoch [60/500], Model 5 Training Loss: 0.8757, Training Accuracy: 53.24%
# Model 1 Validation Accuracy: 26.61%, Validation Loss: 1.5998
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 56.41%, Validation Loss: 0.8104
# Model 4 Validation Accuracy: 27.99%, Validation Loss: 1.5289
# Model 5 Validation Accuracy: 52.15%, Validation Loss: 0.8769
# Epoch [61/500], Model 1 Training Loss: 1.6247, Training Accuracy: 26.70%
# Epoch [61/500], Model 2 Training Loss: 1.7927, Training Accuracy: 17.07%
# Epoch [61/500], Model 3 Training Loss: 0.8240, Training Accuracy: 56.14%
# Epoch [61/500], Model 4 Training Loss: 1.5544, Training Accuracy: 28.41%
# Epoch [61/500], Model 5 Training Loss: 0.8792, Training Accuracy: 53.47%
# Model 1 Validation Accuracy: 26.52%, Validation Loss: 1.6003
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 56.71%, Validation Loss: 0.8094
# Model 4 Validation Accuracy: 27.83%, Validation Loss: 1.5306
# Model 5 Validation Accuracy: 53.01%, Validation Loss: 0.8731
# Epoch [62/500], Model 1 Training Loss: 1.6226, Training Accuracy: 26.43%
# Epoch [62/500], Model 2 Training Loss: 1.7930, Training Accuracy: 16.62%
# Epoch [62/500], Model 3 Training Loss: 0.8269, Training Accuracy: 56.40%
# Epoch [62/500], Model 4 Training Loss: 1.5470, Training Accuracy: 28.75%
# Epoch [62/500], Model 5 Training Loss: 0.8770, Training Accuracy: 53.76%
# Model 1 Validation Accuracy: 26.61%, Validation Loss: 1.5982
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7920
# Model 3 Validation Accuracy: 57.37%, Validation Loss: 0.8105
# Best model 3 saved with accuracy: 57.37%
# Model 4 Validation Accuracy: 28.58%, Validation Loss: 1.5149
# Model 5 Validation Accuracy: 53.04%, Validation Loss: 0.8734
# Epoch [63/500], Model 1 Training Loss: 1.6175, Training Accuracy: 26.49%
# Epoch [63/500], Model 2 Training Loss: 1.7938, Training Accuracy: 15.92%
# Epoch [63/500], Model 3 Training Loss: 0.8293, Training Accuracy: 55.92%
# Epoch [63/500], Model 4 Training Loss: 1.5471, Training Accuracy: 28.48%
# Epoch [63/500], Model 5 Training Loss: 0.8770, Training Accuracy: 54.13%
# Model 1 Validation Accuracy: 26.59%, Validation Loss: 1.5906
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7919
# Model 3 Validation Accuracy: 56.26%, Validation Loss: 0.8106
# Model 4 Validation Accuracy: 28.15%, Validation Loss: 1.5168
# Model 5 Validation Accuracy: 51.93%, Validation Loss: 0.8793
# Epoch [64/500], Model 1 Training Loss: 1.6083, Training Accuracy: 26.85%
# Epoch [64/500], Model 2 Training Loss: 1.7936, Training Accuracy: 16.62%
# Epoch [64/500], Model 3 Training Loss: 0.8367, Training Accuracy: 55.06%
# Epoch [64/500], Model 4 Training Loss: 1.5251, Training Accuracy: 29.51%
# Epoch [64/500], Model 5 Training Loss: 0.8815, Training Accuracy: 53.60%
# Model 1 Validation Accuracy: 26.99%, Validation Loss: 1.5816
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7919
# Model 3 Validation Accuracy: 56.21%, Validation Loss: 0.8235
# Model 4 Validation Accuracy: 29.37%, Validation Loss: 1.4815
# Model 5 Validation Accuracy: 53.47%, Validation Loss: 0.8836
# Epoch [65/500], Model 1 Training Loss: 1.5918, Training Accuracy: 26.80%
# Epoch [65/500], Model 2 Training Loss: 1.7929, Training Accuracy: 16.41%
# Epoch [65/500], Model 3 Training Loss: 0.8448, Training Accuracy: 55.46%
# Epoch [65/500], Model 4 Training Loss: 1.4858, Training Accuracy: 30.14%
# Epoch [65/500], Model 5 Training Loss: 0.8846, Training Accuracy: 53.64%
# Model 1 Validation Accuracy: 24.95%, Validation Loss: 1.6233
# Model 2 Validation Accuracy: 14.62%, Validation Loss: 1.7918
# Model 3 Validation Accuracy: 57.30%, Validation Loss: 0.8110
# Model 4 Validation Accuracy: 31.39%, Validation Loss: 1.3555
# Model 5 Validation Accuracy: 54.71%, Validation Loss: 0.8880
# Epoch [66/500], Model 1 Training Loss: 1.6725, Training Accuracy: 24.17%
# Epoch [66/500], Model 2 Training Loss: 1.7927, Training Accuracy: 17.30%
# Epoch [66/500], Model 3 Training Loss: 0.8529, Training Accuracy: 54.77%
# Epoch [66/500], Model 4 Training Loss: 1.2700, Training Accuracy: 33.28%
# Epoch [66/500], Model 5 Training Loss: 0.8860, Training Accuracy: 53.49%
# Model 1 Validation Accuracy: 14.98%, Validation Loss: 1.7988
# Model 2 Validation Accuracy: 12.47%, Validation Loss: 1.7918
# Model 3 Validation Accuracy: 55.87%, Validation Loss: 0.8665
# Model 4 Validation Accuracy: 32.93%, Validation Loss: 1.2026
# Model 5 Validation Accuracy: 52.70%, Validation Loss: 0.9109
# Epoch [67/500], Model 1 Training Loss: 1.8033, Training Accuracy: 16.52%
# Epoch [67/500], Model 2 Training Loss: 1.7677, Training Accuracy: 21.00%
# Epoch [67/500], Model 3 Training Loss: 0.8667, Training Accuracy: 53.83%
# Epoch [67/500], Model 4 Training Loss: 1.2154, Training Accuracy: 34.24%
# Epoch [67/500], Model 5 Training Loss: 0.8924, Training Accuracy: 53.21%
# Model 1 Validation Accuracy: 14.96%, Validation Loss: 1.7955
# Model 2 Validation Accuracy: 25.20%, Validation Loss: 1.7038
# Model 3 Validation Accuracy: 55.42%, Validation Loss: 0.8406
# Model 4 Validation Accuracy: 35.88%, Validation Loss: 1.2328
# Model 5 Validation Accuracy: 53.79%, Validation Loss: 0.8644
# Epoch [68/500], Model 1 Training Loss: 1.7996, Training Accuracy: 16.02%
# Epoch [68/500], Model 2 Training Loss: 1.6340, Training Accuracy: 27.17%
# Epoch [68/500], Model 3 Training Loss: 0.8739, Training Accuracy: 54.38%
# Epoch [68/500], Model 4 Training Loss: 1.1966, Training Accuracy: 35.86%
# Epoch [68/500], Model 5 Training Loss: 0.8968, Training Accuracy: 52.83%
# Model 1 Validation Accuracy: 16.07%, Validation Loss: 1.7935
# Model 2 Validation Accuracy: 27.38%, Validation Loss: 1.5892
# Model 3 Validation Accuracy: 54.87%, Validation Loss: 0.8556
# Model 4 Validation Accuracy: 35.88%, Validation Loss: 1.1758
# Model 5 Validation Accuracy: 52.99%, Validation Loss: 0.8885
# Epoch [69/500], Model 1 Training Loss: 1.7958, Training Accuracy: 16.69%
# Epoch [69/500], Model 2 Training Loss: 1.5631, Training Accuracy: 27.75%
# Epoch [69/500], Model 3 Training Loss: 0.8673, Training Accuracy: 54.29%
# Epoch [69/500], Model 4 Training Loss: 1.1862, Training Accuracy: 35.66%
# Epoch [69/500], Model 5 Training Loss: 0.8903, Training Accuracy: 53.62%
# Model 1 Validation Accuracy: 16.07%, Validation Loss: 1.7931
# Model 2 Validation Accuracy: 16.07%, Validation Loss: 1.9167
# Model 3 Validation Accuracy: 54.96%, Validation Loss: 0.8073
# Model 4 Validation Accuracy: 37.67%, Validation Loss: 1.1547
# Model 5 Validation Accuracy: 54.15%, Validation Loss: 0.8680
# Epoch [70/500], Model 1 Training Loss: 1.7947, Training Accuracy: 16.90%
# Epoch [70/500], Model 2 Training Loss: 1.8034, Training Accuracy: 17.09%
# Epoch [70/500], Model 3 Training Loss: 0.8778, Training Accuracy: 53.33%
# ...
# Epoch [477/500], Model 5 Training Loss: 0.6029, Training Accuracy: 65.16%
# Model 1 Validation Accuracy: 64.23%, Validation Loss: 0.6089
# Model 2 Validation Accuracy: 65.10%, Validation Loss: 0.5830
# Model 3 Validation Accuracy: 67.72%, Validation Loss: 0.5667
# Model 4 Validation Accuracy: 64.66%, Validation Loss: 0.6105
# Model 5 Validation Accuracy: 61.11%, Validation Loss: 0.7336
# Epoch [478/500], Model 1 Training Loss: 0.6081, Training Accuracy: 64.73%
# Epoch [478/500], Model 2 Training Loss: 0.5605, Training Accuracy: 67.76%
# Epoch [478/500], Model 3 Training Loss: 0.5016, Training Accuracy: 71.13%
# Epoch [478/500], Model 4 Training Loss: 0.5692, Training Accuracy: 66.90%
# Epoch [478/500], Model 5 Training Loss: 0.5973, Training Accuracy: 65.51%
# Model 1 Validation Accuracy: 64.01%, Validation Loss: 0.6108
# Model 2 Validation Accuracy: 65.66%, Validation Loss: 0.5821
# Model 3 Validation Accuracy: 68.83%, Validation Loss: 0.5565
# Model 4 Validation Accuracy: 67.09%, Validation Loss: 0.5883
# Model 5 Validation Accuracy: 63.12%, Validation Loss: 0.7192
# Epoch [479/500], Model 1 Training Loss: 0.6028, Training Accuracy: 64.99%
# Epoch [479/500], Model 2 Training Loss: 0.5527, Training Accuracy: 67.91%
# Epoch [479/500], Model 3 Training Loss: 0.4977, Training Accuracy: 71.03%
# Epoch [479/500], Model 4 Training Loss: 0.5581, Training Accuracy: 67.52%
# Epoch [479/500], Model 5 Training Loss: 0.5957, Training Accuracy: 65.84%
# Model 1 Validation Accuracy: 64.66%, Validation Loss: 0.6040
# Model 2 Validation Accuracy: 65.37%, Validation Loss: 0.5825
# Model 3 Validation Accuracy: 67.97%, Validation Loss: 0.5568
# Model 4 Validation Accuracy: 65.28%, Validation Loss: 0.5965
# Model 5 Validation Accuracy: 62.51%, Validation Loss: 0.6875
# Epoch [480/500], Model 1 Training Loss: 0.5976, Training Accuracy: 65.27%
# Epoch [480/500], Model 2 Training Loss: 0.5495, Training Accuracy: 68.13%
# Epoch [480/500], Model 3 Training Loss: 0.4942, Training Accuracy: 71.33%
# Epoch [480/500], Model 4 Training Loss: 0.5575, Training Accuracy: 67.60%
# Epoch [480/500], Model 5 Training Loss: 0.5906, Training Accuracy: 66.20%
# Model 1 Validation Accuracy: 64.62%, Validation Loss: 0.6006
# Model 2 Validation Accuracy: 65.73%, Validation Loss: 0.5755
# Model 3 Validation Accuracy: 68.45%, Validation Loss: 0.5540
# Model 4 Validation Accuracy: 66.16%, Validation Loss: 0.5877
# Model 5 Validation Accuracy: 62.76%, Validation Loss: 0.6870
# Epoch [481/500], Model 1 Training Loss: 0.5977, Training Accuracy: 65.34%
# Epoch [481/500], Model 2 Training Loss: 0.5525, Training Accuracy: 68.11%
# Epoch [481/500], Model 3 Training Loss: 0.4915, Training Accuracy: 71.95%
# Epoch [481/500], Model 4 Training Loss: 0.5536, Training Accuracy: 67.93%
# Epoch [481/500], Model 5 Training Loss: 0.5883, Training Accuracy: 66.08%
# Model 1 Validation Accuracy: 64.62%, Validation Loss: 0.5995
# Model 2 Validation Accuracy: 66.46%, Validation Loss: 0.5736
# Model 3 Validation Accuracy: 68.88%, Validation Loss: 0.5525
# Model 4 Validation Accuracy: 66.00%, Validation Loss: 0.5865
# Model 5 Validation Accuracy: 63.26%, Validation Loss: 0.6869
# Epoch [482/500], Model 1 Training Loss: 0.6001, Training Accuracy: 65.28%
# Epoch [482/500], Model 2 Training Loss: 0.5508, Training Accuracy: 68.32%
# Epoch [482/500], Model 3 Training Loss: 0.4926, Training Accuracy: 71.68%
# Epoch [482/500], Model 4 Training Loss: 0.5562, Training Accuracy: 67.84%
# Epoch [482/500], Model 5 Training Loss: 0.5911, Training Accuracy: 66.20%
# Model 1 Validation Accuracy: 64.60%, Validation Loss: 0.6014
# Model 2 Validation Accuracy: 66.14%, Validation Loss: 0.5753
# Model 3 Validation Accuracy: 68.81%, Validation Loss: 0.5528
# Model 4 Validation Accuracy: 65.55%, Validation Loss: 0.5904
# Model 5 Validation Accuracy: 63.24%, Validation Loss: 0.6870
# Epoch [483/500], Model 1 Training Loss: 0.6004, Training Accuracy: 65.35%
# Epoch [483/500], Model 2 Training Loss: 0.5521, Training Accuracy: 67.90%
# Epoch [483/500], Model 3 Training Loss: 0.4963, Training Accuracy: 71.50%
# Epoch [483/500], Model 4 Training Loss: 0.5575, Training Accuracy: 67.78%
# Epoch [483/500], Model 5 Training Loss: 0.5925, Training Accuracy: 66.30%
# Model 1 Validation Accuracy: 65.32%, Validation Loss: 0.6018
# Model 2 Validation Accuracy: 66.57%, Validation Loss: 0.5742
# Model 3 Validation Accuracy: 68.50%, Validation Loss: 0.5558
# Model 4 Validation Accuracy: 65.64%, Validation Loss: 0.5870
# Model 5 Validation Accuracy: 62.74%, Validation Loss: 0.6976
# Epoch [484/500], Model 1 Training Loss: 0.6067, Training Accuracy: 65.36%
# Epoch [484/500], Model 2 Training Loss: 0.5544, Training Accuracy: 68.08%
# Epoch [484/500], Model 3 Training Loss: 0.5011, Training Accuracy: 70.97%
# Epoch [484/500], Model 4 Training Loss: 0.5667, Training Accuracy: 67.10%
# Epoch [484/500], Model 5 Training Loss: 0.5986, Training Accuracy: 65.47%
# Model 1 Validation Accuracy: 64.42%, Validation Loss: 0.6187
# Model 2 Validation Accuracy: 66.09%, Validation Loss: 0.5857
# Model 3 Validation Accuracy: 68.95%, Validation Loss: 0.5571
# Model 4 Validation Accuracy: 66.07%, Validation Loss: 0.5967
# Model 5 Validation Accuracy: 63.85%, Validation Loss: 0.6935
# Epoch [485/500], Model 1 Training Loss: 0.6081, Training Accuracy: 64.62%
# Epoch [485/500], Model 2 Training Loss: 0.5606, Training Accuracy: 67.71%
# Epoch [485/500], Model 3 Training Loss: 0.5087, Training Accuracy: 70.69%
# Epoch [485/500], Model 4 Training Loss: 0.5740, Training Accuracy: 66.73%
# Epoch [485/500], Model 5 Training Loss: 0.6000, Training Accuracy: 65.75%
# Model 1 Validation Accuracy: 64.89%, Validation Loss: 0.6181
# Model 2 Validation Accuracy: 65.71%, Validation Loss: 0.5859
# Model 3 Validation Accuracy: 65.96%, Validation Loss: 0.5907
# Model 4 Validation Accuracy: 65.37%, Validation Loss: 0.5990
# Model 5 Validation Accuracy: 63.03%, Validation Loss: 0.7009
# Epoch [486/500], Model 1 Training Loss: 0.6180, Training Accuracy: 64.42%
# Epoch [486/500], Model 2 Training Loss: 0.5678, Training Accuracy: 67.22%
# Epoch [486/500], Model 3 Training Loss: 0.5154, Training Accuracy: 69.96%
# Epoch [486/500], Model 4 Training Loss: 0.5832, Training Accuracy: 66.55%
# Epoch [486/500], Model 5 Training Loss: 0.6066, Training Accuracy: 65.62%
# Model 1 Validation Accuracy: 64.87%, Validation Loss: 0.6136
# Model 2 Validation Accuracy: 66.12%, Validation Loss: 0.5942
# Model 3 Validation Accuracy: 65.50%, Validation Loss: 0.5820
# Model 4 Validation Accuracy: 65.78%, Validation Loss: 0.5950
# Model 5 Validation Accuracy: 63.55%, Validation Loss: 0.6886
# Epoch [487/500], Model 1 Training Loss: 0.6298, Training Accuracy: 64.00%
# Epoch [487/500], Model 2 Training Loss: 0.5771, Training Accuracy: 66.57%
# Epoch [487/500], Model 3 Training Loss: 0.5339, Training Accuracy: 69.05%
# Epoch [487/500], Model 4 Training Loss: 0.5862, Training Accuracy: 66.03%
# Epoch [487/500], Model 5 Training Loss: 0.6153, Training Accuracy: 64.92%
# Model 1 Validation Accuracy: 63.62%, Validation Loss: 0.6262
# Model 2 Validation Accuracy: 65.62%, Validation Loss: 0.5770
# Model 3 Validation Accuracy: 65.64%, Validation Loss: 0.5830
# Model 4 Validation Accuracy: 65.87%, Validation Loss: 0.6102
# Model 5 Validation Accuracy: 63.19%, Validation Loss: 0.7113
# Epoch [488/500], Model 1 Training Loss: 0.6339, Training Accuracy: 64.16%
# Epoch [488/500], Model 2 Training Loss: 0.5784, Training Accuracy: 66.62%
# Epoch [488/500], Model 3 Training Loss: 0.5359, Training Accuracy: 68.78%
# Epoch [488/500], Model 4 Training Loss: 0.5974, Training Accuracy: 65.82%
# Epoch [488/500], Model 5 Training Loss: 0.6265, Training Accuracy: 64.44%
# Model 1 Validation Accuracy: 64.39%, Validation Loss: 0.6238
# Model 2 Validation Accuracy: 65.64%, Validation Loss: 0.5864
# Model 3 Validation Accuracy: 69.45%, Validation Loss: 0.5699
# Model 4 Validation Accuracy: 65.00%, Validation Loss: 0.6169
# Model 5 Validation Accuracy: 60.45%, Validation Loss: 0.7104
# Epoch [489/500], Model 1 Training Loss: 0.6438, Training Accuracy: 63.43%
# Epoch [489/500], Model 2 Training Loss: 0.5771, Training Accuracy: 66.65%
# Epoch [489/500], Model 3 Training Loss: 0.5457, Training Accuracy: 68.45%
# Epoch [489/500], Model 4 Training Loss: 0.6014, Training Accuracy: 65.40%
# Epoch [489/500], Model 5 Training Loss: 0.6248, Training Accuracy: 64.14%
# Model 1 Validation Accuracy: 63.24%, Validation Loss: 0.6352
# Model 2 Validation Accuracy: 65.41%, Validation Loss: 0.5905
# Model 3 Validation Accuracy: 65.44%, Validation Loss: 0.5816
# Model 4 Validation Accuracy: 65.23%, Validation Loss: 0.6468
# Model 5 Validation Accuracy: 62.92%, Validation Loss: 0.7198
# Epoch [490/500], Model 1 Training Loss: 0.6472, Training Accuracy: 63.25%
# Epoch [490/500], Model 2 Training Loss: 0.5831, Training Accuracy: 66.28%
# Epoch [490/500], Model 3 Training Loss: 0.5562, Training Accuracy: 67.99%
# Epoch [490/500], Model 4 Training Loss: 0.6067, Training Accuracy: 65.78%
# Epoch [490/500], Model 5 Training Loss: 0.6349, Training Accuracy: 64.33%
# Model 1 Validation Accuracy: 62.72%, Validation Loss: 0.6524
# Model 2 Validation Accuracy: 64.69%, Validation Loss: 0.6045
# Model 3 Validation Accuracy: 68.45%, Validation Loss: 0.5733
# Model 4 Validation Accuracy: 63.98%, Validation Loss: 0.6386
# Model 5 Validation Accuracy: 62.53%, Validation Loss: 0.7096
# Epoch [491/500], Model 1 Training Loss: 0.6373, Training Accuracy: 63.75%
# Epoch [491/500], Model 2 Training Loss: 0.5834, Training Accuracy: 66.62%
# Epoch [491/500], Model 3 Training Loss: 0.5619, Training Accuracy: 67.69%
# Epoch [491/500], Model 4 Training Loss: 0.6097, Training Accuracy: 65.41%
# Epoch [491/500], Model 5 Training Loss: 0.6371, Training Accuracy: 63.90%
# Model 1 Validation Accuracy: 62.72%, Validation Loss: 0.6533
# Model 2 Validation Accuracy: 65.73%, Validation Loss: 0.5833
# Model 3 Validation Accuracy: 66.18%, Validation Loss: 0.6021
# Model 4 Validation Accuracy: 63.21%, Validation Loss: 0.7136
# Model 5 Validation Accuracy: 63.21%, Validation Loss: 0.7144
# Epoch [492/500], Model 1 Training Loss: 0.6417, Training Accuracy: 63.59%
# Epoch [492/500], Model 2 Training Loss: 0.5800, Training Accuracy: 66.78%
# Epoch [492/500], Model 3 Training Loss: 0.5500, Training Accuracy: 68.57%
# Epoch [492/500], Model 4 Training Loss: 0.6055, Training Accuracy: 65.65%
# Epoch [492/500], Model 5 Training Loss: 0.6310, Training Accuracy: 64.24%
# Model 1 Validation Accuracy: 63.96%, Validation Loss: 0.6224
# Model 2 Validation Accuracy: 65.93%, Validation Loss: 0.5859
# Model 3 Validation Accuracy: 64.19%, Validation Loss: 0.6022
# Model 4 Validation Accuracy: 63.17%, Validation Loss: 0.6251
# Model 5 Validation Accuracy: 61.33%, Validation Loss: 0.7042
# Epoch [493/500], Model 1 Training Loss: 0.6291, Training Accuracy: 63.86%
# Epoch [493/500], Model 2 Training Loss: 0.5735, Training Accuracy: 67.12%
# Epoch [493/500], Model 3 Training Loss: 0.5436, Training Accuracy: 68.23%
# Epoch [493/500], Model 4 Training Loss: 0.5989, Training Accuracy: 65.68%
# Epoch [493/500], Model 5 Training Loss: 0.6232, Training Accuracy: 64.42%
# Model 1 Validation Accuracy: 64.37%, Validation Loss: 0.6127
# Model 2 Validation Accuracy: 65.00%, Validation Loss: 0.5928
# Model 3 Validation Accuracy: 67.57%, Validation Loss: 0.5897
# Model 4 Validation Accuracy: 62.94%, Validation Loss: 0.6327
# Model 5 Validation Accuracy: 62.74%, Validation Loss: 0.6971
# Epoch [494/500], Model 1 Training Loss: 0.6296, Training Accuracy: 64.34%
# Epoch [494/500], Model 2 Training Loss: 0.5748, Training Accuracy: 66.85%
# Epoch [494/500], Model 3 Training Loss: 0.5397, Training Accuracy: 68.74%
# Epoch [494/500], Model 4 Training Loss: 0.5919, Training Accuracy: 66.12%
# Epoch [494/500], Model 5 Training Loss: 0.6204, Training Accuracy: 64.91%
# Model 1 Validation Accuracy: 62.69%, Validation Loss: 0.6379
# Model 2 Validation Accuracy: 66.43%, Validation Loss: 0.5880
# Model 3 Validation Accuracy: 66.59%, Validation Loss: 0.6235
# Model 4 Validation Accuracy: 65.03%, Validation Loss: 0.6308
# Model 5 Validation Accuracy: 63.24%, Validation Loss: 0.6947
# Epoch [495/500], Model 1 Training Loss: 0.6217, Training Accuracy: 64.20%
# Epoch [495/500], Model 2 Training Loss: 0.5684, Training Accuracy: 67.54%
# Epoch [495/500], Model 3 Training Loss: 0.5275, Training Accuracy: 69.23%
# Epoch [495/500], Model 4 Training Loss: 0.5913, Training Accuracy: 66.11%
# Epoch [495/500], Model 5 Training Loss: 0.6186, Training Accuracy: 64.50%
# Model 1 Validation Accuracy: 63.74%, Validation Loss: 0.6265
# Model 2 Validation Accuracy: 66.32%, Validation Loss: 0.5868
# Model 3 Validation Accuracy: 67.82%, Validation Loss: 0.5784
# Model 4 Validation Accuracy: 64.89%, Validation Loss: 0.6075
# Model 5 Validation Accuracy: 63.85%, Validation Loss: 0.6945
# Epoch [496/500], Model 1 Training Loss: 0.6168, Training Accuracy: 64.92%
# Epoch [496/500], Model 2 Training Loss: 0.5594, Training Accuracy: 67.63%
# Epoch [496/500], Model 3 Training Loss: 0.5214, Training Accuracy: 69.59%
# Epoch [496/500], Model 4 Training Loss: 0.5803, Training Accuracy: 66.38%
# Epoch [496/500], Model 5 Training Loss: 0.6068, Training Accuracy: 65.14%
# Model 1 Validation Accuracy: 63.92%, Validation Loss: 0.6095
# Model 2 Validation Accuracy: 64.87%, Validation Loss: 0.5913
# Model 3 Validation Accuracy: 68.45%, Validation Loss: 0.5674
# Model 4 Validation Accuracy: 64.85%, Validation Loss: 0.5982
# Model 5 Validation Accuracy: 60.63%, Validation Loss: 0.7542
# Epoch [497/500], Model 1 Training Loss: 0.6060, Training Accuracy: 65.38%
# Epoch [497/500], Model 2 Training Loss: 0.5538, Training Accuracy: 67.87%
# Epoch [497/500], Model 3 Training Loss: 0.5083, Training Accuracy: 70.15%
# Epoch [497/500], Model 4 Training Loss: 0.5699, Training Accuracy: 66.96%
# Epoch [497/500], Model 5 Training Loss: 0.5986, Training Accuracy: 65.94%
# Model 1 Validation Accuracy: 65.96%, Validation Loss: 0.6031
# Model 2 Validation Accuracy: 65.75%, Validation Loss: 0.5835
# Model 3 Validation Accuracy: 69.42%, Validation Loss: 0.5501
# Model 4 Validation Accuracy: 65.37%, Validation Loss: 0.6100
# Model 5 Validation Accuracy: 62.49%, Validation Loss: 0.6751
# Epoch [498/500], Model 1 Training Loss: 0.5979, Training Accuracy: 65.50%
# Epoch [498/500], Model 2 Training Loss: 0.5501, Training Accuracy: 68.24%
# Epoch [498/500], Model 3 Training Loss: 0.4996, Training Accuracy: 71.08%
# Epoch [498/500], Model 4 Training Loss: 0.5606, Training Accuracy: 67.27%
# Epoch [498/500], Model 5 Training Loss: 0.5979, Training Accuracy: 66.18%
# Model 1 Validation Accuracy: 65.64%, Validation Loss: 0.5988
# Model 2 Validation Accuracy: 66.61%, Validation Loss: 0.5727
# Model 3 Validation Accuracy: 70.08%, Validation Loss: 0.5528
# Best model 3 saved with accuracy: 70.08%
# Model 4 Validation Accuracy: 66.18%, Validation Loss: 0.5925
# Model 5 Validation Accuracy: 63.21%, Validation Loss: 0.6817
# Epoch [499/500], Model 1 Training Loss: 0.5913, Training Accuracy: 65.49%
# Epoch [499/500], Model 2 Training Loss: 0.5522, Training Accuracy: 68.19%
# Epoch [499/500], Model 3 Training Loss: 0.4929, Training Accuracy: 71.61%
# Epoch [499/500], Model 4 Training Loss: 0.5573, Training Accuracy: 67.23%
# Epoch [499/500], Model 5 Training Loss: 0.5876, Training Accuracy: 66.37%
# Model 1 Validation Accuracy: 65.07%, Validation Loss: 0.5966
# Model 2 Validation Accuracy: 66.14%, Validation Loss: 0.5687
# Model 3 Validation Accuracy: 68.47%, Validation Loss: 0.5504
# Model 4 Validation Accuracy: 66.07%, Validation Loss: 0.5887
# Model 5 Validation Accuracy: 63.35%, Validation Loss: 0.6834
# Epoch [500/500], Model 1 Training Loss: 0.5898, Training Accuracy: 65.73%
# Epoch [500/500], Model 2 Training Loss: 0.5452, Training Accuracy: 68.14%
# Epoch [500/500], Model 3 Training Loss: 0.4898, Training Accuracy: 71.94%
# Epoch [500/500], Model 4 Training Loss: 0.5488, Training Accuracy: 67.62%
# Epoch [500/500], Model 5 Training Loss: 0.5836, Training Accuracy: 66.83%
# Model 1 Validation Accuracy: 65.73%, Validation Loss: 0.5939
# Model 2 Validation Accuracy: 66.86%, Validation Loss: 0.5705
# Model 3 Validation Accuracy: 69.13%, Validation Loss: 0.5491
# Model 4 Validation Accuracy: 65.82%, Validation Loss: 0.5894
# Model 5 Validation Accuracy: 63.51%, Validation Loss: 0.6842

# %% [markdown]
# ## 8. 슬라이딩 윈도우와 예측

# %%
# 학습된 모델 로드
for i, model in enumerate(models):
    checkpoint = torch.load(f'best_model_{i+1}.pth.tar')
    model.load_state_dict(checkpoint['state_dict'])
    model.eval()

# 자이로 데이터를 GPU로 이동
gyro_data_tensor = gyro_data_tensor.to(device)

print(f"gyro_data_tensor shape: {gyro_data_tensor.shape}")

# 예측
batch_size = 32
all_predictions = []

for i in range(0, len(gyro_data_tensor), batch_size):
    batch = gyro_data_tensor[i:i+batch_size]
    # 마지막 배치 처리
    if len(batch) < batch_size:
        padding = torch.zeros(batch_size - len(batch), *batch.shape[1:], device=device)
        batch = torch.cat([batch, padding], dim=0)
    batch_predictions = ensemble_predict(models, batch)
    # 패딩 제거
    all_predictions.append(batch_predictions[:len(gyro_data_tensor[i:i+batch_size])])

all_predictions = torch.cat(all_predictions).cpu().numpy()

# 슬라이딩 윈도우 예측 결과를 원본 데이터에 매핑하는 함수
def map_predictions_to_original(original_data_length, predictions, window_size, stride):
    mapped_predictions = np.zeros((original_data_length, 6))  # 6은 활동 클래스의 수
    counts = np.zeros(original_data_length)
    
    for i, pred in enumerate(predictions):
        start = i * stride
        end = min(start + window_size, original_data_length)
        mapped_predictions[start:end, pred] += 1
        counts[start:end] += 1
    
    # 각 데이터 포인트에 대해 가장 많이 예측된 라벨 선택
    final_predictions = np.argmax(mapped_predictions, axis=1)
    
    return final_predictions

# 원본 자이로 데이터 로드
original_gyro_data = pd.read_csv('./원본 데이터/자이로 데이터.csv')

# 원본 데이터에 맞는 예측 라벨 생성
original_predictions = map_predictions_to_original(len(original_gyro_data), all_predictions, window_size=128, stride=64)

# 예측된 라벨을 활동 이름으로 매핑
activity_labels = {0: "walking", 1: "walking_upstairs", 2: "walking_downstairs", 3: "sitting", 4: "standing", 5: "laying"}
predicted_activities = [activity_labels[label] for label in original_predictions]

# 예측 결과 출력
for i, activity in enumerate(predicted_activities[:10]):
    print(f"Sample {i}: {activity}")

# 자이로 데이터에 예측 결과 추가
original_gyro_data['Predicted_Activity'] = predicted_activities

# 결과 저장
original_gyro_data.to_csv('./원본 데이터/자이로 데이터_예측.csv', index=False)

# 예측 결과 시각화
plt.figure(figsize=(12, 6))
activity_counts = pd.Series(predicted_activities).value_counts()
sns.barplot(x=activity_counts.index, y=activity_counts.values)
plt.title('Predicted Activity Distribution')
plt.xlabel('Activity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 시간에 따른 활동 변화 시각화
plt.figure(figsize=(20, 6))
activity_series = pd.Series(predicted_activities)
activity_numeric = pd.factorize(activity_series)[0]
plt.plot(activity_numeric)
plt.title('Activity Changes Over Time')
plt.xlabel('Time')
plt.ylabel('Activity')
plt.yticks(range(len(activity_labels)), list(activity_labels.values()))
plt.tight_layout()
plt.show()

print("예측 완료 및 결과 저장됨")
# Out:
# gyro_data_tensor shape: torch.Size([46256, 128, 3])
# C:\Users\user\AppData\Local\Temp\ipykernel_9356\2412828865.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f'best_model_{i+1}.pth.tar')
# Sample 0: laying
# Sample 1: laying
# Sample 2: laying
# Sample 3: laying
# Sample 4: laying
# Sample 5: laying
# Sample 6: laying
# Sample 7: laying
# Sample 8: laying
# Sample 9: laying
# 예측 완료 및 결과 저장됨

# %% [markdown]
# ## 9. 성능 평가 및 시각화

# %%
# 자이로 데이터에 라벨 추가
gyro_data = pd.read_csv('./원본 데이터/자이로 데이터.csv')
gyro_data['Predicted_Activity'] = predicted_activities[:len(gyro_data)]  # 길이 맞춤

# 라벨링된 자이로 데이터를 저장
gyro_data.to_csv('./원본 데이터/자이로 데이터_예측.csv', index=False)

# 예측된 활동별 분포 시각화
plt.figure(figsize=(10, 6))
sns.countplot(x=gyro_data['Predicted_Activity'])
plt.title('Predicted Activity Distribution')
plt.xticks(rotation=45)
plt.show()

# 예측 결과 요약
print(gyro_data['Predicted_Activity'].value_counts(normalize=True))

# 클러스터링 적용 및 결과 비교
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans_labels = kmeans.fit_predict(gyro_data_tensor.cpu().numpy().reshape(gyro_data_tensor.shape[0], -1))

# 클러스터링 결과와 실제 예측 라벨 비교
kmeans_accuracy = accuracy_score(all_predictions, kmeans_labels)
print(f"K-Means Clustering Accuracy: {kmeans_accuracy:.2f}")

# Confusion Matrix 및 성능 평가
cm = confusion_matrix(all_predictions, kmeans_labels)
ConfusionMatrixDisplay(cm).plot()
plt.show()

print(classification_report(all_predictions, kmeans_labels))
# Out:
# Predicted_Activity
# walking               0.529322
# walking_upstairs      0.339262
# walking_downstairs    0.090493
# laying                0.039928
# sitting               0.000984
# standing              0.000011
# Name: proportion, dtype: float64
# K-Means Clustering Accuracy: 0.10
#               precision    recall  f1-score   support
#
#            0       0.05      0.44      0.09      1500
#            1       0.06      0.01      0.01     24278
#            2       0.30      0.11      0.16     15667
#            3       0.00      0.00      0.00       221
#            4       0.00      0.94      0.00        16
#            5       0.66      0.47      0.55      4574
#
#     accuracy                           0.10     46256
#    macro avg       0.18      0.33      0.14     46256
# weighted avg       0.20      0.10      0.12     46256
