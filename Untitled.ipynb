# %% [markdown]
# > UCI-HAR와 자이로 데이터 간의 차이를 줄이고, 자이로 데이터에 적합한 행동 라벨링을 추가

# %% [markdown]
# ## 1. 라이브러리 및 데이터셋 로드

# %%
# 1. 라이브러리 및 데이터셋 로드
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, f1_score
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from imblearn.over_sampling import RandomOverSampler
from scipy.signal import butter, filtfilt, resample

# GPU 사용 여부 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# GPU 사용 여부 확인
if torch.cuda.is_available():
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available.")
# Out:
# GPU is available: NVIDIA GeForce GTX 1650

# %% [markdown]
# ### 1. 저역통과 필터 및 데이터 전처리 함수 ###

# %%
# 저역통과 필터 적용
def butter_lowpass(cutoff, fs, order=4):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def apply_lowpass_filter(data, cutoff=10, fs=50):
    b, a = butter_lowpass(cutoff, fs)
    return filtfilt(b, a, data, axis=0)

# 데이터 정규화 및 차원 맞춤 함수
def normalize_and_reshape_segments(segments):
    scaler = MinMaxScaler()
    normalized_segments = np.zeros_like(segments)
    for axis in range(segments.shape[2]):
        normalized_segments[:, :, axis] = scaler.fit_transform(segments[:, :, axis])
    return normalized_segments

# 슬라이딩 윈도우 생성 함수
def create_sliding_windows(data, window_size=128, stride=64):
    num_windows = (len(data) - window_size) // stride + 1
    windows = np.array([data[i:i+window_size] for i in range(0, len(data) - window_size + 1, stride)])
    return windows  # (num_windows, window_size, 3) 형태로 반환

# %% [markdown]
# ### 2. UCI-HAR 데이터 로드 및 자이로 데이터 전처리 ###

# %%
# UCI-HAR 데이터 로드
def load_ucihar_data():
    uci_har_path = './원본 데이터/UCI HAR Dataset/'
    gyro_x_train = pd.read_csv(uci_har_path + 'train/Inertial Signals/body_gyro_x_train.txt', sep='\s+', header=None).values
    gyro_y_train = pd.read_csv(uci_har_path + 'train/Inertial Signals/body_gyro_y_train.txt', sep='\s+', header=None).values
    gyro_z_train = pd.read_csv(uci_har_path + 'train/Inertial Signals/body_gyro_z_train.txt', sep='\s+', header=None).values
    labels_train = pd.read_csv(uci_har_path + 'train/y_train.txt', sep='\s+', header=None).values - 1
    X_train = np.stack([gyro_x_train, gyro_y_train, gyro_z_train], axis=-1)
    X_train_normalized = normalize_and_reshape_segments(X_train)
    return X_train_normalized, labels_train

X_train, y_train = load_ucihar_data()

# 자이로 데이터 전처리 함수
def preprocess_gyro_data(gyro_path, current_freq=100, desired_freq=50, window_size=128, stride=64):
    gyro_data = pd.read_csv(gyro_path)
    n_samples = int(len(gyro_data) * desired_freq / current_freq)
    gyro_data_resampled = resample(gyro_data[['X', 'Y', 'Z']].values, n_samples)
    gyro_data_filtered = apply_lowpass_filter(gyro_data_resampled, cutoff=20, fs=desired_freq)
    gyro_data_windows = create_sliding_windows(gyro_data_filtered, window_size, stride)
    gyro_data_normalized = normalize_and_reshape_segments(gyro_data_windows)
    return torch.tensor(gyro_data_normalized, dtype=torch.float32)

gyro_data_tensor = preprocess_gyro_data('./원본 데이터/자이로 데이터.csv')

# 데이터를 Tensor로 변환
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
gyro_data_tensor = gyro_data_tensor.to(device)

# %% [markdown]
# ### 3. 데이터 증강 및 불균형 해결 ###

# %%
# 데이터 증강 함수: 가우시안 노이즈 추가
def add_gaussian_noise(data, noise_factor=0.05):
    noise = np.random.randn(*data.shape)
    augmented_data = data + noise_factor * noise
    augmented_data = np.clip(augmented_data, -1.0, 1.0)
    return augmented_data

def time_warp(data, sigma=0.2, knot=4):
    orig_steps = np.arange(data.shape[1])
    random_warps = np.random.normal(loc=1.0, scale=sigma, size=(data.shape[0], knot+2, data.shape[2]))
    warp_steps = (np.ones((data.shape[2],1))*(np.linspace(0, data.shape[1]-1., num=knot+2))).T
    ret = np.zeros_like(data)
    for i, pat in enumerate(data):
        warper = np.interp(orig_steps, warp_steps[:, 0], random_warps[i, :, 0])
        for dim in range(data.shape[2]):
            ret[i, :, dim] = np.interp(orig_steps, np.cumsum(warper), pat[:, dim])
    return ret

# 증강된 데이터 결합 및 불균형 데이터 해결
X_train_augmented = add_gaussian_noise(X_train)

# 증강된 데이터 결합
X_train_augmented = np.concatenate([
    X_train,
    add_gaussian_noise(X_train),
    time_warp(X_train)
], axis=0)

y_train_augmented = np.concatenate([y_train] * 3, axis=0)

# 클래스별 샘플 수 계산
class_sample_count = np.array([len(np.where(y_train_augmented == t)[0]) for t in np.unique(y_train_augmented)])

# 길이 확인 및 조정
min_length = min(len(X_train_augmented), len(y_train_augmented))
X_train_augmented = X_train_augmented[:min_length]
y_train_augmented = y_train_augmented[:min_length]

# 텐서로 변환
X_train_augmented_tensor = torch.tensor(X_train_augmented, dtype=torch.float32)
y_train_augmented_tensor = torch.tensor(y_train_augmented, dtype=torch.long)

# 학습/검증 데이터 분리
X_train_tensor, X_val_tensor, y_train_tensor, y_val_tensor = train_test_split(
    X_train_augmented_tensor, 
    y_train_augmented_tensor, 
    test_size=0.2,
    random_state=42,
)

# %% [markdown]
# ### 4. 데이터셋 및 모델 정의 ###

# %%
# 데이터셋 클래스
class UCIHARData(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx].view(-1)
    
train_dataset = UCIHARData(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = UCIHARData(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## 5. LSTM, GRU, CNN-LSTM, BiLSTM, Transformer 모델 정의 및 성능 개선(앙상블)

# %%
# LSTM 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(LSTMModel, self).__init__()
        self.input_size = input_size  # 추가
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.batch_norm = nn.BatchNorm1d(hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.batch_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out

# GRU 모델 정의
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(GRUModel, self).__init__()
        self.input_size = input_size  # 추가
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.batch_norm = nn.BatchNorm1d(hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.gru(x)
        out = self.batch_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out

# CNN-LSTM 모델 정의
class CNNLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(CNNLSTMModel, self).__init__()
        self.input_size = input_size  # 추가
        self.conv1 = nn.Conv1d(input_size, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.lstm = nn.LSTM(64, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.pool(F.relu(self.conv1(x)))
        x = x.permute(0, 2, 1)
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# BiLSTM 모델 정의
class BiLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_prob):
        super(BiLSTMModel, self).__init__()
        self.input_size = input_size  # 추가
        self.bilstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob, bidirectional=True)
        self.batch_norm = nn.BatchNorm1d(hidden_size * 2)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        out, _ = self.bilstm(x)
        out = self.batch_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out

# Transformer 모델 정의
class TransformerModel(nn.Module):
    def __init__(self, input_size, num_heads, num_layers, num_classes, dropout_prob):
        super(TransformerModel, self).__init__()
        self.input_size = input_size  # 추가
        self.input_embedding = nn.Linear(input_size, 128)
        self.positional_encoding = nn.Parameter(torch.randn(1, 200, 128))  # 시퀀스 길이가 100이라고 가정
        encoder_layer = nn.TransformerEncoderLayer(d_model=128, nhead=num_heads, dropout=dropout_prob)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        # x: (batch_size, seq_len, input_size) -> (seq_len, batch_size, input_size)
        x = self.input_embedding(x)
        x = x + self.positional_encoding[:, :x.size(1), :]
        x = self.transformer(x.permute(1, 0, 2))  # (seq_len, batch_size, d_model)
        out = self.fc(x[-1, :, :])  # 마지막 타임스텝의 출력만 사용
        return out

# %% [markdown]
# ## 6. 앙상블 모델 정의

# %%
# 입력 크기 정의
input_size = 3  # X, Y, Z 축

# 모델 정의
models = [
    LSTMModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    GRUModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    CNNLSTMModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    BiLSTMModel(input_size=input_size, hidden_size=128, num_layers=3, num_classes=6, dropout_prob=0.5).to(device),
    TransformerModel(input_size=input_size, num_heads=4, num_layers=2, num_classes=6, dropout_prob=0.5).to(device)
]

# 입력 크기 확인
print(f"Input size: {input_size}")
for i, model in enumerate(models):
    print(f"Model {i+1} input size: {model.input_size if hasattr(model, 'input_size') else 'N/A'}")

# 모델들의 예측값을 앙상블로 처리
# 앙상블 예측 함수
def ensemble_predict(models, X_unlabeled, weights=[1, 1, 1, 1, 1]):
    predictions = []
    X_unlabeled = X_unlabeled.to(device)
    for i, model in enumerate(models):
        model.eval()
        with torch.no_grad():
            outputs = model(X_unlabeled)
            predictions.append(weights[i] * torch.softmax(outputs, dim=1))
    
    final_predictions = torch.argmax(sum(predictions), dim=1)
    return final_predictions
# Out:
# Input size: 3
# Model 1 input size: 3
# Model 2 input size: 3
# Model 3 input size: 3
# Model 4 input size: 3
# Model 5 input size: 3
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\torch\nn\modules\transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# ## 7. 손실 함수, 옵티마이저, 스케줄러 및 모델 학습

# %%
# 클래스별 가중치 계산
class_weights = 1.0 / torch.tensor(class_sample_count, dtype=torch.float32)
class_weights = class_weights.to(device)

# 손실 함수 정의 (가중치 적용)
criterion = nn.CrossEntropyLoss(weight=class_weights)

# 각 모델별로 옵티마이저와 스케줄러 정의
optimizers = [
    torch.optim.Adam(model.parameters(), lr=0.00005, weight_decay=1e-4) for model in models
]

schedulers = [
    torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=0.0001) for optimizer in optimizers
]

# 모델 저장 함수
def save_checkpoint(epoch, model, optimizer, filename="checkpoint.pth.tar"):
    state = {'epoch': epoch, 'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()}
    torch.save(state, filename)

best_val_accuracy = 0.0

# 모델 학습 함수
def train_model(models, train_loader, val_loader, criterion, optimizers, schedulers, num_epochs=50, patience=100):
    global best_val_accuracy
    early_stop_counter = 0
    
    for epoch in range(num_epochs):
        for model in models:
            model.train()
        
        running_loss = [0.0] * len(models)
        correct = [0] * len(models)
        total = 0
        
        # Training loop
        for i, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.to(device)
           # 수정 코드
            labels = labels.to(device).squeeze()  # 1D로 변환
            total += labels.size(0)

            # 각 모델별 학습
            for j, model in enumerate(models):
                optimizers[j].zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # 그래디언트 클리핑 추가
                optimizers[j].step()
                
                running_loss[j] += loss.item()
                _, predicted = torch.max(outputs, 1)
                correct[j] += (predicted.cpu() == labels.cpu()).sum().item()

        # Training accuracy and loss
        for j, model in enumerate(models):
            accuracy = 100 * correct[j] / total
            print(f"Epoch [{epoch+1}/{num_epochs}], Model {j+1} Training Loss: {running_loss[j]/len(train_loader):.4f}, Training Accuracy: {accuracy:.2f}%")
        
        # Validation loop
        for model in models:
            model.eval()
        
        val_loss = [0.0] * len(models)
        val_correct = [0] * len(models)
        val_total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                # 수정 코드
                labels = labels.to(device).squeeze()
                val_total += labels.size(0)

                for j, model in enumerate(models):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    val_loss[j] += loss.item()

                    _, predicted = torch.max(outputs, 1)
                    val_correct[j] += (predicted.cpu() == labels.cpu()).sum().item()

        # Validation accuracy and loss
        for j, model in enumerate(models):
            val_accuracy = (val_correct[j] / val_total) * 100
            val_loss[j] = val_loss[j] / len(val_loader)

            print(f"Model {j+1} Validation Accuracy: {val_accuracy:.2f}%, Validation Loss: {val_loss[j]:.4f}")

            # 스케줄러 갱신
            schedulers[j].step()

            # Save best model
            if val_accuracy > best_val_accuracy:
                best_val_accuracy = val_accuracy
                save_checkpoint(epoch, model, optimizers[j], filename=f"best_model_{j+1}.pth.tar")
                print(f"Best model {j+1} saved with accuracy: {best_val_accuracy:.2f}%")
                early_stop_counter = 0
            else:
                early_stop_counter += 1

        # Early stopping
        if early_stop_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

        torch.cuda.empty_cache()

# 모델 학습 실행
train_model(models, train_loader, val_loader, criterion, optimizers, schedulers, num_epochs=100)
# Out:
# C:\Users\user\anaconda3\envs\ai\lib\site-packages\torch\nn\functional.py:5560: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch [1/100], Model 1 Training Loss: 1.9396, Training Accuracy: 16.39%
# Epoch [1/100], Model 2 Training Loss: 1.9878, Training Accuracy: 17.34%
# Epoch [1/100], Model 3 Training Loss: 1.7923, Training Accuracy: 14.85%
# Epoch [1/100], Model 4 Training Loss: 1.9739, Training Accuracy: 16.53%
# Epoch [1/100], Model 5 Training Loss: 1.8277, Training Accuracy: 16.99%
# Model 1 Validation Accuracy: 19.51%, Validation Loss: 1.7919
# Best model 1 saved with accuracy: 19.51%
# Model 2 Validation Accuracy: 22.62%, Validation Loss: 1.7926
# Best model 2 saved with accuracy: 22.62%
# Model 3 Validation Accuracy: 16.07%, Validation Loss: 1.7920
# Model 4 Validation Accuracy: 18.63%, Validation Loss: 1.7923
# Model 5 Validation Accuracy: 21.31%, Validation Loss: 1.7944
# Epoch [2/100], Model 1 Training Loss: 1.8867, Training Accuracy: 16.63%
# Epoch [2/100], Model 2 Training Loss: 1.9264, Training Accuracy: 16.91%
# Epoch [2/100], Model 3 Training Loss: 1.7918, Training Accuracy: 16.59%
# Epoch [2/100], Model 4 Training Loss: 1.9146, Training Accuracy: 16.75%
# Epoch [2/100], Model 5 Training Loss: 1.8177, Training Accuracy: 16.68%
# Model 1 Validation Accuracy: 19.74%, Validation Loss: 1.7922
# Model 2 Validation Accuracy: 13.24%, Validation Loss: 1.7917
# Model 3 Validation Accuracy: 22.08%, Validation Loss: 1.7918
# Model 4 Validation Accuracy: 10.79%, Validation Loss: 1.7919
# Model 5 Validation Accuracy: 18.04%, Validation Loss: 1.7926
# Epoch [3/100], Model 1 Training Loss: 1.8570, Training Accuracy: 17.10%
# Epoch [3/100], Model 2 Training Loss: 1.9028, Training Accuracy: 16.48%
# Epoch [3/100], Model 3 Training Loss: 1.7828, Training Accuracy: 18.52%
# Epoch [3/100], Model 4 Training Loss: 1.8852, Training Accuracy: 16.50%
# Epoch [3/100], Model 5 Training Loss: 1.8098, Training Accuracy: 17.12%
# Model 1 Validation Accuracy: 19.70%, Validation Loss: 1.7918
# Model 2 Validation Accuracy: 14.60%, Validation Loss: 1.7915
# Model 3 Validation Accuracy: 24.93%, Validation Loss: 1.6443
# Best model 3 saved with accuracy: 24.93%
# Model 4 Validation Accuracy: 22.60%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 15.39%, Validation Loss: 1.7927
# Epoch [4/100], Model 1 Training Loss: 1.8325, Training Accuracy: 16.87%
# Epoch [4/100], Model 2 Training Loss: 1.8786, Training Accuracy: 16.90%
# Epoch [4/100], Model 3 Training Loss: 1.5172, Training Accuracy: 28.05%
# Epoch [4/100], Model 4 Training Loss: 1.8605, Training Accuracy: 17.33%
# Epoch [4/100], Model 5 Training Loss: 1.8086, Training Accuracy: 16.57%
# Model 1 Validation Accuracy: 13.64%, Validation Loss: 1.7913
# Model 2 Validation Accuracy: 12.90%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 29.13%, Validation Loss: 1.3938
# Best model 3 saved with accuracy: 29.13%
# Model 4 Validation Accuracy: 11.99%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 14.96%, Validation Loss: 1.7944
# Epoch [5/100], Model 1 Training Loss: 1.8251, Training Accuracy: 16.44%
# Epoch [5/100], Model 2 Training Loss: 1.8649, Training Accuracy: 16.76%
# Epoch [5/100], Model 3 Training Loss: 1.3616, Training Accuracy: 30.03%
# Epoch [5/100], Model 4 Training Loss: 1.8454, Training Accuracy: 17.30%
# Epoch [5/100], Model 5 Training Loss: 1.8059, Training Accuracy: 16.34%
# Model 1 Validation Accuracy: 17.48%, Validation Loss: 1.7918
# Model 2 Validation Accuracy: 14.53%, Validation Loss: 1.7913
# Model 3 Validation Accuracy: 31.23%, Validation Loss: 1.2332
# Best model 3 saved with accuracy: 31.23%
# Model 4 Validation Accuracy: 20.85%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 14.94%, Validation Loss: 1.7918
# Epoch [6/100], Model 1 Training Loss: 1.8150, Training Accuracy: 16.62%
# Epoch [6/100], Model 2 Training Loss: 1.8510, Training Accuracy: 16.62%
# Epoch [6/100], Model 3 Training Loss: 1.2757, Training Accuracy: 30.94%
# Epoch [6/100], Model 4 Training Loss: 1.8365, Training Accuracy: 16.66%
# Epoch [6/100], Model 5 Training Loss: 1.8020, Training Accuracy: 16.77%
# Model 1 Validation Accuracy: 25.45%, Validation Loss: 1.7912
# Model 2 Validation Accuracy: 14.26%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 30.76%, Validation Loss: 1.2538
# Model 4 Validation Accuracy: 24.34%, Validation Loss: 1.7911
# Model 5 Validation Accuracy: 16.07%, Validation Loss: 1.7911
# Epoch [7/100], Model 1 Training Loss: 1.8074, Training Accuracy: 16.98%
# Epoch [7/100], Model 2 Training Loss: 1.8449, Training Accuracy: 16.44%
# Epoch [7/100], Model 3 Training Loss: 1.2097, Training Accuracy: 33.74%
# Epoch [7/100], Model 4 Training Loss: 1.8269, Training Accuracy: 16.99%
# Epoch [7/100], Model 5 Training Loss: 1.7994, Training Accuracy: 16.78%
# Model 1 Validation Accuracy: 23.19%, Validation Loss: 1.7915
# Model 2 Validation Accuracy: 25.61%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 38.87%, Validation Loss: 1.1219
# Best model 3 saved with accuracy: 38.87%
# Model 4 Validation Accuracy: 20.06%, Validation Loss: 1.7918
# Model 5 Validation Accuracy: 20.78%, Validation Loss: 1.7931
# Epoch [8/100], Model 1 Training Loss: 1.8048, Training Accuracy: 16.23%
# Epoch [8/100], Model 2 Training Loss: 1.8376, Training Accuracy: 16.50%
# Epoch [8/100], Model 3 Training Loss: 1.1986, Training Accuracy: 36.37%
# Epoch [8/100], Model 4 Training Loss: 1.8144, Training Accuracy: 17.01%
# Epoch [8/100], Model 5 Training Loss: 1.7999, Training Accuracy: 16.31%
# Model 1 Validation Accuracy: 24.09%, Validation Loss: 1.7914
# Model 2 Validation Accuracy: 24.14%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 35.27%, Validation Loss: 1.3295
# Model 4 Validation Accuracy: 22.42%, Validation Loss: 1.7916
# Model 5 Validation Accuracy: 13.98%, Validation Loss: 1.7938
# Epoch [9/100], Model 1 Training Loss: 1.7991, Training Accuracy: 17.13%
# Epoch [9/100], Model 2 Training Loss: 1.8268, Training Accuracy: 17.05%
# Epoch [9/100], Model 3 Training Loss: 1.1887, Training Accuracy: 36.43%
# Epoch [9/100], Model 4 Training Loss: 1.8109, Training Accuracy: 16.66%
# Epoch [9/100], Model 5 Training Loss: 1.7601, Training Accuracy: 20.95%
# Model 1 Validation Accuracy: 14.51%, Validation Loss: 1.7915
# Model 2 Validation Accuracy: 23.64%, Validation Loss: 1.7913
# Model 3 Validation Accuracy: 35.43%, Validation Loss: 1.1698
# Model 4 Validation Accuracy: 23.71%, Validation Loss: 1.7918
# Model 5 Validation Accuracy: 36.90%, Validation Loss: 1.4273
# Epoch [10/100], Model 1 Training Loss: 1.7994, Training Accuracy: 16.99%
# Epoch [10/100], Model 2 Training Loss: 1.8190, Training Accuracy: 16.97%
# Epoch [10/100], Model 3 Training Loss: 1.1938, Training Accuracy: 37.38%
# Epoch [10/100], Model 4 Training Loss: 1.8078, Training Accuracy: 16.56%
# Epoch [10/100], Model 5 Training Loss: 1.4049, Training Accuracy: 31.91%
# Model 1 Validation Accuracy: 13.37%, Validation Loss: 1.7915
# Model 2 Validation Accuracy: 16.00%, Validation Loss: 1.7909
# Model 3 Validation Accuracy: 37.74%, Validation Loss: 1.1119
# Model 4 Validation Accuracy: 21.46%, Validation Loss: 1.7911
# Model 5 Validation Accuracy: 33.36%, Validation Loss: 1.2961
# Epoch [11/100], Model 1 Training Loss: 1.7981, Training Accuracy: 16.92%
# Epoch [11/100], Model 2 Training Loss: 1.8155, Training Accuracy: 16.61%
# Epoch [11/100], Model 3 Training Loss: 1.1790, Training Accuracy: 37.24%
# Epoch [11/100], Model 4 Training Loss: 1.8031, Training Accuracy: 17.05%
# Epoch [11/100], Model 5 Training Loss: 1.3078, Training Accuracy: 33.73%
# Model 1 Validation Accuracy: 21.03%, Validation Loss: 1.7915
# Model 2 Validation Accuracy: 24.39%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 37.83%, Validation Loss: 1.2487
# Model 4 Validation Accuracy: 19.22%, Validation Loss: 1.7914
# Model 5 Validation Accuracy: 38.60%, Validation Loss: 1.2201
# Epoch [12/100], Model 1 Training Loss: 1.7961, Training Accuracy: 17.22%
# Epoch [12/100], Model 2 Training Loss: 1.8114, Training Accuracy: 16.46%
# Epoch [12/100], Model 3 Training Loss: 1.1471, Training Accuracy: 38.56%
# Epoch [12/100], Model 4 Training Loss: 1.8001, Training Accuracy: 17.46%
# Epoch [12/100], Model 5 Training Loss: 1.2712, Training Accuracy: 33.51%
# Model 1 Validation Accuracy: 25.45%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 24.77%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 39.51%, Validation Loss: 1.1188
# Best model 3 saved with accuracy: 39.51%
# Model 4 Validation Accuracy: 13.89%, Validation Loss: 1.7917
# Model 5 Validation Accuracy: 37.58%, Validation Loss: 1.2245
# Epoch [13/100], Model 1 Training Loss: 1.7963, Training Accuracy: 17.46%
# Epoch [13/100], Model 2 Training Loss: 1.8089, Training Accuracy: 16.32%
# Epoch [13/100], Model 3 Training Loss: 1.1488, Training Accuracy: 38.91%
# Epoch [13/100], Model 4 Training Loss: 1.7998, Training Accuracy: 17.05%
# Epoch [13/100], Model 5 Training Loss: 1.2389, Training Accuracy: 35.28%
# Model 1 Validation Accuracy: 22.44%, Validation Loss: 1.7909
# Model 2 Validation Accuracy: 23.59%, Validation Loss: 1.7913
# Model 3 Validation Accuracy: 40.59%, Validation Loss: 1.1157
# Best model 3 saved with accuracy: 40.59%
# Model 4 Validation Accuracy: 23.21%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 39.08%, Validation Loss: 1.1879
# Epoch [14/100], Model 1 Training Loss: 1.7953, Training Accuracy: 17.80%
# Epoch [14/100], Model 2 Training Loss: 1.8046, Training Accuracy: 16.92%
# Epoch [14/100], Model 3 Training Loss: 1.1560, Training Accuracy: 38.31%
# Epoch [14/100], Model 4 Training Loss: 1.7982, Training Accuracy: 17.15%
# Epoch [14/100], Model 5 Training Loss: 1.2165, Training Accuracy: 37.10%
# Model 1 Validation Accuracy: 23.82%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.63%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 39.32%, Validation Loss: 1.2109
# Model 4 Validation Accuracy: 18.68%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 42.07%, Validation Loss: 1.1871
# Best model 5 saved with accuracy: 42.07%
# Epoch [15/100], Model 1 Training Loss: 1.7948, Training Accuracy: 17.29%
# Epoch [15/100], Model 2 Training Loss: 1.8035, Training Accuracy: 17.01%
# Epoch [15/100], Model 3 Training Loss: 1.1389, Training Accuracy: 39.49%
# Epoch [15/100], Model 4 Training Loss: 1.7963, Training Accuracy: 17.51%
# Epoch [15/100], Model 5 Training Loss: 1.1919, Training Accuracy: 38.68%
# Model 1 Validation Accuracy: 26.22%, Validation Loss: 1.7909
# Model 2 Validation Accuracy: 24.59%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 41.12%, Validation Loss: 1.1007
# Model 4 Validation Accuracy: 13.69%, Validation Loss: 1.7915
# Model 5 Validation Accuracy: 42.20%, Validation Loss: 1.1363
# Best model 5 saved with accuracy: 42.20%
# Epoch [16/100], Model 1 Training Loss: 1.7943, Training Accuracy: 17.09%
# Epoch [16/100], Model 2 Training Loss: 1.8028, Training Accuracy: 16.25%
# Epoch [16/100], Model 3 Training Loss: 1.1396, Training Accuracy: 39.29%
# Epoch [16/100], Model 4 Training Loss: 1.7961, Training Accuracy: 17.60%
# Epoch [16/100], Model 5 Training Loss: 1.1527, Training Accuracy: 41.44%
# Model 1 Validation Accuracy: 23.55%, Validation Loss: 1.7911
# Model 2 Validation Accuracy: 25.75%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 35.36%, Validation Loss: 1.1953
# Model 4 Validation Accuracy: 22.53%, Validation Loss: 1.7911
# Model 5 Validation Accuracy: 41.59%, Validation Loss: 1.1013
# Epoch [17/100], Model 1 Training Loss: 1.7937, Training Accuracy: 17.43%
# Epoch [17/100], Model 2 Training Loss: 1.7984, Training Accuracy: 16.77%
# Epoch [17/100], Model 3 Training Loss: 1.1253, Training Accuracy: 39.83%
# Epoch [17/100], Model 4 Training Loss: 1.7945, Training Accuracy: 17.62%
# Epoch [17/100], Model 5 Training Loss: 1.0930, Training Accuracy: 44.34%
# Model 1 Validation Accuracy: 22.35%, Validation Loss: 1.7905
# Model 2 Validation Accuracy: 26.36%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 40.14%, Validation Loss: 1.0767
# Model 4 Validation Accuracy: 13.35%, Validation Loss: 1.7911
# Model 5 Validation Accuracy: 46.12%, Validation Loss: 1.0501
# Best model 5 saved with accuracy: 46.12%
# Epoch [18/100], Model 1 Training Loss: 1.7933, Training Accuracy: 17.84%
# Epoch [18/100], Model 2 Training Loss: 1.7977, Training Accuracy: 16.80%
# Epoch [18/100], Model 3 Training Loss: 1.1091, Training Accuracy: 40.93%
# Epoch [18/100], Model 4 Training Loss: 1.7959, Training Accuracy: 17.62%
# Epoch [18/100], Model 5 Training Loss: 1.0694, Training Accuracy: 45.61%
# Model 1 Validation Accuracy: 16.16%, Validation Loss: 1.7908
# Model 2 Validation Accuracy: 24.93%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 41.59%, Validation Loss: 1.1100
# Model 4 Validation Accuracy: 16.57%, Validation Loss: 1.7912
# Model 5 Validation Accuracy: 44.61%, Validation Loss: 1.0374
# Epoch [19/100], Model 1 Training Loss: 1.7936, Training Accuracy: 17.77%
# Epoch [19/100], Model 2 Training Loss: 1.7988, Training Accuracy: 16.86%
# Epoch [19/100], Model 3 Training Loss: 1.1020, Training Accuracy: 40.38%
# Epoch [19/100], Model 4 Training Loss: 1.7956, Training Accuracy: 17.14%
# Epoch [19/100], Model 5 Training Loss: 1.0577, Training Accuracy: 45.51%
# Model 1 Validation Accuracy: 23.32%, Validation Loss: 1.7906
# Model 2 Validation Accuracy: 24.50%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 41.30%, Validation Loss: 1.0853
# Model 4 Validation Accuracy: 16.48%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 47.57%, Validation Loss: 1.0221
# Best model 5 saved with accuracy: 47.57%
# Epoch [20/100], Model 1 Training Loss: 1.7929, Training Accuracy: 18.27%
# Epoch [20/100], Model 2 Training Loss: 1.7982, Training Accuracy: 16.80%
# Epoch [20/100], Model 3 Training Loss: 1.1006, Training Accuracy: 41.06%
# Epoch [20/100], Model 4 Training Loss: 1.7928, Training Accuracy: 18.47%
# Epoch [20/100], Model 5 Training Loss: 1.0448, Training Accuracy: 46.16%
# Model 1 Validation Accuracy: 23.32%, Validation Loss: 1.7907
# Model 2 Validation Accuracy: 23.98%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 41.75%, Validation Loss: 1.0882
# Model 4 Validation Accuracy: 22.42%, Validation Loss: 1.7912
# Model 5 Validation Accuracy: 45.63%, Validation Loss: 1.0203
# Epoch [21/100], Model 1 Training Loss: 1.7910, Training Accuracy: 18.54%
# Epoch [21/100], Model 2 Training Loss: 1.7967, Training Accuracy: 16.87%
# Epoch [21/100], Model 3 Training Loss: 1.1143, Training Accuracy: 40.21%
# Epoch [21/100], Model 4 Training Loss: 1.7938, Training Accuracy: 17.84%
# Epoch [21/100], Model 5 Training Loss: 1.0456, Training Accuracy: 46.47%
# Model 1 Validation Accuracy: 24.73%, Validation Loss: 1.7905
# Model 2 Validation Accuracy: 23.84%, Validation Loss: 1.7912
# Model 3 Validation Accuracy: 40.41%, Validation Loss: 1.1109
# Model 4 Validation Accuracy: 20.56%, Validation Loss: 1.7911
# Model 5 Validation Accuracy: 46.71%, Validation Loss: 1.0156
# Epoch [22/100], Model 1 Training Loss: 1.7917, Training Accuracy: 18.52%
# Epoch [22/100], Model 2 Training Loss: 1.7962, Training Accuracy: 16.87%
# Epoch [22/100], Model 3 Training Loss: 1.1025, Training Accuracy: 40.84%
# Epoch [22/100], Model 4 Training Loss: 1.7930, Training Accuracy: 18.17%
# Epoch [22/100], Model 5 Training Loss: 1.0411, Training Accuracy: 46.21%
# Model 1 Validation Accuracy: 16.07%, Validation Loss: 1.7905
# Model 2 Validation Accuracy: 21.74%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 42.41%, Validation Loss: 1.0642
# Model 4 Validation Accuracy: 14.60%, Validation Loss: 1.7913
# Model 5 Validation Accuracy: 47.19%, Validation Loss: 1.0249
# Epoch [23/100], Model 1 Training Loss: 1.7910, Training Accuracy: 18.45%
# Epoch [23/100], Model 2 Training Loss: 1.7960, Training Accuracy: 17.01%
# Epoch [23/100], Model 3 Training Loss: 1.1011, Training Accuracy: 40.85%
# Epoch [23/100], Model 4 Training Loss: 1.7944, Training Accuracy: 17.29%
# Epoch [23/100], Model 5 Training Loss: 1.0382, Training Accuracy: 46.25%
# Model 1 Validation Accuracy: 16.84%, Validation Loss: 1.7899
# Model 2 Validation Accuracy: 23.23%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 39.66%, Validation Loss: 1.1869
# Model 4 Validation Accuracy: 14.78%, Validation Loss: 1.7912
# Model 5 Validation Accuracy: 47.44%, Validation Loss: 1.0211
# Epoch [24/100], Model 1 Training Loss: 1.7895, Training Accuracy: 18.61%
# Epoch [24/100], Model 2 Training Loss: 1.7952, Training Accuracy: 17.56%
# Epoch [24/100], Model 3 Training Loss: 1.1113, Training Accuracy: 40.36%
# Epoch [24/100], Model 4 Training Loss: 1.7941, Training Accuracy: 18.19%
# Epoch [24/100], Model 5 Training Loss: 1.0370, Training Accuracy: 46.31%
# Model 1 Validation Accuracy: 18.06%, Validation Loss: 1.7882
# Model 2 Validation Accuracy: 25.32%, Validation Loss: 1.7910
# Model 3 Validation Accuracy: 40.48%, Validation Loss: 1.0768
# Model 4 Validation Accuracy: 22.26%, Validation Loss: 1.7911
# Model 5 Validation Accuracy: 48.44%, Validation Loss: 1.0059
# Best model 5 saved with accuracy: 48.44%
# Epoch [25/100], Model 1 Training Loss: 1.7853, Training Accuracy: 20.00%
# Epoch [25/100], Model 2 Training Loss: 1.7958, Training Accuracy: 16.99%
# Epoch [25/100], Model 3 Training Loss: 1.1093, Training Accuracy: 40.80%
# Epoch [25/100], Model 4 Training Loss: 1.7934, Training Accuracy: 18.07%
# Epoch [25/100], Model 5 Training Loss: 1.0314, Training Accuracy: 46.38%
# Model 1 Validation Accuracy: 14.96%, Validation Loss: 1.7962
# Model 2 Validation Accuracy: 24.61%, Validation Loss: 1.7909
# Model 3 Validation Accuracy: 40.50%, Validation Loss: 1.1126
# Model 4 Validation Accuracy: 23.07%, Validation Loss: 1.7909
# Model 5 Validation Accuracy: 48.07%, Validation Loss: 1.0057
# Epoch [26/100], Model 1 Training Loss: 1.8085, Training Accuracy: 18.44%
# Epoch [26/100], Model 2 Training Loss: 1.7928, Training Accuracy: 17.33%
# Epoch [26/100], Model 3 Training Loss: 1.0970, Training Accuracy: 41.13%
# Epoch [26/100], Model 4 Training Loss: 1.7931, Training Accuracy: 18.45%
# Epoch [26/100], Model 5 Training Loss: 1.0331, Training Accuracy: 47.53%
# Model 1 Validation Accuracy: 27.92%, Validation Loss: 1.7637
# Model 2 Validation Accuracy: 23.59%, Validation Loss: 1.7911
# Model 3 Validation Accuracy: 43.00%, Validation Loss: 1.0688
# Model 4 Validation Accuracy: 22.21%, Validation Loss: 1.7910
# Model 5 Validation Accuracy: 48.21%, Validation Loss: 0.9960
# Epoch [27/100], Model 1 Training Loss: 1.7051, Training Accuracy: 25.02%
# Epoch [27/100], Model 2 Training Loss: 1.7929, Training Accuracy: 17.80%
# Epoch [27/100], Model 3 Training Loss: 1.1043, Training Accuracy: 41.20%
# Epoch [27/100], Model 4 Training Loss: 1.7918, Training Accuracy: 18.43%
# Epoch [27/100], Model 5 Training Loss: 1.0244, Training Accuracy: 47.29%
# Model 1 Validation Accuracy: 25.32%, Validation Loss: 1.7003
# Model 2 Validation Accuracy: 25.25%, Validation Loss: 1.7908
# Model 3 Validation Accuracy: 40.53%, Validation Loss: 1.0676
# Model 4 Validation Accuracy: 18.11%, Validation Loss: 1.7912
# Model 5 Validation Accuracy: 49.05%, Validation Loss: 0.9906
# Best model 5 saved with accuracy: 49.05%
# Epoch [28/100], Model 1 Training Loss: 1.5469, Training Accuracy: 29.80%
# Epoch [28/100], Model 2 Training Loss: 1.7935, Training Accuracy: 17.64%
# Epoch [28/100], Model 3 Training Loss: 1.1211, Training Accuracy: 40.65%
# Epoch [28/100], Model 4 Training Loss: 1.7915, Training Accuracy: 18.86%
# Epoch [28/100], Model 5 Training Loss: 1.0194, Training Accuracy: 47.95%
# Model 1 Validation Accuracy: 31.62%, Validation Loss: 1.4317
# Model 2 Validation Accuracy: 21.33%, Validation Loss: 1.7908
# Model 3 Validation Accuracy: 41.18%, Validation Loss: 1.0712
# Model 4 Validation Accuracy: 15.57%, Validation Loss: 1.7894
# Model 5 Validation Accuracy: 48.32%, Validation Loss: 0.9906
# Epoch [29/100], Model 1 Training Loss: 1.3960, Training Accuracy: 31.61%
# Epoch [29/100], Model 2 Training Loss: 1.7927, Training Accuracy: 17.79%
# Epoch [29/100], Model 3 Training Loss: 1.1133, Training Accuracy: 40.87%
# Epoch [29/100], Model 4 Training Loss: 1.8044, Training Accuracy: 17.38%
# Epoch [29/100], Model 5 Training Loss: 1.0165, Training Accuracy: 47.35%
# Model 1 Validation Accuracy: 34.63%, Validation Loss: 1.2990
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7957
# Model 3 Validation Accuracy: 36.02%, Validation Loss: 1.2463
# Model 4 Validation Accuracy: 16.07%, Validation Loss: 1.7924
# Model 5 Validation Accuracy: 48.96%, Validation Loss: 0.9767
# Epoch [30/100], Model 1 Training Loss: 1.3242, Training Accuracy: 32.06%
# Epoch [30/100], Model 2 Training Loss: 1.7953, Training Accuracy: 16.46%
# Epoch [30/100], Model 3 Training Loss: 1.1203, Training Accuracy: 40.47%
# Epoch [30/100], Model 4 Training Loss: 1.7976, Training Accuracy: 18.01%
# Epoch [30/100], Model 5 Training Loss: 1.0089, Training Accuracy: 47.74%
# Model 1 Validation Accuracy: 33.36%, Validation Loss: 1.2534
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7928
# Model 3 Validation Accuracy: 39.87%, Validation Loss: 1.1096
# Model 4 Validation Accuracy: 14.55%, Validation Loss: 1.7925
# Model 5 Validation Accuracy: 49.59%, Validation Loss: 0.9673
# Best model 5 saved with accuracy: 49.59%
# Epoch [31/100], Model 1 Training Loss: 1.2452, Training Accuracy: 34.91%
# Epoch [31/100], Model 2 Training Loss: 1.7948, Training Accuracy: 16.58%
# Epoch [31/100], Model 3 Training Loss: 1.1058, Training Accuracy: 40.84%
# Epoch [31/100], Model 4 Training Loss: 1.8022, Training Accuracy: 16.61%
# Epoch [31/100], Model 5 Training Loss: 1.0054, Training Accuracy: 48.11%
# Model 1 Validation Accuracy: 34.84%, Validation Loss: 1.1964
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7922
# Model 3 Validation Accuracy: 42.25%, Validation Loss: 1.0561
# Model 4 Validation Accuracy: 16.07%, Validation Loss: 1.7921
# Model 5 Validation Accuracy: 49.77%, Validation Loss: 0.9640
# Best model 5 saved with accuracy: 49.77%
# Epoch [32/100], Model 1 Training Loss: 1.2174, Training Accuracy: 34.70%
# Epoch [32/100], Model 2 Training Loss: 1.7939, Training Accuracy: 16.86%
# Epoch [32/100], Model 3 Training Loss: 1.1061, Training Accuracy: 40.38%
# Epoch [32/100], Model 4 Training Loss: 1.7998, Training Accuracy: 17.13%
# Epoch [32/100], Model 5 Training Loss: 1.0005, Training Accuracy: 48.34%
# Model 1 Validation Accuracy: 39.17%, Validation Loss: 1.2213
# Model 2 Validation Accuracy: 11.99%, Validation Loss: 1.7903
# Model 3 Validation Accuracy: 41.55%, Validation Loss: 1.0531
# Model 4 Validation Accuracy: 15.98%, Validation Loss: 1.7919
# Model 5 Validation Accuracy: 49.68%, Validation Loss: 0.9667
# Epoch [33/100], Model 1 Training Loss: 1.2035, Training Accuracy: 35.92%
# Epoch [33/100], Model 2 Training Loss: 1.7927, Training Accuracy: 16.89%
# Epoch [33/100], Model 3 Training Loss: 1.0991, Training Accuracy: 41.54%
# Epoch [33/100], Model 4 Training Loss: 1.7954, Training Accuracy: 17.76%
# Epoch [33/100], Model 5 Training Loss: 0.9969, Training Accuracy: 48.89%
# Model 1 Validation Accuracy: 37.28%, Validation Loss: 1.1700
# Model 2 Validation Accuracy: 14.96%, Validation Loss: 1.7931
# Model 3 Validation Accuracy: 36.22%, Validation Loss: 1.2047
# Model 4 Validation Accuracy: 14.98%, Validation Loss: 1.7920
# Model 5 Validation Accuracy: 50.18%, Validation Loss: 0.9744
# Best model 5 saved with accuracy: 50.18%
# Epoch [34/100], Model 1 Training Loss: 1.1874, Training Accuracy: 37.67%
# Epoch [34/100], Model 2 Training Loss: 1.7946, Training Accuracy: 16.36%
# Epoch [34/100], Model 3 Training Loss: 1.0983, Training Accuracy: 42.12%
# Epoch [34/100], Model 4 Training Loss: 1.7951, Training Accuracy: 17.69%
# Epoch [34/100], Model 5 Training Loss: 0.9873, Training Accuracy: 49.30%
# Model 1 Validation Accuracy: 41.12%, Validation Loss: 1.1873
# Model 2 Validation Accuracy: 11.74%, Validation Loss: 1.7922
# Model 3 Validation Accuracy: 41.68%, Validation Loss: 1.0646
# Model 4 Validation Accuracy: 15.00%, Validation Loss: 1.7921
# Model 5 Validation Accuracy: 45.92%, Validation Loss: 1.0817
# Epoch [35/100], Model 1 Training Loss: 1.1568, Training Accuracy: 40.98%
# Epoch [35/100], Model 2 Training Loss: 1.7640, Training Accuracy: 22.09%
# Epoch [35/100], Model 3 Training Loss: 1.0807, Training Accuracy: 42.14%
# Epoch [35/100], Model 4 Training Loss: 1.7992, Training Accuracy: 16.43%
# Epoch [35/100], Model 5 Training Loss: 0.9770, Training Accuracy: 50.27%
# Model 1 Validation Accuracy: 45.15%, Validation Loss: 1.1008
# Model 2 Validation Accuracy: 26.70%, Validation Loss: 1.6987
# Model 3 Validation Accuracy: 41.41%, Validation Loss: 1.0945
# Model 4 Validation Accuracy: 16.98%, Validation Loss: 1.7920
# Model 5 Validation Accuracy: 50.61%, Validation Loss: 0.9587
# Best model 5 saved with accuracy: 50.61%
# Epoch [36/100], Model 1 Training Loss: 1.1299, Training Accuracy: 42.91%
# Epoch [36/100], Model 2 Training Loss: 1.6282, Training Accuracy: 28.25%
# Epoch [36/100], Model 3 Training Loss: 1.0767, Training Accuracy: 42.64%
# Epoch [36/100], Model 4 Training Loss: 1.7950, Training Accuracy: 17.17%
# Epoch [36/100], Model 5 Training Loss: 0.9771, Training Accuracy: 50.05%
# Model 1 Validation Accuracy: 44.49%, Validation Loss: 1.1002
# Model 2 Validation Accuracy: 29.15%, Validation Loss: 1.5512
# Model 3 Validation Accuracy: 40.14%, Validation Loss: 1.1159
# Model 4 Validation Accuracy: 19.06%, Validation Loss: 1.7919
# Model 5 Validation Accuracy: 51.02%, Validation Loss: 0.9464
# Best model 5 saved with accuracy: 51.02%
# Epoch [37/100], Model 1 Training Loss: 1.1216, Training Accuracy: 43.40%
# Epoch [37/100], Model 2 Training Loss: 1.5486, Training Accuracy: 28.96%
# Epoch [37/100], Model 3 Training Loss: 1.0752, Training Accuracy: 42.76%
# Epoch [37/100], Model 4 Training Loss: 1.7960, Training Accuracy: 16.91%
# Epoch [37/100], Model 5 Training Loss: 0.9659, Training Accuracy: 49.85%
# Model 1 Validation Accuracy: 44.36%, Validation Loss: 1.0931
# Model 2 Validation Accuracy: 26.68%, Validation Loss: 1.6251
# Model 3 Validation Accuracy: 42.82%, Validation Loss: 1.0824
# Model 4 Validation Accuracy: 17.04%, Validation Loss: 1.7919
# Model 5 Validation Accuracy: 50.05%, Validation Loss: 0.9364
# Epoch [38/100], Model 1 Training Loss: 1.1130, Training Accuracy: 44.30%
# Epoch [38/100], Model 2 Training Loss: 1.5307, Training Accuracy: 28.58%
# Epoch [38/100], Model 3 Training Loss: 1.0675, Training Accuracy: 43.42%
# Epoch [38/100], Model 4 Training Loss: 1.7621, Training Accuracy: 21.64%
# Epoch [38/100], Model 5 Training Loss: 0.9639, Training Accuracy: 49.90%
# Model 1 Validation Accuracy: 42.66%, Validation Loss: 1.1098
# Model 2 Validation Accuracy: 29.76%, Validation Loss: 1.4515
# Model 3 Validation Accuracy: 44.42%, Validation Loss: 1.0529
# Model 4 Validation Accuracy: 25.05%, Validation Loss: 1.7192
# Model 5 Validation Accuracy: 50.79%, Validation Loss: 0.9307
# Epoch [39/100], Model 1 Training Loss: 1.1061, Training Accuracy: 44.27%
# Epoch [39/100], Model 2 Training Loss: 1.4816, Training Accuracy: 29.64%
# Epoch [39/100], Model 3 Training Loss: 1.0559, Training Accuracy: 43.91%
# Epoch [39/100], Model 4 Training Loss: 1.6703, Training Accuracy: 26.92%
# Epoch [39/100], Model 5 Training Loss: 0.9626, Training Accuracy: 50.43%
# Model 1 Validation Accuracy: 45.92%, Validation Loss: 1.0783
# Model 2 Validation Accuracy: 30.69%, Validation Loss: 1.4199
# Model 3 Validation Accuracy: 42.88%, Validation Loss: 1.0946
# Model 4 Validation Accuracy: 29.01%, Validation Loss: 1.6207
# Model 5 Validation Accuracy: 51.20%, Validation Loss: 0.9424
# Best model 5 saved with accuracy: 51.20%
# Epoch [40/100], Model 1 Training Loss: 1.1030, Training Accuracy: 44.50%
# Epoch [40/100], Model 2 Training Loss: 1.4588, Training Accuracy: 30.79%
# Epoch [40/100], Model 3 Training Loss: 1.0509, Training Accuracy: 44.51%
# Epoch [40/100], Model 4 Training Loss: 1.5899, Training Accuracy: 27.60%
# Epoch [40/100], Model 5 Training Loss: 0.9603, Training Accuracy: 50.11%
# Model 1 Validation Accuracy: 43.77%, Validation Loss: 1.0757
# Model 2 Validation Accuracy: 31.05%, Validation Loss: 1.4234
# Model 3 Validation Accuracy: 43.29%, Validation Loss: 1.0935
# Model 4 Validation Accuracy: 27.61%, Validation Loss: 1.5161
# Model 5 Validation Accuracy: 50.82%, Validation Loss: 0.9324
# Epoch [41/100], Model 1 Training Loss: 1.0981, Training Accuracy: 45.10%
# Epoch [41/100], Model 2 Training Loss: 1.4508, Training Accuracy: 30.73%
# Epoch [41/100], Model 3 Training Loss: 1.0616, Training Accuracy: 44.86%
# Epoch [41/100], Model 4 Training Loss: 1.5161, Training Accuracy: 31.82%
# Epoch [41/100], Model 5 Training Loss: 0.9579, Training Accuracy: 50.24%
# Model 1 Validation Accuracy: 47.76%, Validation Loss: 1.0593
# Model 2 Validation Accuracy: 30.73%, Validation Loss: 1.4239
# Model 3 Validation Accuracy: 43.70%, Validation Loss: 1.0924
# Model 4 Validation Accuracy: 37.53%, Validation Loss: 1.4331
# Model 5 Validation Accuracy: 51.65%, Validation Loss: 0.9205
# Best model 5 saved with accuracy: 51.65%
# Epoch [42/100], Model 1 Training Loss: 1.0907, Training Accuracy: 45.60%
# Epoch [42/100], Model 2 Training Loss: 1.4436, Training Accuracy: 30.79%
# Epoch [42/100], Model 3 Training Loss: 1.0487, Training Accuracy: 45.13%
# Epoch [42/100], Model 4 Training Loss: 1.4821, Training Accuracy: 33.48%
# Epoch [42/100], Model 5 Training Loss: 0.9535, Training Accuracy: 50.52%
# Model 1 Validation Accuracy: 45.87%, Validation Loss: 1.0616
# Model 2 Validation Accuracy: 33.18%, Validation Loss: 1.3920
# Model 3 Validation Accuracy: 44.70%, Validation Loss: 1.0252
# Model 4 Validation Accuracy: 33.98%, Validation Loss: 1.4331
# Model 5 Validation Accuracy: 51.81%, Validation Loss: 0.9173
# Best model 5 saved with accuracy: 51.81%
# Epoch [43/100], Model 1 Training Loss: 1.0956, Training Accuracy: 44.99%
# Epoch [43/100], Model 2 Training Loss: 1.4364, Training Accuracy: 31.33%
# Epoch [43/100], Model 3 Training Loss: 1.0510, Training Accuracy: 45.67%
# Epoch [43/100], Model 4 Training Loss: 1.4609, Training Accuracy: 34.33%
# Epoch [43/100], Model 5 Training Loss: 0.9500, Training Accuracy: 50.96%
# Model 1 Validation Accuracy: 43.65%, Validation Loss: 1.0933
# Model 2 Validation Accuracy: 30.53%, Validation Loss: 1.4751
# Model 3 Validation Accuracy: 46.80%, Validation Loss: 1.0276
# Model 4 Validation Accuracy: 35.77%, Validation Loss: 1.4057
# Model 5 Validation Accuracy: 51.43%, Validation Loss: 0.9167
# Epoch [44/100], Model 1 Training Loss: 1.0994, Training Accuracy: 44.91%
# Epoch [44/100], Model 2 Training Loss: 1.4323, Training Accuracy: 31.99%
# Epoch [44/100], Model 3 Training Loss: 1.0429, Training Accuracy: 45.71%
# Epoch [44/100], Model 4 Training Loss: 1.4335, Training Accuracy: 36.00%
# Epoch [44/100], Model 5 Training Loss: 0.9535, Training Accuracy: 50.39%
# Model 1 Validation Accuracy: 44.15%, Validation Loss: 1.0819
# Model 2 Validation Accuracy: 32.50%, Validation Loss: 1.4017
# Model 3 Validation Accuracy: 45.83%, Validation Loss: 1.0042
# Model 4 Validation Accuracy: 35.56%, Validation Loss: 1.4090
# Model 5 Validation Accuracy: 51.93%, Validation Loss: 0.9109
# Best model 5 saved with accuracy: 51.93%
# Epoch [45/100], Model 1 Training Loss: 1.0998, Training Accuracy: 45.14%
# Epoch [45/100], Model 2 Training Loss: 1.4323, Training Accuracy: 31.13%
# Epoch [45/100], Model 3 Training Loss: 1.0414, Training Accuracy: 45.84%
# Epoch [45/100], Model 4 Training Loss: 1.4432, Training Accuracy: 35.75%
# Epoch [45/100], Model 5 Training Loss: 0.9571, Training Accuracy: 50.69%
# Model 1 Validation Accuracy: 44.47%, Validation Loss: 1.0600
# Model 2 Validation Accuracy: 26.31%, Validation Loss: 1.5175
# Model 3 Validation Accuracy: 48.30%, Validation Loss: 0.9926
# Model 4 Validation Accuracy: 36.38%, Validation Loss: 1.4019
# Model 5 Validation Accuracy: 51.45%, Validation Loss: 0.9266
# Epoch [46/100], Model 1 Training Loss: 1.0877, Training Accuracy: 45.70%
# Epoch [46/100], Model 2 Training Loss: 1.4205, Training Accuracy: 32.20%
# Epoch [46/100], Model 3 Training Loss: 1.0307, Training Accuracy: 47.41%
# Epoch [46/100], Model 4 Training Loss: 1.4230, Training Accuracy: 36.07%
# Epoch [46/100], Model 5 Training Loss: 0.9540, Training Accuracy: 50.32%
# Model 1 Validation Accuracy: 44.67%, Validation Loss: 1.0745
# Model 2 Validation Accuracy: 29.17%, Validation Loss: 1.4591
# Model 3 Validation Accuracy: 47.73%, Validation Loss: 0.9934
# Model 4 Validation Accuracy: 36.94%, Validation Loss: 1.3578
# Model 5 Validation Accuracy: 52.49%, Validation Loss: 0.9167
# Best model 5 saved with accuracy: 52.49%
# Epoch [47/100], Model 1 Training Loss: 1.0870, Training Accuracy: 45.27%
# Epoch [47/100], Model 2 Training Loss: 1.4266, Training Accuracy: 31.29%
# Epoch [47/100], Model 3 Training Loss: 1.0185, Training Accuracy: 47.31%
# Epoch [47/100], Model 4 Training Loss: 1.4069, Training Accuracy: 35.81%
# Epoch [47/100], Model 5 Training Loss: 0.9506, Training Accuracy: 50.93%
# Model 1 Validation Accuracy: 44.51%, Validation Loss: 1.1056
# Model 2 Validation Accuracy: 31.55%, Validation Loss: 1.4194
# Model 3 Validation Accuracy: 49.66%, Validation Loss: 0.9856
# Model 4 Validation Accuracy: 32.39%, Validation Loss: 1.4818
# Model 5 Validation Accuracy: 52.20%, Validation Loss: 0.9071
# Epoch [48/100], Model 1 Training Loss: 1.1002, Training Accuracy: 44.62%
# Epoch [48/100], Model 2 Training Loss: 1.3653, Training Accuracy: 33.45%
# Epoch [48/100], Model 3 Training Loss: 1.0169, Training Accuracy: 47.36%
# Epoch [48/100], Model 4 Training Loss: 1.4041, Training Accuracy: 35.21%
# Epoch [48/100], Model 5 Training Loss: 0.9558, Training Accuracy: 50.45%
# Model 1 Validation Accuracy: 48.32%, Validation Loss: 1.0708
# Model 2 Validation Accuracy: 33.18%, Validation Loss: 1.3401
# Model 3 Validation Accuracy: 48.48%, Validation Loss: 1.0008
# Model 4 Validation Accuracy: 24.05%, Validation Loss: 1.6649
# Model 5 Validation Accuracy: 53.38%, Validation Loss: 0.9072
# Best model 5 saved with accuracy: 53.38%
# Epoch [49/100], Model 1 Training Loss: 1.1009, Training Accuracy: 44.40%
# Epoch [49/100], Model 2 Training Loss: 1.3199, Training Accuracy: 34.22%
# Epoch [49/100], Model 3 Training Loss: 1.0313, Training Accuracy: 47.57%
# Epoch [49/100], Model 4 Training Loss: 1.3798, Training Accuracy: 36.09%
# Epoch [49/100], Model 5 Training Loss: 0.9524, Training Accuracy: 50.56%
# Model 1 Validation Accuracy: 46.01%, Validation Loss: 1.0816
# Model 2 Validation Accuracy: 33.70%, Validation Loss: 1.3042
# Model 3 Validation Accuracy: 47.82%, Validation Loss: 0.9607
# Model 4 Validation Accuracy: 33.32%, Validation Loss: 1.4859
# Model 5 Validation Accuracy: 51.45%, Validation Loss: 0.9080
# Epoch [50/100], Model 1 Training Loss: 1.0933, Training Accuracy: 45.02%
# Epoch [50/100], Model 2 Training Loss: 1.2955, Training Accuracy: 35.47%
# Epoch [50/100], Model 3 Training Loss: 1.0075, Training Accuracy: 47.68%
# Epoch [50/100], Model 4 Training Loss: 1.3642, Training Accuracy: 36.60%
# Epoch [50/100], Model 5 Training Loss: 0.9475, Training Accuracy: 51.39%
# Model 1 Validation Accuracy: 40.71%, Validation Loss: 1.2796
# Model 2 Validation Accuracy: 35.29%, Validation Loss: 1.3133
# Model 3 Validation Accuracy: 47.19%, Validation Loss: 1.0779
# Model 4 Validation Accuracy: 35.06%, Validation Loss: 1.3138
# Model 5 Validation Accuracy: 51.84%, Validation Loss: 0.9115
# Epoch [51/100], Model 1 Training Loss: 1.0870, Training Accuracy: 44.98%
# Epoch [51/100], Model 2 Training Loss: 1.2911, Training Accuracy: 35.74%
# Epoch [51/100], Model 3 Training Loss: 0.9904, Training Accuracy: 48.82%
# Epoch [51/100], Model 4 Training Loss: 1.2658, Training Accuracy: 37.25%
# Epoch [51/100], Model 5 Training Loss: 0.9524, Training Accuracy: 50.95%
# Model 1 Validation Accuracy: 45.01%, Validation Loss: 1.0449
# Model 2 Validation Accuracy: 36.36%, Validation Loss: 1.2682
# Model 3 Validation Accuracy: 47.98%, Validation Loss: 0.9645
# Model 4 Validation Accuracy: 33.82%, Validation Loss: 1.2569
# Model 5 Validation Accuracy: 51.56%, Validation Loss: 0.9134
# Epoch [52/100], Model 1 Training Loss: 1.0786, Training Accuracy: 45.13%
# Epoch [52/100], Model 2 Training Loss: 1.2836, Training Accuracy: 36.62%
# Epoch [52/100], Model 3 Training Loss: 0.9963, Training Accuracy: 48.63%
# Epoch [52/100], Model 4 Training Loss: 1.2099, Training Accuracy: 38.60%
# Epoch [52/100], Model 5 Training Loss: 0.9444, Training Accuracy: 50.99%
# Model 1 Validation Accuracy: 46.12%, Validation Loss: 1.0420
# Model 2 Validation Accuracy: 37.17%, Validation Loss: 1.2330
# Model 3 Validation Accuracy: 50.61%, Validation Loss: 0.9548
# Model 4 Validation Accuracy: 42.00%, Validation Loss: 1.1447
# Model 5 Validation Accuracy: 53.24%, Validation Loss: 0.8969
# Epoch [53/100], Model 1 Training Loss: 1.0866, Training Accuracy: 45.66%
# Epoch [53/100], Model 2 Training Loss: 1.2546, Training Accuracy: 37.52%
# Epoch [53/100], Model 3 Training Loss: 0.9801, Training Accuracy: 49.55%
# Epoch [53/100], Model 4 Training Loss: 1.1651, Training Accuracy: 40.97%
# Epoch [53/100], Model 5 Training Loss: 0.9382, Training Accuracy: 51.26%
# Model 1 Validation Accuracy: 45.26%, Validation Loss: 1.0439
# Model 2 Validation Accuracy: 39.69%, Validation Loss: 1.2385
# Model 3 Validation Accuracy: 48.73%, Validation Loss: 0.9483
# Model 4 Validation Accuracy: 35.15%, Validation Loss: 1.2329
# Model 5 Validation Accuracy: 52.81%, Validation Loss: 0.9005
# Epoch [54/100], Model 1 Training Loss: 1.0621, Training Accuracy: 46.24%
# Epoch [54/100], Model 2 Training Loss: 1.2364, Training Accuracy: 38.24%
# Epoch [54/100], Model 3 Training Loss: 0.9872, Training Accuracy: 49.65%
# Epoch [54/100], Model 4 Training Loss: 1.1424, Training Accuracy: 42.27%
# Epoch [54/100], Model 5 Training Loss: 0.9357, Training Accuracy: 51.42%
# Model 1 Validation Accuracy: 46.17%, Validation Loss: 1.0385
# Model 2 Validation Accuracy: 38.98%, Validation Loss: 1.2121
# Model 3 Validation Accuracy: 45.42%, Validation Loss: 1.3081
# Model 4 Validation Accuracy: 43.70%, Validation Loss: 1.0969
# Model 5 Validation Accuracy: 52.88%, Validation Loss: 0.9205
# Epoch [55/100], Model 1 Training Loss: 1.0680, Training Accuracy: 46.38%
# Epoch [55/100], Model 2 Training Loss: 1.2204, Training Accuracy: 38.91%
# Epoch [55/100], Model 3 Training Loss: 0.9782, Training Accuracy: 49.78%
# Epoch [55/100], Model 4 Training Loss: 1.1235, Training Accuracy: 43.56%
# Epoch [55/100], Model 5 Training Loss: 0.9277, Training Accuracy: 51.84%
# Model 1 Validation Accuracy: 45.38%, Validation Loss: 1.0301
# Model 2 Validation Accuracy: 39.91%, Validation Loss: 1.1987
# Model 3 Validation Accuracy: 49.59%, Validation Loss: 0.9350
# Model 4 Validation Accuracy: 45.10%, Validation Loss: 1.0737
# Model 5 Validation Accuracy: 53.42%, Validation Loss: 0.8980
# Best model 5 saved with accuracy: 53.42%
# Epoch [56/100], Model 1 Training Loss: 1.0676, Training Accuracy: 46.19%
# Epoch [56/100], Model 2 Training Loss: 1.2067, Training Accuracy: 39.78%
# Epoch [56/100], Model 3 Training Loss: 0.9549, Training Accuracy: 50.74%
# Epoch [56/100], Model 4 Training Loss: 1.1150, Training Accuracy: 43.65%
# Epoch [56/100], Model 5 Training Loss: 0.9290, Training Accuracy: 51.52%
# Model 1 Validation Accuracy: 47.28%, Validation Loss: 1.0329
# Model 2 Validation Accuracy: 41.46%, Validation Loss: 1.1642
# Model 3 Validation Accuracy: 50.88%, Validation Loss: 0.9330
# Model 4 Validation Accuracy: 43.70%, Validation Loss: 1.0914
# Model 5 Validation Accuracy: 52.52%, Validation Loss: 0.8955
# Epoch [57/100], Model 1 Training Loss: 1.0470, Training Accuracy: 47.06%
# Epoch [57/100], Model 2 Training Loss: 1.1904, Training Accuracy: 40.48%
# Epoch [57/100], Model 3 Training Loss: 0.9453, Training Accuracy: 50.41%
# Epoch [57/100], Model 4 Training Loss: 1.1072, Training Accuracy: 44.22%
# Epoch [57/100], Model 5 Training Loss: 0.9203, Training Accuracy: 52.39%
# Model 1 Validation Accuracy: 46.65%, Validation Loss: 1.0265
# Model 2 Validation Accuracy: 40.53%, Validation Loss: 1.2073
# Model 3 Validation Accuracy: 49.61%, Validation Loss: 0.9222
# Model 4 Validation Accuracy: 42.50%, Validation Loss: 1.1406
# Model 5 Validation Accuracy: 54.24%, Validation Loss: 0.9059
# Best model 5 saved with accuracy: 54.24%
# Epoch [58/100], Model 1 Training Loss: 1.0508, Training Accuracy: 46.49%
# Epoch [58/100], Model 2 Training Loss: 1.1806, Training Accuracy: 40.87%
# Epoch [58/100], Model 3 Training Loss: 0.9352, Training Accuracy: 50.22%
# Epoch [58/100], Model 4 Training Loss: 1.0980, Training Accuracy: 44.64%
# Epoch [58/100], Model 5 Training Loss: 0.9161, Training Accuracy: 52.13%
# Model 1 Validation Accuracy: 47.57%, Validation Loss: 1.0222
# Model 2 Validation Accuracy: 36.85%, Validation Loss: 1.4032
# Model 3 Validation Accuracy: 50.54%, Validation Loss: 0.9698
# Model 4 Validation Accuracy: 43.93%, Validation Loss: 1.0935
# Model 5 Validation Accuracy: 52.29%, Validation Loss: 0.8937
# Epoch [59/100], Model 1 Training Loss: 1.0479, Training Accuracy: 46.92%
# Epoch [59/100], Model 2 Training Loss: 1.1702, Training Accuracy: 41.56%
# Epoch [59/100], Model 3 Training Loss: 0.9203, Training Accuracy: 52.03%
# Epoch [59/100], Model 4 Training Loss: 1.0862, Training Accuracy: 44.72%
# Epoch [59/100], Model 5 Training Loss: 0.9144, Training Accuracy: 52.39%
# Model 1 Validation Accuracy: 48.66%, Validation Loss: 1.0098
# Model 2 Validation Accuracy: 43.52%, Validation Loss: 1.1540
# Model 3 Validation Accuracy: 50.95%, Validation Loss: 0.9010
# Model 4 Validation Accuracy: 44.79%, Validation Loss: 1.0547
# Model 5 Validation Accuracy: 53.56%, Validation Loss: 0.8787
# Epoch [60/100], Model 1 Training Loss: 1.0374, Training Accuracy: 46.85%
# Epoch [60/100], Model 2 Training Loss: 1.1536, Training Accuracy: 42.16%
# Epoch [60/100], Model 3 Training Loss: 0.9180, Training Accuracy: 51.31%
# Epoch [60/100], Model 4 Training Loss: 1.0860, Training Accuracy: 44.98%
# Epoch [60/100], Model 5 Training Loss: 0.9091, Training Accuracy: 53.19%
# Model 1 Validation Accuracy: 47.53%, Validation Loss: 1.0070
# Model 2 Validation Accuracy: 42.72%, Validation Loss: 1.1150
# Model 3 Validation Accuracy: 52.31%, Validation Loss: 0.9042
# Model 4 Validation Accuracy: 45.83%, Validation Loss: 1.0651
# Model 5 Validation Accuracy: 54.65%, Validation Loss: 0.8834
# Best model 5 saved with accuracy: 54.65%
# Epoch [61/100], Model 1 Training Loss: 1.0364, Training Accuracy: 47.28%
# Epoch [61/100], Model 2 Training Loss: 1.1423, Training Accuracy: 42.46%
# Epoch [61/100], Model 3 Training Loss: 0.9218, Training Accuracy: 51.50%
# Epoch [61/100], Model 4 Training Loss: 1.0838, Training Accuracy: 44.54%
# Epoch [61/100], Model 5 Training Loss: 0.9073, Training Accuracy: 52.50%
# Model 1 Validation Accuracy: 46.51%, Validation Loss: 1.0080
# Model 2 Validation Accuracy: 42.18%, Validation Loss: 1.1699
# Model 3 Validation Accuracy: 46.80%, Validation Loss: 1.0292
# Model 4 Validation Accuracy: 44.17%, Validation Loss: 1.0619
# Model 5 Validation Accuracy: 53.49%, Validation Loss: 0.8800
# Epoch [62/100], Model 1 Training Loss: 1.0253, Training Accuracy: 47.32%
# Epoch [62/100], Model 2 Training Loss: 1.1377, Training Accuracy: 43.29%
# Epoch [62/100], Model 3 Training Loss: 0.9195, Training Accuracy: 51.06%
# Epoch [62/100], Model 4 Training Loss: 1.0734, Training Accuracy: 45.27%
# Epoch [62/100], Model 5 Training Loss: 0.9068, Training Accuracy: 52.61%
# Model 1 Validation Accuracy: 47.73%, Validation Loss: 0.9940
# Model 2 Validation Accuracy: 43.81%, Validation Loss: 1.0951
# Model 3 Validation Accuracy: 50.50%, Validation Loss: 0.8996
# Model 4 Validation Accuracy: 46.44%, Validation Loss: 1.0361
# Model 5 Validation Accuracy: 54.83%, Validation Loss: 0.8778
# Best model 5 saved with accuracy: 54.83%
# Epoch [63/100], Model 1 Training Loss: 1.0172, Training Accuracy: 47.00%
# Epoch [63/100], Model 2 Training Loss: 1.1263, Training Accuracy: 43.88%
# Epoch [63/100], Model 3 Training Loss: 0.9250, Training Accuracy: 51.94%
# Epoch [63/100], Model 4 Training Loss: 1.0796, Training Accuracy: 44.96%
# Epoch [63/100], Model 5 Training Loss: 0.9031, Training Accuracy: 53.00%
# Model 1 Validation Accuracy: 46.65%, Validation Loss: 1.0230
# Model 2 Validation Accuracy: 43.97%, Validation Loss: 1.1080
# Model 3 Validation Accuracy: 51.95%, Validation Loss: 0.9189
# Model 4 Validation Accuracy: 46.26%, Validation Loss: 1.1111
# Model 5 Validation Accuracy: 53.90%, Validation Loss: 0.8920
# Epoch [64/100], Model 1 Training Loss: 1.0165, Training Accuracy: 46.46%
# Epoch [64/100], Model 2 Training Loss: 1.1159, Training Accuracy: 44.92%
# Epoch [64/100], Model 3 Training Loss: 0.9430, Training Accuracy: 51.12%
# Epoch [64/100], Model 4 Training Loss: 1.0832, Training Accuracy: 45.41%
# Epoch [64/100], Model 5 Training Loss: 0.9014, Training Accuracy: 53.04%
# Model 1 Validation Accuracy: 47.44%, Validation Loss: 1.0128
# Model 2 Validation Accuracy: 45.85%, Validation Loss: 1.0780
# Model 3 Validation Accuracy: 43.68%, Validation Loss: 1.2283
# Model 4 Validation Accuracy: 44.63%, Validation Loss: 1.0450
# Model 5 Validation Accuracy: 53.54%, Validation Loss: 0.8732
# Epoch [65/100], Model 1 Training Loss: 1.0162, Training Accuracy: 47.22%
# Epoch [65/100], Model 2 Training Loss: 1.0865, Training Accuracy: 45.64%
# Epoch [65/100], Model 3 Training Loss: 0.9286, Training Accuracy: 51.22%
# Epoch [65/100], Model 4 Training Loss: 1.0720, Training Accuracy: 45.05%
# Epoch [65/100], Model 5 Training Loss: 0.8983, Training Accuracy: 53.30%
# Model 1 Validation Accuracy: 45.65%, Validation Loss: 1.0022
# Model 2 Validation Accuracy: 44.67%, Validation Loss: 1.0969
# Model 3 Validation Accuracy: 52.43%, Validation Loss: 0.9002
# Model 4 Validation Accuracy: 46.17%, Validation Loss: 1.0371
# Model 5 Validation Accuracy: 53.65%, Validation Loss: 0.8708
# Epoch [66/100], Model 1 Training Loss: 1.0070, Training Accuracy: 47.23%
# Epoch [66/100], Model 2 Training Loss: 1.0467, Training Accuracy: 46.88%
# Epoch [66/100], Model 3 Training Loss: 0.9296, Training Accuracy: 50.52%
# Epoch [66/100], Model 4 Training Loss: 1.0681, Training Accuracy: 45.23%
# Epoch [66/100], Model 5 Training Loss: 0.9006, Training Accuracy: 52.74%
# Model 1 Validation Accuracy: 46.35%, Validation Loss: 1.0223
# Model 2 Validation Accuracy: 46.92%, Validation Loss: 1.0276
# Model 3 Validation Accuracy: 40.39%, Validation Loss: 1.3889
# Model 4 Validation Accuracy: 44.24%, Validation Loss: 1.1102
# Model 5 Validation Accuracy: 54.51%, Validation Loss: 0.8724
# Epoch [67/100], Model 1 Training Loss: 1.0207, Training Accuracy: 46.39%
# Epoch [67/100], Model 2 Training Loss: 1.0221, Training Accuracy: 47.65%
# Epoch [67/100], Model 3 Training Loss: 0.9599, Training Accuracy: 50.50%
# Epoch [67/100], Model 4 Training Loss: 1.0612, Training Accuracy: 45.56%
# Epoch [67/100], Model 5 Training Loss: 0.9016, Training Accuracy: 52.20%
# Model 1 Validation Accuracy: 46.83%, Validation Loss: 0.9896
# Model 2 Validation Accuracy: 48.10%, Validation Loss: 0.9843
# Model 3 Validation Accuracy: 39.91%, Validation Loss: 1.4139
# Model 4 Validation Accuracy: 47.33%, Validation Loss: 1.0270
# Model 5 Validation Accuracy: 54.06%, Validation Loss: 0.8960
# Epoch [68/100], Model 1 Training Loss: 1.0134, Training Accuracy: 47.61%
# Epoch [68/100], Model 2 Training Loss: 0.9993, Training Accuracy: 48.18%
# Epoch [68/100], Model 3 Training Loss: 0.9404, Training Accuracy: 50.62%
# Epoch [68/100], Model 4 Training Loss: 1.0690, Training Accuracy: 45.93%
# Epoch [68/100], Model 5 Training Loss: 0.8983, Training Accuracy: 53.39%
# Model 1 Validation Accuracy: 46.17%, Validation Loss: 0.9922
# Model 2 Validation Accuracy: 47.17%, Validation Loss: 0.9920
# Model 3 Validation Accuracy: 51.81%, Validation Loss: 0.8981
# Model 4 Validation Accuracy: 46.85%, Validation Loss: 1.0163
# Model 5 Validation Accuracy: 54.31%, Validation Loss: 0.8787
# Epoch [69/100], Model 1 Training Loss: 1.0179, Training Accuracy: 46.97%
# Epoch [69/100], Model 2 Training Loss: 0.9914, Training Accuracy: 48.70%
# Epoch [69/100], Model 3 Training Loss: 0.9417, Training Accuracy: 51.03%
# Epoch [69/100], Model 4 Training Loss: 1.0595, Training Accuracy: 46.00%
# Epoch [69/100], Model 5 Training Loss: 0.8988, Training Accuracy: 53.37%
# Model 1 Validation Accuracy: 46.74%, Validation Loss: 1.0067
# Model 2 Validation Accuracy: 48.87%, Validation Loss: 0.9956
# Model 3 Validation Accuracy: 50.48%, Validation Loss: 0.9325
# Model 4 Validation Accuracy: 43.88%, Validation Loss: 1.0590
# Model 5 Validation Accuracy: 53.40%, Validation Loss: 0.9038
# Epoch [70/100], Model 1 Training Loss: 1.0091, Training Accuracy: 47.45%
# Epoch [70/100], Model 2 Training Loss: 0.9853, Training Accuracy: 49.29%
# Epoch [70/100], Model 3 Training Loss: 0.9379, Training Accuracy: 51.10%
# ...
# Model 2 Validation Accuracy: 54.71%, Validation Loss: 0.8817
# Model 3 Validation Accuracy: 52.72%, Validation Loss: 0.8904
# Model 4 Validation Accuracy: 46.60%, Validation Loss: 1.0253
# Model 5 Validation Accuracy: 54.10%, Validation Loss: 0.8478
# Epoch [78/100], Model 1 Training Loss: 0.9669, Training Accuracy: 48.79%
# Epoch [78/100], Model 2 Training Loss: 0.9121, Training Accuracy: 53.41%
# Epoch [78/100], Model 3 Training Loss: 0.8955, Training Accuracy: 52.41%
# Epoch [78/100], Model 4 Training Loss: 1.0227, Training Accuracy: 47.53%
# Epoch [78/100], Model 5 Training Loss: 0.8596, Training Accuracy: 54.83%
# Model 1 Validation Accuracy: 48.14%, Validation Loss: 0.9960
# Model 2 Validation Accuracy: 53.38%, Validation Loss: 0.8767
# Model 3 Validation Accuracy: 51.54%, Validation Loss: 0.9102
# Model 4 Validation Accuracy: 47.89%, Validation Loss: 1.0081
# Model 5 Validation Accuracy: 53.26%, Validation Loss: 0.8627
# Epoch [79/100], Model 1 Training Loss: 0.9701, Training Accuracy: 49.22%
# Epoch [79/100], Model 2 Training Loss: 0.9123, Training Accuracy: 54.23%
# Epoch [79/100], Model 3 Training Loss: 0.8935, Training Accuracy: 53.05%
# Epoch [79/100], Model 4 Training Loss: 1.0252, Training Accuracy: 47.25%
# Epoch [79/100], Model 5 Training Loss: 0.8608, Training Accuracy: 54.66%
# Model 1 Validation Accuracy: 50.57%, Validation Loss: 0.9476
# Model 2 Validation Accuracy: 53.83%, Validation Loss: 0.8729
# Model 3 Validation Accuracy: 51.54%, Validation Loss: 0.8692
# Model 4 Validation Accuracy: 48.37%, Validation Loss: 0.9803
# Model 5 Validation Accuracy: 54.83%, Validation Loss: 0.8552
# Epoch [80/100], Model 1 Training Loss: 0.9574, Training Accuracy: 49.81%
# Epoch [80/100], Model 2 Training Loss: 0.9004, Training Accuracy: 54.32%
# Epoch [80/100], Model 3 Training Loss: 0.8922, Training Accuracy: 53.17%
# Epoch [80/100], Model 4 Training Loss: 1.0212, Training Accuracy: 47.01%
# Epoch [80/100], Model 5 Training Loss: 0.8583, Training Accuracy: 54.77%
# Model 1 Validation Accuracy: 51.45%, Validation Loss: 0.9336
# Model 2 Validation Accuracy: 55.17%, Validation Loss: 0.8686
# Model 3 Validation Accuracy: 53.74%, Validation Loss: 0.8676
# Model 4 Validation Accuracy: 48.89%, Validation Loss: 0.9818
# Model 5 Validation Accuracy: 55.85%, Validation Loss: 0.8462
# Epoch [81/100], Model 1 Training Loss: 0.9599, Training Accuracy: 50.33%
# Epoch [81/100], Model 2 Training Loss: 0.9072, Training Accuracy: 54.01%
# Epoch [81/100], Model 3 Training Loss: 0.8854, Training Accuracy: 53.56%
# Epoch [81/100], Model 4 Training Loss: 1.0208, Training Accuracy: 47.61%
# Epoch [81/100], Model 5 Training Loss: 0.8520, Training Accuracy: 54.95%
# Model 1 Validation Accuracy: 50.00%, Validation Loss: 0.9298
# Model 2 Validation Accuracy: 55.67%, Validation Loss: 0.8579
# Model 3 Validation Accuracy: 51.18%, Validation Loss: 0.8760
# Model 4 Validation Accuracy: 45.94%, Validation Loss: 1.0477
# Model 5 Validation Accuracy: 55.46%, Validation Loss: 0.8316
# Epoch [82/100], Model 1 Training Loss: 0.9599, Training Accuracy: 50.06%
# Epoch [82/100], Model 2 Training Loss: 0.9033, Training Accuracy: 53.83%
# Epoch [82/100], Model 3 Training Loss: 0.8803, Training Accuracy: 52.88%
# Epoch [82/100], Model 4 Training Loss: 1.0228, Training Accuracy: 46.88%
# Epoch [82/100], Model 5 Training Loss: 0.8508, Training Accuracy: 54.69%
# Model 1 Validation Accuracy: 51.59%, Validation Loss: 0.9426
# Model 2 Validation Accuracy: 55.19%, Validation Loss: 0.8676
# Model 3 Validation Accuracy: 54.13%, Validation Loss: 0.8572
# Model 4 Validation Accuracy: 48.82%, Validation Loss: 0.9920
# Model 5 Validation Accuracy: 56.21%, Validation Loss: 0.8383
# Best model 5 saved with accuracy: 56.21%
# Epoch [83/100], Model 1 Training Loss: 0.9624, Training Accuracy: 49.76%
# Epoch [83/100], Model 2 Training Loss: 0.8954, Training Accuracy: 53.78%
# Epoch [83/100], Model 3 Training Loss: 0.8884, Training Accuracy: 52.84%
# Epoch [83/100], Model 4 Training Loss: 1.0250, Training Accuracy: 47.15%
# Epoch [83/100], Model 5 Training Loss: 0.8483, Training Accuracy: 55.24%
# Model 1 Validation Accuracy: 50.07%, Validation Loss: 0.9434
# Model 2 Validation Accuracy: 56.37%, Validation Loss: 0.8533
# Best model 2 saved with accuracy: 56.37%
# Model 3 Validation Accuracy: 52.74%, Validation Loss: 0.8858
# Model 4 Validation Accuracy: 49.05%, Validation Loss: 0.9819
# Model 5 Validation Accuracy: 54.92%, Validation Loss: 0.8414
# Epoch [84/100], Model 1 Training Loss: 0.9504, Training Accuracy: 50.92%
# Epoch [84/100], Model 2 Training Loss: 0.8884, Training Accuracy: 54.53%
# Epoch [84/100], Model 3 Training Loss: 0.8868, Training Accuracy: 52.56%
# Epoch [84/100], Model 4 Training Loss: 1.0176, Training Accuracy: 47.60%
# Epoch [84/100], Model 5 Training Loss: 0.8466, Training Accuracy: 55.11%
# Model 1 Validation Accuracy: 52.61%, Validation Loss: 0.9195
# Model 2 Validation Accuracy: 53.49%, Validation Loss: 0.8793
# Model 3 Validation Accuracy: 51.43%, Validation Loss: 0.8810
# Model 4 Validation Accuracy: 49.23%, Validation Loss: 0.9914
# Model 5 Validation Accuracy: 56.71%, Validation Loss: 0.8266
# Best model 5 saved with accuracy: 56.71%
# Epoch [85/100], Model 1 Training Loss: 0.9476, Training Accuracy: 50.99%
# Epoch [85/100], Model 2 Training Loss: 0.8886, Training Accuracy: 54.19%
# Epoch [85/100], Model 3 Training Loss: 0.8866, Training Accuracy: 52.43%
# Epoch [85/100], Model 4 Training Loss: 1.0199, Training Accuracy: 47.38%
# Epoch [85/100], Model 5 Training Loss: 0.8559, Training Accuracy: 55.03%
# Model 1 Validation Accuracy: 51.97%, Validation Loss: 0.9114
# Model 2 Validation Accuracy: 56.39%, Validation Loss: 0.8400
# Model 3 Validation Accuracy: 53.60%, Validation Loss: 0.8688
# Model 4 Validation Accuracy: 49.55%, Validation Loss: 1.0006
# Model 5 Validation Accuracy: 55.03%, Validation Loss: 0.8281
# Epoch [86/100], Model 1 Training Loss: 0.9373, Training Accuracy: 51.72%
# Epoch [86/100], Model 2 Training Loss: 0.8769, Training Accuracy: 54.59%
# Epoch [86/100], Model 3 Training Loss: 0.9014, Training Accuracy: 52.02%
# Epoch [86/100], Model 4 Training Loss: 1.0220, Training Accuracy: 46.78%
# Epoch [86/100], Model 5 Training Loss: 0.8488, Training Accuracy: 54.51%
# Model 1 Validation Accuracy: 51.50%, Validation Loss: 0.9269
# Model 2 Validation Accuracy: 55.53%, Validation Loss: 0.8509
# Model 3 Validation Accuracy: 50.97%, Validation Loss: 0.8943
# Model 4 Validation Accuracy: 47.57%, Validation Loss: 1.0067
# Model 5 Validation Accuracy: 56.41%, Validation Loss: 0.8363
# Epoch [87/100], Model 1 Training Loss: 0.9414, Training Accuracy: 51.96%
# Epoch [87/100], Model 2 Training Loss: 0.8782, Training Accuracy: 54.91%
# Epoch [87/100], Model 3 Training Loss: 0.9078, Training Accuracy: 52.01%
# Epoch [87/100], Model 4 Training Loss: 1.0259, Training Accuracy: 47.57%
# Epoch [87/100], Model 5 Training Loss: 0.8515, Training Accuracy: 54.98%
# Model 1 Validation Accuracy: 50.61%, Validation Loss: 0.9218
# Model 2 Validation Accuracy: 55.01%, Validation Loss: 0.8472
# Model 3 Validation Accuracy: 52.77%, Validation Loss: 0.8913
# Model 4 Validation Accuracy: 47.94%, Validation Loss: 0.9826
# Model 5 Validation Accuracy: 56.53%, Validation Loss: 0.8357
# Epoch [88/100], Model 1 Training Loss: 0.9389, Training Accuracy: 51.25%
# Epoch [88/100], Model 2 Training Loss: 0.8702, Training Accuracy: 55.31%
# Epoch [88/100], Model 3 Training Loss: 0.9088, Training Accuracy: 51.47%
# Epoch [88/100], Model 4 Training Loss: 1.0261, Training Accuracy: 46.91%
# Epoch [88/100], Model 5 Training Loss: 0.8526, Training Accuracy: 54.98%
# Model 1 Validation Accuracy: 53.42%, Validation Loss: 0.9147
# Model 2 Validation Accuracy: 54.26%, Validation Loss: 0.8435
# Model 3 Validation Accuracy: 49.23%, Validation Loss: 0.9512
# Model 4 Validation Accuracy: 49.37%, Validation Loss: 0.9687
# Model 5 Validation Accuracy: 54.76%, Validation Loss: 0.8465
# Epoch [89/100], Model 1 Training Loss: 0.9398, Training Accuracy: 52.07%
# Epoch [89/100], Model 2 Training Loss: 0.8664, Training Accuracy: 55.17%
# Epoch [89/100], Model 3 Training Loss: 0.8976, Training Accuracy: 52.47%
# Epoch [89/100], Model 4 Training Loss: 1.0253, Training Accuracy: 47.55%
# Epoch [89/100], Model 5 Training Loss: 0.8488, Training Accuracy: 55.52%
# Model 1 Validation Accuracy: 51.70%, Validation Loss: 0.9156
# Model 2 Validation Accuracy: 54.96%, Validation Loss: 0.8477
# Model 3 Validation Accuracy: 53.24%, Validation Loss: 0.8742
# Model 4 Validation Accuracy: 47.96%, Validation Loss: 0.9879
# Model 5 Validation Accuracy: 56.55%, Validation Loss: 0.8287
# Epoch [90/100], Model 1 Training Loss: 0.9331, Training Accuracy: 52.30%
# Epoch [90/100], Model 2 Training Loss: 0.8628, Training Accuracy: 55.46%
# Epoch [90/100], Model 3 Training Loss: 0.9168, Training Accuracy: 51.77%
# Epoch [90/100], Model 4 Training Loss: 1.0323, Training Accuracy: 47.34%
# Epoch [90/100], Model 5 Training Loss: 0.8450, Training Accuracy: 55.09%
# Model 1 Validation Accuracy: 53.08%, Validation Loss: 0.9147
# Model 2 Validation Accuracy: 57.16%, Validation Loss: 0.8250
# Best model 2 saved with accuracy: 57.16%
# Model 3 Validation Accuracy: 51.65%, Validation Loss: 0.8779
# Model 4 Validation Accuracy: 45.56%, Validation Loss: 1.0957
# Model 5 Validation Accuracy: 55.85%, Validation Loss: 0.8498
# Epoch [91/100], Model 1 Training Loss: 0.9304, Training Accuracy: 52.47%
# Epoch [91/100], Model 2 Training Loss: 0.8593, Training Accuracy: 55.27%
# Epoch [91/100], Model 3 Training Loss: 0.9236, Training Accuracy: 51.55%
# Epoch [91/100], Model 4 Training Loss: 1.0287, Training Accuracy: 48.09%
# Epoch [91/100], Model 5 Training Loss: 0.8509, Training Accuracy: 55.07%
# Model 1 Validation Accuracy: 53.38%, Validation Loss: 0.8920
# Model 2 Validation Accuracy: 55.78%, Validation Loss: 0.8350
# Model 3 Validation Accuracy: 54.19%, Validation Loss: 0.8661
# Model 4 Validation Accuracy: 50.95%, Validation Loss: 0.9599
# Model 5 Validation Accuracy: 56.19%, Validation Loss: 0.8287
# Epoch [92/100], Model 1 Training Loss: 0.9412, Training Accuracy: 52.10%
# Epoch [92/100], Model 2 Training Loss: 0.8536, Training Accuracy: 55.49%
# Epoch [92/100], Model 3 Training Loss: 0.9157, Training Accuracy: 51.82%
# Epoch [92/100], Model 4 Training Loss: 1.0242, Training Accuracy: 47.82%
# Epoch [92/100], Model 5 Training Loss: 0.8459, Training Accuracy: 55.29%
# Model 1 Validation Accuracy: 52.83%, Validation Loss: 0.8900
# Model 2 Validation Accuracy: 53.63%, Validation Loss: 0.9255
# Model 3 Validation Accuracy: 53.79%, Validation Loss: 0.8725
# Model 4 Validation Accuracy: 47.03%, Validation Loss: 1.0013
# Model 5 Validation Accuracy: 56.89%, Validation Loss: 0.8445
# Epoch [93/100], Model 1 Training Loss: 0.9298, Training Accuracy: 52.34%
# Epoch [93/100], Model 2 Training Loss: 0.8476, Training Accuracy: 55.55%
# Epoch [93/100], Model 3 Training Loss: 0.8968, Training Accuracy: 52.48%
# Epoch [93/100], Model 4 Training Loss: 1.0199, Training Accuracy: 48.08%
# Epoch [93/100], Model 5 Training Loss: 0.8425, Training Accuracy: 55.27%
# Model 1 Validation Accuracy: 52.77%, Validation Loss: 0.9060
# Model 2 Validation Accuracy: 56.62%, Validation Loss: 0.8106
# Model 3 Validation Accuracy: 54.51%, Validation Loss: 0.8669
# Model 4 Validation Accuracy: 49.23%, Validation Loss: 0.9853
# Model 5 Validation Accuracy: 55.64%, Validation Loss: 0.8241
# Epoch [94/100], Model 1 Training Loss: 0.9261, Training Accuracy: 52.84%
# Epoch [94/100], Model 2 Training Loss: 0.8416, Training Accuracy: 56.12%
# Epoch [94/100], Model 3 Training Loss: 0.9110, Training Accuracy: 52.71%
# Epoch [94/100], Model 4 Training Loss: 1.0130, Training Accuracy: 47.98%
# Epoch [94/100], Model 5 Training Loss: 0.8432, Training Accuracy: 55.88%
# Model 1 Validation Accuracy: 52.45%, Validation Loss: 0.9010
# Model 2 Validation Accuracy: 55.46%, Validation Loss: 0.8099
# Model 3 Validation Accuracy: 52.99%, Validation Loss: 0.8868
# Model 4 Validation Accuracy: 50.84%, Validation Loss: 0.9953
# Model 5 Validation Accuracy: 56.32%, Validation Loss: 0.8337
# Epoch [95/100], Model 1 Training Loss: 0.9194, Training Accuracy: 52.95%
# Epoch [95/100], Model 2 Training Loss: 0.8355, Training Accuracy: 55.88%
# Epoch [95/100], Model 3 Training Loss: 0.8805, Training Accuracy: 52.61%
# Epoch [95/100], Model 4 Training Loss: 1.0083, Training Accuracy: 48.57%
# Epoch [95/100], Model 5 Training Loss: 0.8348, Training Accuracy: 55.90%
# Model 1 Validation Accuracy: 54.01%, Validation Loss: 0.8852
# Model 2 Validation Accuracy: 55.94%, Validation Loss: 0.7912
# Model 3 Validation Accuracy: 51.97%, Validation Loss: 0.8587
# Model 4 Validation Accuracy: 49.27%, Validation Loss: 0.9847
# Model 5 Validation Accuracy: 54.26%, Validation Loss: 0.8449
# Epoch [96/100], Model 1 Training Loss: 0.9143, Training Accuracy: 52.99%
# Epoch [96/100], Model 2 Training Loss: 0.8229, Training Accuracy: 56.12%
# Epoch [96/100], Model 3 Training Loss: 0.8812, Training Accuracy: 52.98%
# Epoch [96/100], Model 4 Training Loss: 1.0195, Training Accuracy: 48.19%
# Epoch [96/100], Model 5 Training Loss: 0.8303, Training Accuracy: 55.98%
# Model 1 Validation Accuracy: 52.04%, Validation Loss: 0.9112
# Model 2 Validation Accuracy: 56.50%, Validation Loss: 0.8247
# Model 3 Validation Accuracy: 52.49%, Validation Loss: 0.8608
# Model 4 Validation Accuracy: 49.00%, Validation Loss: 0.9664
# Model 5 Validation Accuracy: 55.10%, Validation Loss: 0.8295
# Epoch [97/100], Model 1 Training Loss: 0.9107, Training Accuracy: 52.98%
# Epoch [97/100], Model 2 Training Loss: 0.8166, Training Accuracy: 56.51%
# Epoch [97/100], Model 3 Training Loss: 0.8754, Training Accuracy: 53.16%
# Epoch [97/100], Model 4 Training Loss: 0.9985, Training Accuracy: 49.04%
# Epoch [97/100], Model 5 Training Loss: 0.8275, Training Accuracy: 55.58%
# Model 1 Validation Accuracy: 52.11%, Validation Loss: 0.8982
# Model 2 Validation Accuracy: 56.48%, Validation Loss: 0.7887
# Model 3 Validation Accuracy: 51.81%, Validation Loss: 0.9323
# Model 4 Validation Accuracy: 49.82%, Validation Loss: 0.9869
# Model 5 Validation Accuracy: 57.55%, Validation Loss: 0.8166
# Best model 5 saved with accuracy: 57.55%
# Epoch [98/100], Model 1 Training Loss: 0.9048, Training Accuracy: 53.65%
# Epoch [98/100], Model 2 Training Loss: 0.8074, Training Accuracy: 56.99%
# Epoch [98/100], Model 3 Training Loss: 0.8815, Training Accuracy: 52.53%
# Epoch [98/100], Model 4 Training Loss: 0.9883, Training Accuracy: 49.19%
# Epoch [98/100], Model 5 Training Loss: 0.8180, Training Accuracy: 56.27%
# Model 1 Validation Accuracy: 53.26%, Validation Loss: 0.8813
# Model 2 Validation Accuracy: 56.91%, Validation Loss: 0.7793
# Model 3 Validation Accuracy: 52.99%, Validation Loss: 0.8599
# Model 4 Validation Accuracy: 50.27%, Validation Loss: 0.9538
# Model 5 Validation Accuracy: 56.28%, Validation Loss: 0.8295
# Epoch [99/100], Model 1 Training Loss: 0.9003, Training Accuracy: 53.51%
# Epoch [99/100], Model 2 Training Loss: 0.8000, Training Accuracy: 57.25%
# Epoch [99/100], Model 3 Training Loss: 0.8689, Training Accuracy: 53.84%
# Epoch [99/100], Model 4 Training Loss: 0.9917, Training Accuracy: 49.08%
# Epoch [99/100], Model 5 Training Loss: 0.8162, Training Accuracy: 56.65%
# Model 1 Validation Accuracy: 54.37%, Validation Loss: 0.8714
# Model 2 Validation Accuracy: 57.59%, Validation Loss: 0.7873
# Best model 2 saved with accuracy: 57.59%
# Model 3 Validation Accuracy: 51.86%, Validation Loss: 0.8907
# Model 4 Validation Accuracy: 50.11%, Validation Loss: 0.9569
# Model 5 Validation Accuracy: 57.03%, Validation Loss: 0.8378
# Epoch [100/100], Model 1 Training Loss: 0.8973, Training Accuracy: 53.75%
# Epoch [100/100], Model 2 Training Loss: 0.7905, Training Accuracy: 57.29%
# Epoch [100/100], Model 3 Training Loss: 0.8696, Training Accuracy: 53.24%
# Epoch [100/100], Model 4 Training Loss: 0.9906, Training Accuracy: 49.84%
# Epoch [100/100], Model 5 Training Loss: 0.8200, Training Accuracy: 56.46%
# Model 1 Validation Accuracy: 54.44%, Validation Loss: 0.8602
# Model 2 Validation Accuracy: 58.34%, Validation Loss: 0.7653
# Best model 2 saved with accuracy: 58.34%
# Model 3 Validation Accuracy: 54.83%, Validation Loss: 0.8361
# Model 4 Validation Accuracy: 48.10%, Validation Loss: 1.0086
# Model 5 Validation Accuracy: 57.03%, Validation Loss: 0.8515

# %% [markdown]
# ## 8. 슬라이딩 윈도우와 예측

# %%
# 학습된 모델 로드
for i, model in enumerate(models):
    checkpoint = torch.load(f'best_model_{i+1}.pth.tar')
    model.load_state_dict(checkpoint['state_dict'])
    model.eval()

# 자이로 데이터를 GPU로 이동
gyro_data_tensor = gyro_data_tensor.to(device)

print(f"gyro_data_tensor shape: {gyro_data_tensor.shape}")

# 예측
batch_size = 100
all_predictions = []

for i in range(0, len(gyro_data_tensor), batch_size):
    batch = gyro_data_tensor[i:i+batch_size]
    # 마지막 배치 처리
    if len(batch) < batch_size:
        padding = torch.zeros(batch_size - len(batch), *batch.shape[1:], device=device)
        batch = torch.cat([batch, padding], dim=0)
    batch_predictions = ensemble_predict(models, batch)
    # 패딩 제거
    all_predictions.append(batch_predictions[:len(gyro_data_tensor[i:i+batch_size])])

all_predictions = torch.cat(all_predictions).cpu().numpy()

# 슬라이딩 윈도우 예측 결과를 원본 데이터에 매핑하는 함수
def map_predictions_to_original(original_data_length, predictions, window_size, stride):
    mapped_predictions = np.zeros((original_data_length, 6))  # 6은 활동 클래스의 수
    counts = np.zeros(original_data_length)
    
    for i, pred in enumerate(predictions):
        start = i * stride
        end = min(start + window_size, original_data_length)
        mapped_predictions[start:end, pred] += 1
        counts[start:end] += 1
    
    # 각 데이터 포인트에 대해 가장 많이 예측된 라벨 선택
    final_predictions = np.argmax(mapped_predictions, axis=1)
    
    return final_predictions

# 원본 자이로 데이터 로드
original_gyro_data = pd.read_csv('./원본 데이터/자이로 데이터.csv')

# 원본 데이터에 맞는 예측 라벨 생성
original_predictions = map_predictions_to_original(len(original_gyro_data), all_predictions, window_size=128, stride=64)

# 예측된 라벨을 활동 이름으로 매핑
activity_labels = {0: "walking", 1: "walking_upstairs", 2: "walking_downstairs", 3: "sitting", 4: "standing", 5: "laying"}
predicted_activities = [activity_labels[label] for label in original_predictions]

# 예측 결과 출력
for i, activity in enumerate(predicted_activities[:10]):
    print(f"Sample {i}: {activity}")

# 자이로 데이터에 예측 결과 추가
original_gyro_data['Predicted_Activity'] = predicted_activities

# 결과 저장
original_gyro_data.to_csv('./원본 데이터/자이로 데이터_예측.csv', index=False)

# 예측 결과 시각화
plt.figure(figsize=(12, 6))
activity_counts = pd.Series(predicted_activities).value_counts()
sns.barplot(x=activity_counts.index, y=activity_counts.values)
plt.title('Predicted Activity Distribution')
plt.xlabel('Activity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 시간에 따른 활동 변화 시각화
plt.figure(figsize=(20, 6))
activity_series = pd.Series(predicted_activities)
activity_numeric = pd.factorize(activity_series)[0]
plt.plot(activity_numeric)
plt.title('Activity Changes Over Time')
plt.xlabel('Time')
plt.ylabel('Activity')
plt.yticks(range(len(activity_labels)), list(activity_labels.values()))
plt.tight_layout()
plt.show()

print("예측 완료 및 결과 저장됨")
# Out:
# gyro_data_tensor shape: torch.Size([46256, 128, 3])
# C:\Users\user\AppData\Local\Temp\ipykernel_7052\4031207289.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f'best_model_{i+1}.pth.tar')
# Sample 0: walking_downstairs
# Sample 1: walking_downstairs
# Sample 2: walking_downstairs
# Sample 3: walking_downstairs
# Sample 4: walking_downstairs
# Sample 5: walking_downstairs
# Sample 6: walking_downstairs
# Sample 7: walking_downstairs
# Sample 8: walking_downstairs
# Sample 9: walking_downstairs
# 예측 완료 및 결과 저장됨

# %% [markdown]
# ## 9. 성능 평가 및 시각화

# %%
# 자이로 데이터에 라벨 추가
gyro_data = pd.read_csv('./원본 데이터/자이로 데이터.csv')
gyro_data['Predicted_Activity'] = predicted_activities[:len(gyro_data)]  # 길이 맞춤

# 라벨링된 자이로 데이터를 저장
gyro_data.to_csv('./원본 데이터/자이로 데이터_예측.csv', index=False)

# 예측된 활동별 분포 시각화
plt.figure(figsize=(10, 6))
sns.countplot(x=gyro_data['Predicted_Activity'])
plt.title('Predicted Activity Distribution')
plt.xticks(rotation=45)
plt.show()

# 예측 결과 요약
print(gyro_data['Predicted_Activity'].value_counts(normalize=True))

# 클러스터링 적용 및 결과 비교
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans_labels = kmeans.fit_predict(gyro_data_tensor.cpu().numpy().reshape(gyro_data_tensor.shape[0], -1))

# 클러스터링 결과와 실제 예측 라벨 비교
kmeans_accuracy = accuracy_score(all_predictions, kmeans_labels)
print(f"K-Means Clustering Accuracy: {kmeans_accuracy:.2f}")

# Confusion Matrix 및 성능 평가
cm = confusion_matrix(all_predictions, kmeans_labels)
ConfusionMatrixDisplay(cm).plot()
plt.show()

print(classification_report(all_predictions, kmeans_labels))
# Out:
# Predicted_Activity
# walking               0.515021
# walking_upstairs      0.241344
# walking_downstairs    0.223509
# laying                0.019445
# sitting               0.000649
# standing              0.000032
# Name: proportion, dtype: float64
# K-Means Clustering Accuracy: 0.08
#               precision    recall  f1-score   support
#
#            0       0.01      0.14      0.02       814
#            1       0.06      0.01      0.01     16857
#            2       0.63      0.14      0.22     26444
#            3       0.00      0.00      0.00       136
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00      2001
#
#     accuracy                           0.08     46256
#    macro avg       0.12      0.05      0.04     46256
# weighted avg       0.38      0.08      0.13     46256
