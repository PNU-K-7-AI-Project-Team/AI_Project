# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE

def parse_end(s):
    try:
        return float(s[-1])
    except:
        return np.nan

def read_data(file_path):
    labels = {'Walking': 0, 'Jogging': 1, 'Upstairs': 2, 'Sitting': 3, 'Downstairs': 4, 'Standing': 5}    
    data = np.loadtxt(file_path, delimiter=",", usecols=(0,1, 3, 4, 5),
                      converters={1: lambda name: labels[name.decode()],
                                  5: parse_end})
    data = data[~np.isnan(data).any(axis=1)]
    return data

data = read_data("./DATA/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt")

mean = np.mean(data[:,2:], axis=0)
std = np.std(data[:,2:], axis=0)
data[:,2:] = (data[:,2:]-mean)/std

# 데이터 불균형 확인 및 시각화
activity_counts = np.bincount(data[:, 1].astype(int))
activity_names = ['Walking', 'Jogging', 'Upstairs', 'Sitting', 'Downstairs', 'Standing']

print("활동별 데이터 수:")
for i, count in enumerate(activity_counts):
    print(f"{activity_names[i]}: {count}")

plt.figure(figsize=(10, 6))
plt.bar(activity_names, activity_counts)
plt.title("활동별 데이터 분포")
plt.xlabel("활동")
plt.ylabel("데이터 수")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 데이터 증강 함수
def time_warp(x, sigma=0.2, knot=4):
    orig_steps = np.arange(x.shape[0])
    random_warps = np.random.normal(loc=1.0, scale=sigma, size=(knot+2,))
    warp_steps = np.zeros(knot+2)
    warp_steps[0] = 0
    warp_steps[-1] = x.shape[0] - 1
    warp_steps[1:-1] = np.sort(np.random.randint(1, x.shape[0]-1, size=(knot,)))
    warper = interp1d(warp_steps, random_warps, bounds_error=False, fill_value='extrapolate')
    warped_steps = warper(orig_steps)
    ret = np.zeros_like(x)
    for i in range(x.shape[1]):
        ret[:, i] = np.interp(orig_steps, warped_steps, x[:, i])
    return ret

def magnitude_warp(x, sigma=0.2, knot=4):
    orig_steps = np.arange(x.shape[0])
    random_warps = np.random.normal(loc=1.0, scale=sigma, size=(knot+2,))
    warp_steps = np.zeros(knot+2)
    warp_steps[0] = 0
    warp_steps[-1] = x.shape[0] - 1
    warp_steps[1:-1] = np.sort(np.random.randint(1, x.shape[0]-1, size=(knot,)))
    warper = interp1d(warp_steps, random_warps, bounds_error=False, fill_value='extrapolate')
    warped_steps = warper(orig_steps)
    return x * warped_steps[:, np.newaxis]

def window_slice(x, reduce_ratio=0.9):
    target_len = int(reduce_ratio * x.shape[0])
    if target_len >= x.shape[0]:
        return x
    starts = np.random.randint(low=0, high=x.shape[0] - target_len, size=(1,)).astype(int)[0]
    return x[starts:starts + target_len, :]

def window_warp(x, window_ratio=0.1, scales=[0.5, 2.]):
    warp_scales = np.random.choice(scales, x.shape[1])
    warp_size = np.ceil(window_ratio * x.shape[0]).astype(int)
    window_steps = np.arange(warp_size)
        
    window_starts = np.random.randint(low=1, high=x.shape[0] - warp_size - 1, size=(x.shape[1],)).astype(int)
    window_ends = (window_starts + warp_size).astype(int)
        
    ret = np.zeros_like(x)
    for i in range(x.shape[1]):
        start_seg = x[:window_starts[i], i]
        window_seg = np.interp(np.linspace(0, warp_size, num=int(warp_size*warp_scales[i])), window_steps, x[window_starts[i]:window_ends[i], i])
        end_seg = x[window_ends[i]:, i]
        warped = np.concatenate((start_seg, window_seg, end_seg))
        ret[:, i] = np.interp(np.arange(x.shape[0]), np.linspace(0, x.shape[0], num=warped.size), warped)
    return ret

def augment_data(x, y):
    augmented_x = []
    augmented_y = []
    for i in range(len(x)):
        augmented_x.append(x[i])
        augmented_y.append(y[i])
        
        # Time warping
        warped = time_warp(x[i])
        augmented_x.append(warped)
        augmented_y.append(y[i])
        
        # Magnitude warping
        warped = magnitude_warp(x[i])
        augmented_x.append(warped)
        augmented_y.append(y[i])
        
        # Window slicing
        sliced = window_slice(x[i])
        if sliced.shape[0] == x[i].shape[0]:
            augmented_x.append(sliced)
            augmented_y.append(y[i])
        
        # Window warping
        warped = window_warp(x[i])
        augmented_x.append(warped)
        augmented_y.append(y[i])
    
    return np.array(augmented_x), np.array(augmented_y)

# 데이터 분할 및 세그먼트화
x_train = data[data[:,0] <= 28]
x_test = data[data[:,0] > 28]

TIME_PERIODS = 80
STEP_DISTANCE = 40

def data_segments(data):
    segments = []
    labels = []
    for i in range(0, len(data) - TIME_PERIODS, STEP_DISTANCE):
        X = data[i:i+TIME_PERIODS, 2:].tolist()
        values, counts = np.unique(data[i:i+TIME_PERIODS, 1], return_counts=True)
        label = values[np.argmax(counts)]
        segments.append(X)
        labels.append(label)
    segments = np.array(segments, dtype=np.float32).reshape(-1, TIME_PERIODS, 3)
    labels = np.asarray(labels)
    return segments, labels

x_train, y_train = data_segments(x_train)
x_test, y_test = data_segments(x_test)

# 데이터 증강 적용
x_train, y_train = augment_data(x_train, y_train)

# SMOTE 적용
smote = SMOTE(random_state=42)
x_train_reshaped = x_train.reshape(x_train.shape[0], -1)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train_reshaped, y_train)
x_train = x_train_resampled.reshape(-1, TIME_PERIODS, 3)
y_train = y_train_resampled

# 원-핫 인코딩
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# 모델 구축
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(TIME_PERIODS, 3)),
    tf.keras.layers.Conv1D(filters=100, kernel_size=11, activation='relu'),
    tf.keras.layers.MaxPool1D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv1D(filters=10, kernel_size=5, activation='relu'),
    tf.keras.layers.MaxPool1D(),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=6, activation='softmax')
])

model.summary()

# 모델 컴파일 및 훈련
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
ret = model.fit(x_train, y_train, epochs=100, batch_size=400,
                validation_data=(x_test, y_test), verbose=2)

# 모델 평가
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

# 정확도 및 손실 그래프
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(ret.history['accuracy'], label='train accuracy')
plt.plot(ret.history['val_accuracy'], label='val accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 혼동 행렬 및 분류 보고서
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Confusion Matrix:")
print(confusion_matrix(y_true, y_pred_classes))
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=activity_names))

# 샘플 활동 시각화
plt.figure(figsize=(12, 8))
for i in range(6):
    plt.subplot(3, 2, i+1)
    activity_data = x_test[y_true == i][0]
    plt.plot(activity_data)
    plt.title(activity_names[i])
    plt.xlabel('Time')
    plt.ylabel('Normalized Acceleration')
plt.tight_layout()
plt.show()
# Out:
# 활동별 데이터 수:
# Walking: 424397
# Jogging: 342176
# Upstairs: 122869
# Sitting: 59939
# Downstairs: 100427
# Standing: 48395
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 54876 (\N{HANGUL SYLLABLE HWAL}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_1848\3337819948.py:42: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   plt.tight_layout()
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 70, 100)             │           3,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 35, 100)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 35, 100)             │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 31, 10)              │           5,010 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 15, 10)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 15, 10)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 150)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 6)                   │             906 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,716 (37.95 KB)
#  Trainable params: 9,516 (37.17 KB)
#  Non-trainable params: 200 (800.00 B)
# Epoch 1/100
# 493/493 - 8s - 17ms/step - accuracy: 0.6232 - loss: 1.0167 - val_accuracy: 0.7980 - val_loss: 1.2669
# Epoch 2/100
# 493/493 - 7s - 15ms/step - accuracy: 0.7267 - loss: 0.7415 - val_accuracy: 0.8164 - val_loss: 1.1515
# Epoch 3/100
# 493/493 - 7s - 15ms/step - accuracy: 0.7618 - loss: 0.6464 - val_accuracy: 0.8481 - val_loss: 1.1507
# Epoch 4/100
# 493/493 - 7s - 15ms/step - accuracy: 0.7768 - loss: 0.6031 - val_accuracy: 0.8341 - val_loss: 0.8928
# Epoch 5/100
# 493/493 - 7s - 15ms/step - accuracy: 0.7850 - loss: 0.5826 - val_accuracy: 0.8502 - val_loss: 0.9714
# Epoch 6/100
# 493/493 - 8s - 15ms/step - accuracy: 0.7905 - loss: 0.5672 - val_accuracy: 0.8651 - val_loss: 1.2028
# Epoch 7/100
# 493/493 - 7s - 15ms/step - accuracy: 0.7958 - loss: 0.5544 - val_accuracy: 0.8616 - val_loss: 0.9065
# Epoch 8/100
# 493/493 - 8s - 15ms/step - accuracy: 0.7970 - loss: 0.5484 - val_accuracy: 0.8524 - val_loss: 0.6022
# Epoch 9/100
# 493/493 - 8s - 15ms/step - accuracy: 0.7990 - loss: 0.5442 - val_accuracy: 0.8584 - val_loss: 0.5851
# Epoch 10/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8008 - loss: 0.5401 - val_accuracy: 0.8563 - val_loss: 0.5816
# Epoch 11/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8044 - loss: 0.5284 - val_accuracy: 0.8524 - val_loss: 0.6503
# Epoch 12/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8040 - loss: 0.5307 - val_accuracy: 0.8566 - val_loss: 0.6078
# Epoch 13/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8045 - loss: 0.5278 - val_accuracy: 0.8580 - val_loss: 0.7348
# Epoch 14/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8067 - loss: 0.5247 - val_accuracy: 0.8648 - val_loss: 0.5247
# Epoch 15/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8073 - loss: 0.5210 - val_accuracy: 0.8963 - val_loss: 0.4017
# Epoch 16/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8077 - loss: 0.5204 - val_accuracy: 0.8499 - val_loss: 0.7408
# Epoch 17/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8091 - loss: 0.5172 - val_accuracy: 0.8478 - val_loss: 0.6028
# Epoch 18/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8096 - loss: 0.5138 - val_accuracy: 0.8741 - val_loss: 0.4774
# Epoch 19/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8095 - loss: 0.5132 - val_accuracy: 0.8563 - val_loss: 0.5035
# Epoch 20/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8113 - loss: 0.5111 - val_accuracy: 0.8648 - val_loss: 0.6449
# Epoch 21/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8102 - loss: 0.5140 - val_accuracy: 0.8894 - val_loss: 0.4027
# Epoch 22/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8116 - loss: 0.5101 - val_accuracy: 0.8581 - val_loss: 0.6561
# Epoch 23/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8124 - loss: 0.5089 - val_accuracy: 0.8673 - val_loss: 0.6198
# Epoch 24/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8126 - loss: 0.5061 - val_accuracy: 0.8587 - val_loss: 0.6460
# Epoch 25/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8125 - loss: 0.5069 - val_accuracy: 0.8455 - val_loss: 0.6743
# Epoch 26/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8131 - loss: 0.5048 - val_accuracy: 0.8721 - val_loss: 0.5350
# Epoch 27/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8127 - loss: 0.5046 - val_accuracy: 0.8437 - val_loss: 0.9187
# Epoch 28/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8128 - loss: 0.5069 - val_accuracy: 0.8700 - val_loss: 0.5608
# Epoch 29/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8126 - loss: 0.5048 - val_accuracy: 0.8540 - val_loss: 0.9544
# Epoch 30/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8138 - loss: 0.4994 - val_accuracy: 0.8469 - val_loss: 0.7487
# Epoch 31/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8138 - loss: 0.5016 - val_accuracy: 0.8510 - val_loss: 0.6336
# Epoch 32/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8141 - loss: 0.5001 - val_accuracy: 0.8694 - val_loss: 0.5142
# Epoch 33/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8145 - loss: 0.5017 - val_accuracy: 0.8686 - val_loss: 0.7415
# Epoch 34/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8141 - loss: 0.5011 - val_accuracy: 0.8603 - val_loss: 0.6481
# Epoch 35/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8150 - loss: 0.4995 - val_accuracy: 0.8557 - val_loss: 0.5997
# Epoch 36/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8157 - loss: 0.4978 - val_accuracy: 0.8556 - val_loss: 0.6919
# Epoch 37/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8136 - loss: 0.4999 - val_accuracy: 0.8505 - val_loss: 0.6454
# Epoch 38/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8150 - loss: 0.4961 - val_accuracy: 0.8545 - val_loss: 0.7464
# Epoch 39/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8141 - loss: 0.5002 - val_accuracy: 0.8683 - val_loss: 0.6807
# Epoch 40/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8156 - loss: 0.4995 - val_accuracy: 0.8425 - val_loss: 0.9508
# Epoch 41/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8151 - loss: 0.4975 - val_accuracy: 0.8695 - val_loss: 0.8353
# Epoch 42/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8163 - loss: 0.4966 - val_accuracy: 0.8657 - val_loss: 0.6718
# Epoch 43/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8158 - loss: 0.4965 - val_accuracy: 0.8694 - val_loss: 0.5259
# Epoch 44/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8157 - loss: 0.4983 - val_accuracy: 0.8443 - val_loss: 0.5682
# Epoch 45/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8161 - loss: 0.4986 - val_accuracy: 0.8575 - val_loss: 0.7377
# Epoch 46/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8160 - loss: 0.4948 - val_accuracy: 0.8689 - val_loss: 0.5189
# Epoch 47/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8171 - loss: 0.4940 - val_accuracy: 0.8632 - val_loss: 0.7307
# Epoch 48/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8167 - loss: 0.4951 - val_accuracy: 0.8509 - val_loss: 1.0137
# Epoch 49/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8158 - loss: 0.4955 - val_accuracy: 0.8627 - val_loss: 0.6444
# Epoch 50/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8162 - loss: 0.4953 - val_accuracy: 0.8559 - val_loss: 0.6461
# Epoch 51/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8175 - loss: 0.4918 - val_accuracy: 0.8560 - val_loss: 0.6642
# Epoch 52/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8174 - loss: 0.4930 - val_accuracy: 0.8531 - val_loss: 0.7004
# Epoch 53/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8175 - loss: 0.4917 - val_accuracy: 0.8656 - val_loss: 0.7361
# Epoch 54/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8170 - loss: 0.4937 - val_accuracy: 0.8574 - val_loss: 0.7332
# Epoch 55/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8170 - loss: 0.4914 - val_accuracy: 0.8625 - val_loss: 0.6019
# Epoch 56/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8191 - loss: 0.4899 - val_accuracy: 0.8525 - val_loss: 0.5992
# Epoch 57/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8173 - loss: 0.4955 - val_accuracy: 0.8578 - val_loss: 0.5746
# Epoch 58/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8178 - loss: 0.4927 - val_accuracy: 0.8546 - val_loss: 0.7476
# Epoch 59/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8180 - loss: 0.4939 - val_accuracy: 0.8709 - val_loss: 0.6204
# Epoch 60/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8177 - loss: 0.4929 - val_accuracy: 0.8670 - val_loss: 0.6721
# Epoch 61/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8187 - loss: 0.4900 - val_accuracy: 0.8636 - val_loss: 0.6459
# Epoch 62/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8170 - loss: 0.4940 - val_accuracy: 0.8595 - val_loss: 0.7199
# Epoch 63/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8167 - loss: 0.4980 - val_accuracy: 0.8572 - val_loss: 0.8344
# Epoch 64/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8182 - loss: 0.4913 - val_accuracy: 0.8674 - val_loss: 0.6651
# Epoch 65/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8186 - loss: 0.4917 - val_accuracy: 0.8591 - val_loss: 0.9263
# Epoch 66/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8185 - loss: 0.4902 - val_accuracy: 0.8597 - val_loss: 0.9079
# Epoch 67/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8178 - loss: 0.4950 - val_accuracy: 0.8607 - val_loss: 0.6010
# Epoch 68/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8167 - loss: 0.4976 - val_accuracy: 0.8689 - val_loss: 0.7466
# Epoch 69/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8174 - loss: 0.4972 - val_accuracy: 0.8717 - val_loss: 0.5486
# Epoch 70/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8176 - loss: 0.4943 - val_accuracy: 0.8597 - val_loss: 0.9925
# Epoch 71/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8178 - loss: 0.4951 - val_accuracy: 0.8615 - val_loss: 0.7561
# Epoch 72/100
# 493/493 - 9s - 19ms/step - accuracy: 0.8176 - loss: 0.4940 - val_accuracy: 0.8644 - val_loss: 0.6172
# Epoch 73/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8183 - loss: 0.4924 - val_accuracy: 0.8592 - val_loss: 0.5345
# Epoch 74/100
# 493/493 - 8s - 15ms/step - accuracy: 0.8176 - loss: 0.4914 - val_accuracy: 0.8559 - val_loss: 0.6626
# Epoch 75/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8176 - loss: 0.4969 - val_accuracy: 0.8624 - val_loss: 0.9330
# Epoch 76/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8170 - loss: 0.4976 - val_accuracy: 0.8715 - val_loss: 0.8213
# Epoch 77/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8166 - loss: 0.4967 - val_accuracy: 0.8604 - val_loss: 0.7808
# Epoch 78/100
# 493/493 - 7s - 15ms/step - accuracy: 0.8183 - loss: 0.4956 - val_accuracy: 0.8663 - val_loss: 0.6294
# Epoch 79/100
# 493/493 - 11s - 22ms/step - accuracy: 0.8175 - loss: 0.4958 - val_accuracy: 0.8601 - val_loss: 0.7621
# Epoch 80/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8169 - loss: 0.4974 - val_accuracy: 0.8594 - val_loss: 0.7395
# Epoch 81/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8173 - loss: 0.4988 - val_accuracy: 0.8761 - val_loss: 0.5588
# Epoch 82/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8173 - loss: 0.4960 - val_accuracy: 0.8372 - val_loss: 0.8374
# Epoch 83/100
# 493/493 - 10s - 19ms/step - accuracy: 0.8160 - loss: 0.4986 - val_accuracy: 0.8777 - val_loss: 0.5176
# Epoch 84/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8178 - loss: 0.4934 - val_accuracy: 0.8597 - val_loss: 0.6350
# Epoch 85/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8173 - loss: 0.4971 - val_accuracy: 0.8934 - val_loss: 0.4756
# Epoch 86/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8175 - loss: 0.4954 - val_accuracy: 0.8589 - val_loss: 0.6213
# Epoch 87/100
# 493/493 - 10s - 21ms/step - accuracy: 0.8183 - loss: 0.4975 - val_accuracy: 0.8689 - val_loss: 0.9636
# Epoch 88/100
# 493/493 - 10s - 20ms/step - accuracy: 0.8179 - loss: 0.4972 - val_accuracy: 0.8610 - val_loss: 0.7949
# Epoch 89/100
# 493/493 - 11s - 22ms/step - accuracy: 0.8161 - loss: 0.4997 - val_accuracy: 0.8375 - val_loss: 0.9955
# Epoch 90/100
# 493/493 - 21s - 42ms/step - accuracy: 0.8187 - loss: 0.4925 - val_accuracy: 0.8613 - val_loss: 0.9652
# Epoch 91/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8176 - loss: 0.4963 - val_accuracy: 0.8647 - val_loss: 0.7309
# Epoch 92/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8190 - loss: 0.4901 - val_accuracy: 0.8512 - val_loss: 0.7201
# Epoch 93/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8188 - loss: 0.4916 - val_accuracy: 0.8592 - val_loss: 0.8397
# Epoch 94/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8180 - loss: 0.4966 - val_accuracy: 0.8574 - val_loss: 0.8272
# Epoch 95/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8183 - loss: 0.4991 - val_accuracy: 0.8679 - val_loss: 0.6002
# Epoch 96/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8200 - loss: 0.4937 - val_accuracy: 0.8455 - val_loss: 0.8886
# Epoch 97/100
# 493/493 - 8s - 17ms/step - accuracy: 0.8186 - loss: 0.4918 - val_accuracy: 0.8574 - val_loss: 0.8860
# Epoch 98/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8185 - loss: 0.4947 - val_accuracy: 0.8587 - val_loss: 1.0947
# Epoch 99/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8189 - loss: 0.4934 - val_accuracy: 0.8642 - val_loss: 0.8462
# Epoch 100/100
# 493/493 - 8s - 16ms/step - accuracy: 0.8193 - loss: 0.4945 - val_accuracy: 0.8557 - val_loss: 0.6820
# 6161/6161 - 6s - 906us/step - accuracy: 0.8561 - loss: 0.3806
# 206/206 - 0s - 990us/step - accuracy: 0.8557 - loss: 0.6820
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion Matrix:
# [[1971  251   25    0  152    0]
#  [  36 1908    8    0   36    0]
#  [  47   35  502    0  142    0]
#  [   0    0    7  445    0    0]
#  [  21   43   18    0  567    0]
#  [   5    0   39   73   12  241]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Walking       0.95      0.82      0.88      2399
#      Jogging       0.85      0.96      0.90      1988
#     Upstairs       0.84      0.69      0.76       726
#      Sitting       0.86      0.98      0.92       452
#   Downstairs       0.62      0.87      0.73       649
#     Standing       1.00      0.65      0.79       370
#
#     accuracy                           0.86      6584
#    macro avg       0.85      0.83      0.83      6584
# weighted avg       0.87      0.86      0.86      6584
